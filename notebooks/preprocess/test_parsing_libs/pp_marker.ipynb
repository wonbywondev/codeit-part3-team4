# %%
import preprocess.pp_v4 as pp
from preprocess.pp_basic import BASE_DIR, RAW_DIR, DATA_DIR, docs

# %%
PDF_PATH = str(docs[0])

# %% [markdown]
# ## 표 데이터 추출 이쁘게

# %%
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
from marker.output import text_from_rendered

converter = PdfConverter(
    artifact_dict=create_model_dict(),
)
rendered = converter(PDF_PATH)
text, _, images = text_from_rendered(rendered)
# Out:
# Loaded layout model s3://layout/2025_02_18 on device cpu with dtype torch.float16
# Loaded texify model s3://texify/2025_02_18 on device cpu with dtype torch.float16
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       2 from marker.models import create_model_dict
#       3 from marker.output import text_from_rendered
#       5 converter = PdfConverter(
# ----> 6     artifact_dict=create_model_dict(device="cpu"),
#       7 )
#       8 rendered = converter(PDF_PATH)
#       9 text, _, images = text_from_rendered(rendered)
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/marker/models.py:16, in create_model_dict(device, dtype)
#      12 def create_model_dict(device=None, dtype=None) -> dict:
#      13     return {
#      14         "layout_model": LayoutPredictor(device=device, dtype=dtype),
#      15         "texify_model": TexifyPredictor(device=device, dtype=dtype),
# ---> 16         "recognition_model": RecognitionPredictor(device=device, dtype=dtype),
#      17         "table_rec_model": TableRecPredictor(device=device, dtype=dtype),
#      18         "detection_model": DetectionPredictor(device=device, dtype=dtype),
#      19         "inline_detection_model": InlineDetectionPredictor(device=device, dtype=dtype),
#      20         "ocr_error_model": OCRErrorPredictor(device=device, dtype=dtype)
#      21     }
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/surya/common/predictor.py:24, in BasePredictor.__init__(self, checkpoint, device, dtype)
#      21 self.processor = None
#      22 loader = self.model_loader_cls(checkpoint)
# ---> 24 self.model = loader.model(device, dtype)
#      25 self.processor = loader.processor()
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/surya/recognition/loader.py:35, in RecognitionModelLoader.model(self, device, dtype)
#      32 if dtype is None:
#      33     dtype = settings.MODEL_DTYPE
# ---> 35 config = SuryaOCRConfig.from_pretrained(self.checkpoint)
#      36 decoder_config = config.decoder
#      37 decoder = SuryaOCRDecoderConfig(**decoder_config)
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/surya/common/s3.py:132, in S3DownloaderMixin.from_pretrained(cls, pretrained_model_name_or_path, *args, **kwargs)
#     129             print(f"Failed to download {pretrained_model_name_or_path} after {retries} attempts.")
#     130             raise e  # Reraise exception after max retries
# --> 132 return super().from_pretrained(local_path, *args, **kwargs)
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/transformers/configuration_utils.py:640, in PretrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     634     if config_dict["model_type"] != cls.model_type:
#     635         logger.warning(
#     636             f"You are using a model of type {config_dict['model_type']} to instantiate a model of type "
#     637             f"{cls.model_type}. This is not supported for all configurations of models and can yield errors."
#     638         )
# --> 640 return cls.from_dict(config_dict, **kwargs)
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/transformers/configuration_utils.py:839, in PretrainedConfig.from_dict(cls, config_dict, **kwargs)
#     836 for key in to_remove:
#     837     kwargs.pop(key, None)
# --> 839 logger.info(f"Model config {config}")
#     840 if return_unused_kwargs:
#     841     return config, kwargs
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/transformers/configuration_utils.py:873, in PretrainedConfig.__repr__(self)
#     872 def __repr__(self):
# --> 873     return f"{self.__class__.__name__} {self.to_json_string()}"
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/transformers/configuration_utils.py:985, in PretrainedConfig.to_json_string(self, use_diff)
#     973 """
#     974 Serializes this instance to a JSON string.
#     975
#    (...)    982     `str`: String containing all the attributes that make up this configuration instance in JSON format.
#     983 """
#     984 if use_diff is True:
# --> 985     config_dict = self.to_diff_dict()
#     986 else:
#     987     config_dict = self.to_dict()
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/transformers/configuration_utils.py:893, in PretrainedConfig.to_diff_dict(self)
#     890 default_config_dict = PretrainedConfig().to_dict()
#     892 # get class specific config dict
# --> 893 class_config_dict = self.__class__().to_dict() if not self.has_no_defaults_at_init else {}
#     895 serializable_config_dict = {}
#     897 # Only serialize values that differ from the default config,
#     898 # except always keep the 'config' attribute.
#
# File ~/dev/00_codeit/0_mission/200_DL_RAG/.venv/lib/python3.11/site-packages/surya/recognition/model/config.py:17, in SuryaOCRConfig.__init__(self, **kwargs)
#      14 def __init__(self, **kwargs):
#      15     super().__init__(**kwargs)
# ---> 17     encoder_config = kwargs.pop("encoder")
#      18     decoder_config = kwargs.pop("decoder")
#      20     self.encoder = encoder_config
#
# KeyError: 'encoder'
