# %% [markdown]
# ### 사전 준비 사항
#
# #### (1) uv add (터미널)
#
# ```bash
# uv add pdfplumber sentence-transformers faiss-cpu numpy torch python-dotenv openai
# ```
#
# #### (2) .env 파일 세팅
# ```bash
# OPENAI_API_KEY = ""
# HF_TOKEN = ""
# ```

# %%
import pdfplumber
import os
from pathlib import Path
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()
MODEL = "gpt-4o-mini"

# %%
import json

BASE_DIR = Path.cwd().parent  # /codeit-part3-team4
RAW_FOLDER = BASE_DIR / "data/raw/files"  # 수정된 경로

# 폴더에서 PDF 목록 가져오기
def get_pdf_paths(folder_path: Path | str) -> list[Path]:
    folder = Path(folder_path)
    pdf_paths = [p for p in folder.glob("*.pdf")]
    return sorted(pdf_paths)

PDF_PATH_LIST = get_pdf_paths(RAW_FOLDER)


all_data_path = os.path.join(BASE_DIR, "data", "ALL_DATA.json")

with open(all_data_path, "r", encoding="utf-8") as f:
    ALL_DATA = json.load(f)

# %%
# PDF to text
def extract_text(pdf_path: Path | str) -> str:
    texts = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            texts.append(page.extract_text() or "")
    return "\n".join(texts)

# %%
# Chunking
def chunk(text: str, size: int = 800) -> list[str]:
    return [text[i:i+size] for i in range(0, len(text), size)]

# %%
# 임베딩 및 인덱스 만들기
def build_index(chunks: list[str]) -> tuple:
    model = SentenceTransformer("all-MiniLM-L6-v2")
    embs = model.encode(chunks)

    index = faiss.IndexFlatL2(embs.shape[1])
    index.add(np.array(embs).astype("float32"))
    return index, model, chunks

# %%
# RFP 분석용 프롬프트
RFP_PROMPT = """
너는 정부·공공기관 제안요청서(RFP)를 분석하는 전문가다.
아래 컨텍스트는 하나의 정부 RFP 문서에서 추출된 내용이다.

다음 기준에 따라 **핵심 정보만 구조적으로 요약**해라.

[요약 규칙]
- 추측하지 말고, 문서에 명시된 내용만 사용
- 불필요한 설명, 배경, 미사여구 제거
- 사업 참여 판단에 필요한 정보 위주로 요약
- 항목이 없으면 "명시 없음"으로 표기

[출력 형식]
아래 각 항목은 **질문에 답하는 형태**로 작성하되,
반드시 `key: 답변` 형식으로 출력하라.
(예시) project_name: 고려대학교 차세대 포털·학사 정보시스템 구축 사업

project_name: 사업(용역)명은 무엇인가?
agency: 발주 기관(수요기관)은 어디인가?
purpose: 사업 목적(추진 배경)은 무엇인가?
budget: 총 사업 예산(사업비)은 얼마인가?
base_amount: 추정 가격/기초금액은 얼마인가?
contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
deadline: 입찰/제안서 제출 마감일시는 언제인가?
submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가?
submission_docs: 제출 서류 목록은 무엇인가?
format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가?
duration: 사업 수행 기간은 얼마나 되는가?
start_date: 사업 착수(시작) 예정일은 언제인가?
end_date: 사업 종료(납품) 예정일은 언제인가?
scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가?
requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가?
requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가?
eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가?
eval_weights: 평가 배점(점수) 비율은 어떻게 되는가?
price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가?
presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은?
qa_period: 질의응답(Q&A) 접수 기간은 언제인가?
qa_method: 질의응답 제출 방법/양식은 무엇인가?
briefing: 현장설명회가 있는가? 있다면 일정/장소는?
eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가?
consortium: 공동수급/하도급/컨소시엄 가능 여부는?
staffing: 필수 인력 요건(PM/보안담당 등)이 있는가?
security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가?
deliverables: 납품물(산출물) 목록은 무엇인가?
maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가?
contact: 문의처(담당자/전화/이메일)는 무엇인가?

[컨텍스트]
{context}

이제 위 형식에 맞춰 한국어로 요약해라.
"""

# %%
# 쿼리 답변
def answer(index, model, chunks, query: str, top_k: int = 15) -> str:
    q_emb = model.encode([query])
    _, I = index.search(np.array(q_emb).astype("float32"), top_k)
    
    context = "\n\n".join(chunks[i] for i in I[0])
    prompt = RFP_PROMPT.format(context=context)
    
    resp = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "RFP 전문 분석가. 형식 엄수."},
            {"role": "user", "content": prompt},
        ],
        max_tokens=2000,
    )
    return resp.choices[0].message.content

# %%
# 데이터 폴더 설정
docs = get_pdf_paths(RAW_FOLDER)
print(f"발견된 PDF: {len(docs)}개")
for i, doc in enumerate(docs):
    print(f"{i}: {doc.name}")
# Out:
# 발견된 PDF: 100개
# 0: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf
# 1: (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.pdf
# 2: (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.pdf
# 3: (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf
# 4: 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf
# 5: BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).pdf
# 6: KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .pdf
# 7: 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.pdf
# 8: 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.pdf
# 9: 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.pdf
# 10: 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).pdf
# 11: 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.pdf
# 12: 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.pdf
# 13: 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.pdf
# 14: 광주과학기술원_학사시스템 기능개선 사업.pdf
# 15: 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.pdf
# 16: 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.pdf
# 17: 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.pdf
# 18: 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.pdf
# 19: 국민연금공단_2024년 이러닝시스템 운영 용역.pdf
# 20: 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.pdf
# 21: 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.pdf
# 22: 국방과학연구소_대용량 자료전송시스템 고도화.pdf
# 23: 그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.pdf
# 24: 나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.pdf
# 25: 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.pdf
# 26: 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.pdf
# 27: 대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.pdf
# 28: 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.pdf
# 29: 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .pdf
# 30: 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .pdf
# 31: 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.pdf
# 32: 부산관광공사_경영정보시스템 기능개선.pdf
# 33: 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf
# 34: 사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.pdf
# 35: 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.pdf
# 36: 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.pdf
# 37: 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.pdf
# 38: 서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .pdf
# 39: 세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.pdf
# 40: 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.pdf
# 41: 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.pdf
# 42: 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.pdf
# 43: 을지대학교_을지대학교 비교과시스템 개발.pdf
# 44: 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .pdf
# 45: 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .pdf
# 46: 인천광역시_도시계획위원회 통합관리시스템 구축용역.pdf
# 47: 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.pdf
# 48: 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.pdf
# 49: 재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.pdf
# 50: 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.pdf
# 51: 재단법인경기도일자리재단_2025년 통합접수시스템 운영.pdf
# 52: 재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.pdf
# 53: 재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.pdf
# 54: 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.pdf
# 55: 전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.pdf
# 56: 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.pdf
# 57: 중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.pdf
# 58: 축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.pdf
# 59: 축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).pdf
# 60: 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .pdf
# 61: 파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.pdf
# 62: 한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.pdf
# 63: 한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.pdf
# 64: 한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.pdf
# 65: 한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .pdf
# 66: 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.pdf
# 67: 한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.pdf
# 68: 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .pdf
# 69: 한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.pdf
# 70: 한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.pdf
# 71: 한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.pdf
# 72: 한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.pdf
# 73: 한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.pdf
# 74: 한국산업단지공단_산단 안전정보시스템 1차 구축 용역.pdf
# 75: 한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.pdf
# 76: 한국생산기술연구원_2세대 전자조달시스템  기반구축사업.pdf
# 77: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.pdf
# 78: 한국수자원공사_건설통합시스템(CMS) 고도화.pdf
# 79: 한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.pdf
# 80: 한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.pdf
# 81: 한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.pdf
# 82: 한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.pdf
# 83: 한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.pdf
# 84: 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.pdf
# 85: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.pdf
# 86: 한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.pdf
# 87: 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.pdf
# 88: 한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.pdf
# 89: 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.pdf
# 90: 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.pdf
# 91: 한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).pdf
# 92: 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.pdf
# 93: 한국한의학연구원_통합정보시스템 고도화 용역.pdf
# 94: 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.pdf
# 95: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.pdf
# 96: 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf
# 97: 기초과학연구원_2025년도 중이온가속기용 극저온시스템 운전 용역.pdf
# 98: 서울시립대학교_[사전공개] 학업성취도 다차원 종단분석 통합시스템 1차.pdf
# 99: 서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf

# %%
def format_table(table: dict) -> str:
    """table_content를 읽기 좋은 텍스트로 변환."""
    tc = table.get("table_content", {})
    cols = tc.get("columns", [])
    rows = tc.get("data", [])
    if not cols and not rows:
        return ""
    
    lines = []
    title = table.get("table_title", "")
    if title:
        lines.append(f"[표] {title}")
    lines.append(" | ".join(str(c or "") for c in cols))
    for row in rows:
        lines.append(" | ".join(str(c or "") for c in row))
    return "\n".join(lines)

# %%
import re

def clean_text(text: str) -> str:
    """PDF 추출 텍스트에서 노이즈 제거."""
    # 페이지 번호 (- 1 -, - 23 - 등)
    text = re.sub(r'^- \d+ -\n?', '', text.strip())
    # 목차 점선 (···, ……, .... 등)
    text = re.sub(r'[·.…]{5,}', ' ', text)
    # 같은 글자 5회 이상 반복 (목   목   목... / 차차차차...)
    text = re.sub(r'(.)\1{4,}', '', text)
    # 연속 공백 → 단일 공백
    text = re.sub(r' {2,}', ' ', text)
    # 연속 빈줄 → 단일 빈줄
    text = re.sub(r'\n{3,}', '\n\n', text)
    return text.strip()

# %%
def chunk_from_alldata(doc_name: str, all_data: dict, size: int = 800) -> list[str] | None:
    """ALL_DATA의 섹션 단위로 그룹핑 후 size 단위로 분할."""
    if doc_name not in all_data:
        return None

    pages = all_data[doc_name]["metadata"]

    # 1) 섹션별로 페이지 텍스트 그룹핑
    sections = []  # [(섹션명, 텍스트)]
    current_sec = None
    current_parts = []

    for page in pages:
        sec = page.get("section")
        if isinstance(sec, list):
            sec_str = " | ".join(sec)
        elif sec:
            sec_str = sec
        else:
            sec_str = ""

        # 섹션이 바뀌면 이전 섹션 저장
        if sec_str != current_sec and current_parts:
            sections.append((current_sec, "\n".join(current_parts)))
            current_parts = []
        current_sec = sec_str

        # 페이지 텍스트 조립
        parts = []
        if sec_str:
            parts.append(f"[섹션: {sec_str}] (p.{page['page'] + 1})")
        else:
            parts.append(f"(p.{page['page'] + 1})")

        if page.get("text"):
            parts.append(clean_text(page["text"]))

        if page.get("table"):
            for t in page["table"]:
                table_text = format_table(t)
                if table_text:
                    parts.append(table_text)

        current_parts.append("\n".join(parts))

    # 마지막 섹션
    if current_parts:
        sections.append((current_sec, "\n".join(current_parts)))

    # 2) 섹션별로 size 단위 분할 (섹션 경계에서 끊김 방지)
    chunks = []
    for sec_name, sec_text in sections:
        for i in range(0, len(sec_text), size):
            chunks.append(sec_text[i:i + size])

    return chunks

# %%
# 전체 문서별 인덱스 저장
doc_indexes = {}

for doc_path in docs:
    print(f"처리 중: {doc_path.name}")
    chunks = chunk_from_alldata(doc_path.name, ALL_DATA)

    if chunks is None:
        text = clean_text(extract_text(doc_path))
        chunks = chunk(text)

    index, model, chunks = build_index(chunks)
    doc_indexes[doc_path] = (index, model, chunks)

print("모든 문서 인덱싱 완료!")
# Out:
# 처리 중: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1498.53it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2663.77it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3188.55it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2558.68it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2400.38it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2349.19it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2615.20it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2496.10it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2558.37it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1137.55it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2861.91it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2336.50it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2814.35it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2565.19it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 광주과학기술원_학사시스템 기능개선 사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2527.18it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2472.39it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1160.84it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2440.75it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2646.31it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국민연금공단_2024년 이러닝시스템 운영 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2902.40it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2482.95it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2590.60it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 국방과학연구소_대용량 자료전송시스템 고도화.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2726.69it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2437.19it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2738.56it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2496.68it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2783.77it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2986.82it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2282.75it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2878.73it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2443.47it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2464.70it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 부산관광공사_경영정보시스템 기능개선.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2890.09it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2531.53it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2605.69it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 842.49it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2767.35it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2893.42it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2741.20it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3815.09it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2731.31it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2793.65it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2661.64it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 을지대학교_을지대학교 비교과시스템 개발.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2782.50it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2600.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2596.95it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 인천광역시_도시계획위원회 통합관리시스템 구축용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2517.97it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2665.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3467.45it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2481.79it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2595.63it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인경기도일자리재단_2025년 통합접수시스템 운영.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1365.48it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2695.90it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2748.86it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2345.86it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2857.21it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3671.49it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1182.34it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2555.22it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2597.08it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2595.38it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2473.54it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2606.73it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2616.34it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2543.71it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2585.14it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2554.76it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2643.46it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2609.44it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2531.40it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1224.58it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2665.55it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2614.14it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2602.27it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국산업단지공단_산단 안전정보시스템 1차 구축 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2388.41it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2485.33it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국생산기술연구원_2세대 전자조달시스템  기반구축사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2643.82it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2200.02it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국수자원공사_건설통합시스템(CMS) 고도화.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2300.49it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3165.21it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2488.10it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2525.74it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1295.17it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2504.93it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2815.12it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2653.07it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2535.94it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2837.30it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2812.68it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2735.28it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2490.88it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1449.13it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2664.12it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국한의학연구원_통합정보시스템 고도화 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2544.71it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2410.04it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2503.70it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2311.33it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 기초과학연구원_2025년도 중이온가속기용 극저온시스템 운전 용역.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2550.71it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서울시립대학교_[사전공개] 학업성취도 다차원 종단분석 통합시스템 1차.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2470.38it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 처리 중: 서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2574.17it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 모든 문서 인덱싱 완료!

# %%
# 특정 문서의 청크 몇 개를 뽑아서 확인
test_name = str(docs[0]).split("/")[-1]
chunks_test = chunk_from_alldata(test_name, ALL_DATA)

print(f"문서: {test_name}")
print(f"총 청크 수: {len(chunks_test)}")
print()

# 섹션/페이지/테이블이 포함된 청크 찾기
for i, c in enumerate(chunks_test):
    has_section = "[섹션:" in c
    has_page = "(p." in c
    has_table = "[표]" in c
    if has_section or has_table:
        print(f"=== 청크 {i} ({len(c)}자) ===")
        print(c)
        print("...\n")
        if i > 5:
            break
# Out:
# 문서: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf
# 총 청크 수: 252
#
# === 청크 1 (800자) ===
# [섹션: 1. 추진개요] (p.3)
# Ⅰ. 추진개요1추진배경 및 방향□ 「벤처기업육성에 관한 특별조치법」(이하 ‘벤처기업법’) 복수의결권주식, 스톡옵션(주식매수선택권), 성과조건부주식교부계약(RS) 등의 기능 고도화 및 이관, 신규 구축업무를 本 과업에서 추진 ⚬(복수의결권주식*) 벤처기업법 제16조의11에 따라 발행된 복수의결권주식 보고 업무처리 시스템 구축* 복수의결권이란? 모든 주주는 1주당 하나의 의결권을 갖는 주주평등원칙(상법)과 별도로 비상장 벤처기업 창업자에게만 1주당 최대 10배의 의결권 행사를 부여하는 제도 ⚬(스톡옵션*) 벤처기업법 제16조의3에 따라 부여된 벤처기업 스톡옵션 부여, 취소·철회 신고 및 업무시스템 구축* 스톡옵션이란? 비상장 벤처기업 임·직원 및 기업 성장에 기여한 자에게 미리 정한 가격(행사가격)으로 신주를 인수하거나 자기의 주식을 매수할 수 있는 권리 혹은 주식의 시가와 행사가격의 차액을 청구할 수 있는 권리를 부여하는 제도 -중소벤처24 內 스톡옵션 신청 기능 이관을 추진하며, 과거 데이터 정제 및 적재 등을 통한 데이터 이관 추진 ⚬(성과조건부주식*) 벤처기업법 제16조의19에 따라 성과조건부주식교부계약의 신고 및 업무처리 시스템 구축* 성과조건부주식이란? 비상장 벤처기업 임ㆍ직원 및 특정인에게 자기주식 부여를 약속하되, 일정 재직기간 및 조건을 충족해야 주식이 부여 대상자에게 귀속되도록 제한을 둔 주식□ 복수의결권주식 발행 보고 및 스톡옵션 신고기능은 기존 시스템 내 벤처확인 이력정보와 신고자(벤처기업)의 정보와 연동
# [섹션: 1. 추진개요] (p.4)
# 2사업개요□ (
# ...
#
# === 청크 3 (800자) ===
# [섹션: 2. 추진방안] (p.5)
# Ⅱ. 사업 추진방안1 추진목표추진목표◈ 벤처확인 연계를 통한 복수의결권 및 스톡옵션 시스템 고도화◈ 복수의결권주식, 스톡옵션 업무시스템 구축◈ 스톡옵션 데이터 이관 작업 수행◈ 신청접수 및 처리 결과 알림 One-Stop Service
# 추진과제세부 실행내용대민사이트① 비상장 벤처확인기업 조회, 복수의결권주식 발행·변경 보고 고도화, 스톡옵션 부여, 취소·철회 신고기능 구축 ② 단계별 처리 절차 준수복수의결권주식비상장 벤처기업 조회→보고(발행ㆍ변경)→접수(보완)→공시ㆍ고시스톡옵션성과조건부 주식비상장 벤처기업 조회→신고(취소 철회 포함)→접수(보완)③ 복수의결권(기업), 스톡옵션(기업, 부여대상자) 정보 확인 기능 구축BackOffice④ 감독기관 전용 시스템(복수의결권, 스톡옵션 별도) ⑤ 복수의결권주식, 스톡옵션 관리(본부, 13개 지방청) 기능⑥ 복수의결권주식, 스톡옵션 통계 등추가사항⑦ 타 기관 API연계를 통한 정보 확인⑧ 입력정보&서류제출 간소화, 정보보안 솔루션 적용
# [표] ◈ 벤처확인 연계를 통한 복수의결권 및 스톡옵션 시스템 고도화
# 추진 목표
# ◈ 복수의결권주식, 스톡옵션 업무시스템 구축
# ◈ 스톡옵션 데이터 이관 작업 수행
# ◈ 신청접수 및 처리 결과 알림 One-Stop Service
# 추진과제 세부 실행내용
# 대민사이트 | ① 비상장 벤처확인기업 조회, 복수의결권주식 발행·변경 보고 고도화,
# 스톡옵션 부여, 취소·철회 신고기능 구축
# ② 단계별 처리 절차 준수 | ① 비상장 벤처확인기업 조회, 복수의결권주식 발행·변경 보고 고도화,
# 스톡옵션 부여, 취소·철회 신고기능
# ...
#
# === 청크 4 (800자) ===
#  구축
# ② 단계별 처리 절차 준수_1
# 대민사이트 | 복수의결권주식 | 비상장 벤처기업 조회→보고(발행ㆍ변경)→접수(보완)→공시ㆍ고시
# 대민사이트 | 스톡옵션
# 성과조건부 주식 | 비상장 벤처기업 조회→신고(취소 철회 포함)→접수(보완)
# 대민사이트 | ③ 복수의결권(기업), 스톡옵션(기업, 부여대상자) 정보 확인 기능 구축 | ③ 복수의결권(기업), 스톡옵션(기업, 부여대상자) 정보 확인 기능 구축
# BackOffice | ④ 감독기관 전용 시스템(복수의결권, 스톡옵션 별도)
# ⑤ 복수의결권주식, 스톡옵션 관리(본부, 13개 지방청) 기능
# ⑥ 복수의결권주식, 스톡옵션 통계 등
# 추가사항 | ⑦ 타 기관 API연계를 통한 정보 확인
# ⑧ 입력정보&서류제출 간소화, 정보보안 솔루션 적용
# [섹션: 2. 추진방안] (p.6)
# 2 추진체계 및 역할□ 추진체계중소벤처기업부벤처기업확인기관(시스템 고도화 발주)자문위원(법률, 검수·검사 등)사업 수행업체벤처확인종합관리시스템 기능 고도화 수행(복수의결권, 스톡옵션, 성과조건부주식)운영 유지관리 업체現 시스템 유지관리업무 수행 中□ 추진역할구 분 역 할중소벤처기업부ㆍ사업총괄 운영ㆍ관리 감독벤처기업확인기관ㆍ벤처확인제도 운영기관ㆍ사업계획 수립, 제안요청서 작성ㆍ사업관리 및 검사ㆍ사업수행 및 운영업무자문위원ㆍ시스템 구축 및 법률 자문 등운영 유지관리 업체ㆍ벤처확인종합관리시스템 운영 유지관리 업무 수행 中사업 수행업체ㆍ복수의결권주식 및 스톡옵션 시스템 기능 고도화 컨설팅ㆍ사업수행에 필요한 데이터(스톡옵션) 자료 이관ㆍ주요 기능 분석 및 인터뷰ㆍ기획 및 디자인, 벤처확인종합관리시스템 연계 영향 평가
# ...
#
# === 청크 5 (800자) ===
# ㆍ복수의결권주식 및 스톡옵션 시스템 기능 고도화 및 테스트
# [표] □ 추진역할
# 구 분 | 역 할
# 중소벤처기업부 | ㆍ사업총괄 운영ㆍ관리 감독
# 벤처기업확인기관 | ㆍ벤처확인제도 운영기관
# ㆍ사업계획 수립, 제안요청서 작성
# ㆍ사업관리 및 검사
# ㆍ사업수행 및 운영업무
# 자문위원 | ㆍ시스템 구축 및 법률 자문 등
# 운영 유지관리 업체 | ㆍ벤처확인종합관리시스템 운영 유지관리 업무 수행 中
# 사업 수행업체 | ㆍ복수의결권주식 및 스톡옵션 시스템 기능 고도화 컨설팅
# ㆍ사업수행에 필요한 데이터(스톡옵션) 자료 이관
# ㆍ주요 기능 분석 및 인터뷰
# ㆍ기획 및 디자인, 벤처확인종합관리시스템 연계 영향 평가
# ㆍ복수의결권주식 및 스톡옵션 시스템 기능 고도화 및 테스트
# [섹션: 2. 추진방안] (p.7)
# 3 추진방안□ (구축 인터뷰) 복수의결권주식 및 스톡옵션 시스템 구축을 위한 사전 기능 요구사항에 대한 충분한 인터뷰* 진행, 분석ㆍ기획 보고서 제출 * 시스템 Risk-Point해결/개선을 위한 중소벤처기업부, 중소벤처기업부 지방청(13개) 미팅 □ (데이터분석) 스톡옵션 데이터분석을 통한 통계*자료 및 타 기관 연계정보 현황 수요조사 진행 * 벤처기업유형별(① 벤처투자, ②연구개발, ③혁신성장, 그 외 과거유형) 연계를 통한 과거 스톡옵션 신고 비율 및 업종, 지역, 매출 통계, 거래소상장 여부 등으로 활용 ◦ 벤처확인종합관리시스템 벤처확인유형별 입수된 정보를 이용한 스톡옵션 부여신고 간소화 서비스 추진ㆍ분석, 회원연계(중소벤처24) 분석 ◦ 스톡옵션 데이터 및 문서 정제/적재 작업 수행□ (시스템 구성) 벤처확인종합관리시스템 대민/백
# ...
#
# === 청크 6 (800자) ===
# 오피스 이원화 운영 中, 복수의결권, 스톡옵션 제도안내, 신청 등 서브메뉴 구성 ◦ 스톡옵션, 복수의결권주식 확인 및 행정업무 수행을 위한 별도 백오피스를 구성, 외부* 접속을 위한 접근제어 솔루션 탑재 여부 분석 * 공동인증서 로그인을 통해 접속 中, 개선방안 제시 및 로그인 기록 보관□ (시스템 기획) 스톡옵션, 복수의결권주식 정의 및 제도 이슈사항 등 분석, 스톡옵선 부여신고, 복수의결권 행사에 관한 간편 신청, 자료연계(타기관), 사용자 알림, 운영 모니터링, 통계 등 기획 ◦ 벤처확인종합관리시스템 內 탑재를 위한 시스템 분석* 자료(영향도 분석) 제출 * 데이터 연계, 기정원 인프라 구성(TA분석), 상용SW 활용 및 Risk(라이선스 등) 분석
# [섹션: 2. 추진방안] (p.8)
# 4 추진일정□ 추진일정(안)★ 복수의결권 1차 오픈일(‘24.07.10) 준수, 스톡옵션 GrandOpen(미정)주요내용M-1MM+1M+2M+3M+4123412341234123412341234RFP 공고
# 사업추진
# 기술/가격 협상 및 계약착수보고요구분석/설계시스템 구축사용자 교육시스템 오픈1차오픈운영 안정화검사 및 검수, 테스트□ 요구분석 및 설계 완료 후 중간보고 1회 진행, 시스템 고도화 및 테스트(단위, 통합), 사용자 교육 최소 2회 이상, 완료보고 1회 ◦ 중간보고 및 완료보고(중소벤처기업부, 벤처기업확인기관) -사용자 매뉴얼 작성, 업무용 매뉴얼을 통한 교육 2회 ◦ 주 단위 시스템 진행 보고(벤처기업확인기관) ◦ 시스템 안정화를 위한 1개월 이상 안정화 운영인력 상주
# [표] □ 추진일정(안)
# ★ 복수의결권 1차
# ...

# %%
# 테스트 1: 단일 문서 (docs[0])
if docs:
    test_doc = docs[0]
    print(f"\n=== {test_doc.name} 분석 ===")
    index, model, chunks = doc_indexes[test_doc]
    result = answer(index, model, chunks, "RFP 분석해줘")
    print(result)
# Out:
# === (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가?
# agency: 발주 기관(수요기관)은 어디인가?
# purpose: 사업 목적(추진 배경)은 무엇인가?
# budget: 총 사업 예산(사업비)은 얼마인가?
# base_amount: 추정 가격/기초금액은 얼마인가?
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
# deadline: 입찰/제안서 제출 마감일시는 언제인가?
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가?
# submission_docs: 제출 서류 목록은 무엇인가?
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가?
# duration: 사업 수행 기간은 얼마나 되는가?
# start_date: 사업 착수(시작) 예정일은 언제인가?
# end_date: 사업 종료(납품) 예정일은 언제인가?
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가?
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가?
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가?
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가?
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가?
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가?
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은?
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가?
# qa_method: 질의응답 제출 방법/양식은 무엇인가?
# briefing: 현장설명회가 있는가? 있다면 일정/장소는?
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가?
# consortium: 공동수급/하도급/컨소시엄 가능 여부는?
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가?
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가?
# deliverables: 납품물(산출물) 목록은 무엇인가?
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가?
# contact: 문의처(담당자/전화/이메일)는 무엇인가?

# %%
# 테스트 2: 전체 문서 루프 (비용 주의! 주석 해제 후 사용)
# 실행 완료시 rfp_summaries.json 파일이 생성됩니다.

results = {}
for doc_path in docs:
    print(f"\n=== {doc_path.name} 분석 ===")
    index, model, chunks = doc_indexes[doc_path]
    result = answer(index, model, chunks, "RFP 분석해줘")
    results[doc_path.name] = result
    print(result)

# JSON 저장
import json
with open(BASE_DIR / "rfp_summaries_meta_v3.json", "w", encoding="utf-8") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)
print("전체 분석 완료!")
# Out:
# === (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가? 명시 없음
# agency: 발주 기관(수요기관)은 어디인가? 명시 없음
# purpose: 사업 목적(추진 배경)은 무엇인가? 운영 안정화
# budget: 총 사업 예산(사업비)은 얼마인가? 명시 없음
# base_amount: 추정 가격/기초금액은 얼마인가? 명시 없음
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가? 명시 없음
# deadline: 입찰/제안서 제출 마감일시는 언제인가? 명시 없음
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가? 명시 없음
# submission_docs: 제출 서류 목록은 무엇인가? 명시 없음
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가? 명시 없음
# duration: 사업 수행 기간은 얼마나 되는가? 명시 없음
# start_date: 사업 착수(시작) 예정일은 언제인가? 명시 없음
# end_date: 사업 종료(납품) 예정일은 언제인가? 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? 요구분석/설계, 시스템 구축, 사용자 교육, 시스템 오픈
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가? 다양한 브라우저 환경 지원, 접근성 준수, 보안 요구사항
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가? 명시 없음
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가? 명시 없음
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가? 명시 없음
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가? 명시 없음
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은? 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가? 명시 없음
# qa_method: 질의응답 제출 방법/양식은 무엇인가? 명시 없음
# briefing: 현장설명회가 있는가? 있다면 일정/장소는? 명시 없음
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가? 명시 없음
# consortium: 공동수급/하도급/컨소시엄 가능 여부는? 가능
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가? 명시 없음
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가? 개인정보보호법 준수, 보안 교육 실시
# deliverables: 납품물(산출물) 목록은 무엇인가? 사업수행계획서, 보안점검결과서
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가? 명시 없음
# contact: 문의처(담당자/전화/이메일)는 무엇인가? 명시 없음
#
# === (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.pdf 분석 ===
# project_name: BIFF&ACFM 온라인서비스 재개발 및 행사지원시스템 공급 용역
# agency: 부산국제영화제
# purpose: 온라인 기반의 의전 시스템 및 출입 관리 시스템 구축
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 의전 관리, 출입 관리, 시스템 연동 등
# requirements_must: 데이터별 검색 기능, 모바일 어플리케이션 제공, 보안 요구 사항 등
# requirements_optional: 명시 없음
# eval_items: 기술 능력 평가, 경영상태, 유사사업 수행실적 등
# eval_weights: 기술 능력 평가 90점, 정량적 평가 10점, 정성적 평가 80점
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: PM급 웹 개발자 1명 필요
# security: ISMS 인증 요구
# deliverables: 통합업무관리시스템과 연계된 응용 프로그램 등
# maintenance: 유지보수 지원 포함
# contact: 명시 없음
#
# === (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.pdf 분석 ===
# project_name: 명시 없음
# agency: 한국대학스포츠협의회
# purpose: 클라우드 서비스 제공
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 일반경쟁
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 6개월
# start_date: 2024년 10월
# end_date: 2025년 3월
# scope: 서버 운영관리, 장비 운영관리 등
# requirements_must: 오픈소스 기반의 솔루션, 고가용성 범용 DBMS, SSL 지원, 백업 계획 수립 등
# requirements_optional: 국정원 보안인증 획득 서비스 제공
# eval_items: 기술 및 가격
# eval_weights: 명시 없음
# price_eval: 협상에 의한 계약
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: 필수 인력 요건 없음
# security: PKI기반 사용자 인증, 국가 사이버안전 매뉴얼 준수
# deliverables: 시스템 구성도, 응용 S/W 설치 파일 및 설정 등
# maintenance: 명시 없음
# contact: 명시 없음
#
# === (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf 분석 ===
# project_name: 통합 정보시스템 구축 사전 컨설팅
# agency: 재단법인 예술경영지원센터
# purpose: 통합미술정보시스템 구축‧운영을 위한 사전 분석 및 고도화 전략 수립
# budget: 50,000,000 (VAT 포함)
# base_amount: 명시 없음
# contract_type: 제한경쟁입찰(협상에 의한 계약)
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 계약체결일로부터 ~ 2024년 11월 29일
# start_date: 계약체결일
# end_date: 2024년 11월 29일
# scope: 환경 및 현황 분석, 데이터 분석 및 설계, 벤치마킹 사례 조사, 비전 및 전략 수립, 서비스 개발
# requirements_must: 명시 없음
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 개인정보의 안전성 확보조치 및 기밀 유지
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 경영지원팀 02-708-2212, ksj37@gokams.or.kr; 시각정보팀 02-2098-294, shwan@gokams.or.kr
#
# === 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf 분석 ===
# project_name: 2025 구미 아시아육상경기선수권대회 종합정보시스템 구축 사업
# agency: 2025 구미아시아육상경기선수권대회 조직위원회
# purpose: 종합정보시스템 구축을 통한 대회 운영 효율성 및 대회 정보 제공
# budget: 260,000,000원 (부가세 포함)
# base_amount: 260,000,000원
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 제안서 10부 (USB 별도 제출)
# format_requirement: A4규격 (210×297), 50페이지 이내, PT 보고용 파워포인트 제출
# duration: 계약일 ~ 2025. 6. 6.
# start_date: 계약일
# end_date: 2025. 6. 6.
# scope: 대회 종합정보시스템 구축 및 운영
# requirements_must: 웹 접근성 및 호환성 준수, 저작권 및 지적재산권 보호, 시스템 보안성 확보
# requirements_optional: 명시 없음
# eval_items: 기술능력 평가 (정량 20점, 정성 70점) + 가격평가 (10점)
# eval_weights: 기술능력 90점, 가격 10점
# price_eval: 가격 평가 방식 (협상기준)
# presentation: 제안 발표 필요, 일정은 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 중소 소프트웨어 사업자만 입찰 가능, 대기업 및 중견기업 입찰 불가
# consortium: 공동수급 불가
# staffing: 필수 인력 요건 명시 없음
# security: 시스템 보안성 및 개인정보 보호 요구사항 존재
# deliverables: 종합정보시스템, 대회 홈페이지, 보고서 관리 시스템 등
# maintenance: 대회 종료 시까지 유지보수
# contact: 명시 없음
#
# === BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가? 명시 없음
# agency: 발주 기관(수요기관)은 어디인가? 명시 없음
# purpose: 사업 목적(추진 배경)은 무엇인가? 명시 없음
# budget: 총 사업 예산(사업비)은 얼마인가? 명시 없음
# base_amount: 추정 가격/기초금액은 얼마인가? 명시 없음
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가? 명시 없음
# deadline: 입찰/제안서 제출 마감일시는 언제인가? 명시 없음
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가? 명시 없음
# submission_docs: 제출 서류 목록은 무엇인가? 명시 없음
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가? 명시 없음
# duration: 사업 수행 기간은 얼마나 되는가? 명시 없음
# start_date: 사업 착수(시작) 예정일은 언제인가? 명시 없음
# end_date: 사업 종료(납품) 예정일은 언제인가? 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? 명시 없음
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가? 원격지 개발에 따른 구체적인 원격지 보안관리대책 제시 요구
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가? 명시 없음
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가? 경영상태 평가, 사회적 책임 평가
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가? 명시 없음
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가? 명시 없음
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은? 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가? 명시 없음
# qa_method: 질의응답 제출 방법/양식은 무엇인가? 명시 없음
# briefing: 현장설명회가 있는가? 있다면 일정/장소는? 명시 없음
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가? 명시 없음
# consortium: 공동수급/하도급/컨소시엄 가능 여부는? 명시 없음
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가? 명시 없음
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가? 원격지 보안관리대책 요구
# deliverables: 납품물(산출물) 목록은 무엇인가? 명시 없음
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가? 명시 없음
# contact: 문의처(담당자/전화/이메일)는 무엇인가? 명시 없음
#
# === KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 명시 없음
# requirements_optional: 명시 없음
# eval_items: 기술력, 실적, 경험, 인력구성
# eval_weights: 100% (최고 수준), 85%, 70%, 55%, 40% 등급별 배점
# price_eval: 명시 없음
# presentation: 제안 발표 일정은 별도 공지
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 보안 요구 사항 및 인증 요구사항 명시 없음
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: - VOIP 보안 - 무선침입방지 - 무선랜 인증 - 가상사설망 - 네트워크 접근통제 - 스팸메일차단 - 바이러스백신 - PC매체제어 - PC침입차단 - 콘텐츠보안 - 자료유출 방지 - 메일보안 - 서버보안 - DB접근 통제 - 다중영역구분 - 스마트카드 - 보안USB - 복합기 완전삭제
# requirements_optional: 명시 없음
# eval_items: - 전략 및 방법론 - 기술 및 기능 - 성능 및 품질 - 신용 평가 등급
# eval_weights: - 정성적 평가: 70점 - 가격 평가: 10점
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: - 보안 요구사항은 공인전자서명 기반으로 사용자 인증 필요 - 국가 정보보안 기본지침 준수 - 보안적합성 인증 필요
# deliverables: 명시 없음
# maintenance: - 하자보수는 과업 최종완료일로부터 1년간 지원 - 교육 및 기술 지원 요구사항 포함
# contact: 명시 없음
#
# === 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.pdf 분석 ===
# project_name: 2024년도 평택시 버스정보시스템(BIS) 구축사업 용역
# agency: 평택시
# purpose: 대중교통 이용편의 증진 및 서비스 수준 향상을 위한 버스정보시스템(BIS) 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 버스정보시스템 구축 및 관련 서비스 제공
# requirements_must: 장애 관리 및 위험 수준 발생 시 SMS 알림, 정보 처리 개선, 정류소 안내단말기 소프트웨어 기능 요구사항
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 보안 및 개인정보 요구사항 준수
# deliverables: 시스템 구축 문서, 사용자 교육 자료
# maintenance: 유지보수 및 운영 조건 설정
# contact: 명시 없음
#
# === 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.pdf 분석 ===
# project_name: 2024년 통합사회정보시스템 운영 지원
# agency: 경기도사회서비스원
# purpose: 사업 목적은 통합사회정보시스템 운영 지원을 위한 것임.
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 2024년 3월로 예상
# end_date: 명시 없음
# scope: 통합사회정보시스템의 운영 지원
# requirements_must: 보안 요구사항, 시스템 관리 요구사항 등 포함
# requirements_optional: 명시 없음
# eval_items: 기술능력평가
# eval_weights: 기술능력평가 90점, 정량적 평가기준 20점 점수 부여
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 정보시스템 구축 또는 유지관리 실적 필요
# consortium: 명시 없음
# staffing: PM 및 관련 인력 요구사항 포함될 수 있음
# security: 보안 취약점 점검 및 조치 요구
# deliverables: 납품물 목록 명시 없음
# maintenance: 유지관리 계획 및 범위 포함
# contact: 기획예산팀 김 복 인 (070-4880-1941), 경영지원팀 김 경 아 (070-4880-3784)
#
# === 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).pdf 분석 ===
# project_name: 봉화군 재난통합관리시스템 고도화 사업
# agency: 봉화군청
# purpose: 재난통합관리시스템 구축 및 운영에 따른 기술 지원
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 구축 및 운영에 필요한 기술이전 및 기술자문
# requirements_must: 시스템 구축 및 운영 관련 기술이전 계획, 운영요원 기술이전 계획, 사용자 지침서 작성
# requirements_optional: 지속적인 정보 제공 및 기술자문
# eval_items: 평가 항목 구성 미제시
# eval_weights: 평가 배점 비율 미제시
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 과거 3년 이내 최저임금법 및 근로기준법 위반 기록이 없는 자
# consortium: 가능
# staffing: 명시 없음
# security: 정보 보호 및 보안 규정 준수 요구
# deliverables: 착수보고서, 수시보고서, 최종보고서, 운영자 매뉴얼
# maintenance: 하자 보증기간 12개월
# contact: 명시 없음
#
# === 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.pdf 분석 ===
# project_name: 산학협력단 정보시스템 운영 용역업체 선정
# agency: 경희대학교 산학협력단
# purpose: 정보시스템 운영 효율화 및 안정적인 서비스 제공
# budget: 400,000,000원 (부가세 포함)
# base_amount: 200,000,000원 (1차년도)
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 2024년 계약체결일 ~ 2026년 4월 30일
# start_date: 계약체결일
# end_date: 2026년 4월 30일
# scope: 정보시스템 운영 및 유지관리, 내외부 연계시스템 관련 운영
# requirements_must: 품질 보증 활동, 정보보호 준수 등
# requirements_optional: 명시 없음
# eval_items: 사업수행 실적, 경영상태 등
# eval_weights: 5점 (각 항목)
# price_eval: 가격 및 기술 평가
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 필수 인력 요구사항 명시됨
# security: 보안 및 개인정보 요구사항 포함
# deliverables: 사업수행계획서, 각종 보고서, 시스템 관련 문서 등
# maintenance: 시스템 유지보수 및 운영 지원 조건 포함
# contact: 명시 없음
#
# === 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가?
# agency: 발주 기관(수요기관)은 어디인가?
# purpose: 사업 목적(추진 배경)은 무엇인가?
# budget: 총 사업 예산(사업비)은 얼마인가?
# base_amount: 추정 가격/기초금액은 얼마인가?
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
# deadline: 입찰/제안서 제출 마감일시는 언제인가?
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가?
# submission_docs: 제출 서류 목록은 무엇인가?
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가?
# duration: 사업 수행 기간은 얼마나 되는가?
# start_date: 사업 착수(시작) 예정일은 언제인가?
# end_date: 사업 종료(납품) 예정일은 언제인가?
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가?
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가?
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가?
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가?
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가?
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가?
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은?
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가?
# qa_method: 질의응답 제출 방법/양식은 무엇인가?
# briefing: 현장설명회가 있는가? 있다면 일정/장소는?
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가?
# consortium: 공동수급/하도급/컨소시엄 가능 여부는?
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가?
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가?
# deliverables: 납품물(산출물) 목록은 무엇인가?
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가?
# contact: 문의처(담당자/전화/이메일)는 무엇인가?
#
# 명시 없음.
#
# === 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.pdf 분석 ===
# project_name: 명시 없음
# agency: 광주과학기술원
# purpose: 연구·개발 용도로 운영 중인 시스템에 대한 유지보수 용역업체 보안관리 가이드라인 제시
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 계약체결일로부터 3개월 이내
# start_date: 계약체결일
# end_date: 계약체결일로부터 3개월 이내
# scope: 연구용 시스템 유지보수 관련 업무
# requirements_must: 용역직원 작업이력 로그 관리, 최소 권한만 설정·부여, 시스템 접근 권한 제한
# requirements_optional: 명시 없음
# eval_items: 기술 및 기능, 성능 및 품질, 프로젝트 관리
# eval_weights: 기술 및 기능 80점, 성능 및 품질 9점, 프로젝트 관리 9점
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 하도급 가능
# staffing: 명시 없음
# security: 정보보안부서 통보 및 승인 후 계정 부여, 보안조치 필요
# deliverables: 명시 없음
# maintenance: 유지보수 계약기간 동안 유지보수 조건 적용
# contact: 명시 없음
#
# === 광주과학기술원_학사시스템 기능개선 사업.pdf 분석 ===
# project_name: 학사시스템 기능개선 사업
# agency: 광주과학기술원
# purpose: 업무서비스 품질 제고 및 행정 효율화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 5개월
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 구축/개발 및 설치, 테스트 수행 및 유지보수
# requirements_must: 기능개선 및 업무 연속성 보장
# requirements_optional: 명시 없음
# eval_items: 기술 평가, 가격 평가
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: 필수 인력 요건 없음
# security: 개인정보 보호 요구사항
# deliverables: 명시 없음
# maintenance: 유지보수 기간 및 범위 명시 없음
# contact: 명시 없음
#
# === 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 입찰참가신청서 1부, 법인인감증명서 및 사용인감계 1부, 사업자등록증 사본 1부, 법인등기부등본 민간인 경우 1부, 국세, 지방세, 건강보험료 완납증명서
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 네트워크 접근통제, 네트워크 자료유출방지, 웹서비스 적용, 정보시스템의 보안 계획
# requirements_optional: 명시 없음
# eval_items: 필수 요구사항, 성능 요구사항, 인터페이스 요구사항, 데이터 요구사항, 테스트 요구사항, 보안 요구사항, 품질 요구사항
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 필수 인력 요건 명시 없음
# security: 보안 및 개인정보 요구사항, 프로그래밍 언어 요구사항
# deliverables: 명시 없음
# maintenance: 유상 유지관리 범위 및 세부내역 포함
# contact: 재무회계팀 이정호 042-868-9366 jeongho@kiom.re.kr, 총무전산팀 김유성 042-866-9265 zzziii@kiom.re.kr
#
# === 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.pdf 분석 ===
# project_name: 철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역
# agency: 국가철도공단
# purpose: 디지털트윈 관련 정보체계 및 전략 수립
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 2024년 8월(정확한 날짜 미제공)
# submission_method: 명시 없음
# submission_docs: 제안서, 실적증명서, 경영상태 서류 등
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 디지털트윈 현황 및 환경 분석, 관련 표준정보체계 검토 등
# requirements_must: 정보보안 관리, 관련 실적 및 인력 요건
# requirements_optional: 명시 없음
# eval_items: 경영상태, 수행 경험 및 실적, 투입인력 적정성, 사업 이해도, 추진 전략, 방법론, 보안 요구사항, 품질 요구사항
# eval_weights: 기술력 30%, 가격 30%, 수행능력 30%, 기타 10%
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 최근 3년 이내 디지털트윈 및 BIM 관련 실적, 실적증명서 필요
# consortium: 명시 없음
# staffing: 필수 인력 요구 없음
# security: 정보보안 요구사항 포함
# deliverables: 연구보고서, 환경 분석 보고서, 전략 수립 방안, 최종 보고서 등
# maintenance: 명시 없음
# contact: 철도혁신연구원 차효정(042-607-3112), 김지훈(042-607-3115), 최성수(042-607-3116)
#
# === 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.pdf 분석 ===
# project_name: 국립인천해양박물관 해양자료관리시스템 구축 용역
# agency: 국립인천해양박물관
# purpose: 해양자료 관리 시스템 구축
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 장기계속계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 계약일로부터 6개월 (1차 4개월, 2차 2개월)
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 해양자료관리시스템 기능 및 요구사항
# requirements_must: 시스템 무중단 운영 및 장애 복구 요구사항
# requirements_optional: 명시 없음
# eval_items: 기술 및 기능 요구사항 등
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 발주기관의 정보보안 관리규정 준수
# deliverables: 사업수행계획서, 완료보고서, 사용자 매뉴얼 등
# maintenance: 명시 없음
# contact: 배진경 (032-453-8832)
#
# === 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.pdf 분석 ===
# project_name: 디지털 콜 서비스 통합 구축 사업
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 디지털 콜 서비스 통합 구축
# requirements_must: H.320~H.324, H.310, VoIP, H.323, SIP, 데이터 공유 및 재사용, 공공데이터 제공, 이중화 구성, 통화 품질 확보
# requirements_optional: 소프트웨어 관련 인증(가점 2점), 하수급인의 정부ㆍ지자체ㆍ공공기관 수상경력(회당 1점)
# eval_items: 유사과업수행경험, 과업이해도, 추진 전략, 적용기술, 표준 프레임워크, 시스템 요구사항, 기능 요구사항, 보안 요구사항
# eval_weights: 기술(29점), 일반현황(5점), 전략 및 방법론(17점)
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 보안 및 정보 보호 요구사항(음성 및 신호 트래픽 암호화)
# deliverables: 납품완료보고서, 기술지원 확약서, 시스템 구성도
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 국민연금공단_2024년 이러닝시스템 운영 용역.pdf 분석 ===
# project_name: 2024년 이러닝시스템 운영 용역 제안요청서
# agency: 국민연금공단
# purpose: 이러닝 시스템 운영 및 콘텐츠 개발, 관리
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 이러닝 시스템 운영 및 콘텐츠 개발·관리
# requirements_must: MS-SQL 2005, JAVA, JSP 사용, 보안 관리 대책 마련
# requirements_optional: 유효한 정보보호체계 인증 또는 소프트웨어프로세스 품질인증 보유시 우대
# eval_items: 기술 평가, 가격 평가
# eval_weights: 기술 70점, 가격 30점
# price_eval: 가격 평가 방식 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 하도급 및 공동수급체 구성 가능
# consortium: 가능
# staffing: 명시 없음
# security: 개인정보 보호, 보안 조치 요구
# deliverables: 교육 콘텐츠, 교육 평가서, 설문조사 및 결과 분석 자료
# maintenance: 유지보수, 운영 조건 명시 없음
# contact: 명시 없음
#
# === 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.pdf 분석 ===
# project_name: 사회보험료 지원 프로그램 개발 사업
# agency: 발주 기관(수요기관)은 어디인가? 명시 없음
# purpose: 사업 목적(추진 배경)은 무엇인가? 2024년도 사업장 사회보험료 지원 사업 추진을 위한 전산프로그램 개발
# budget: 총 사업 예산(사업비)은 얼마인가? 명시 없음
# base_amount: 추정 가격/기초금액은 얼마인가? 명시 없음
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가? 명시 없음
# deadline: 입찰/제안서 제출 마감일시는 언제인가? 명시 없음
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가? 명시 없음
# submission_docs: 제출 서류 목록은 무엇인가? 요구사항 추적표, 인터페이스 설계서, 단위/통합테스트 결과서, 운영 및 사용자 매뉴얼
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가? 명시 없음
# duration: 사업 수행 기간은 얼마나 되는가? 명시 없음
# start_date: 사업 착수(시작) 예정일은 언제인가? 명시 없음
# end_date: 사업 종료(납품) 예정일은 언제인가? 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? 상용·일용근로자 사업장 사회보험료 소급 지원관리
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가? 중요정보 저장 및 보호를 위한 보안 관리 요구사항
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가? 명시 없음
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가? 명시 없음
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가? 명시 없음
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가? 명시 없음
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은? 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가? 명시 없음
# qa_method: 질의응답 제출 방법/양식은 무엇인가? 명시 없음
# briefing: 현장설명회가 있는가? 있다면 일정/장소는? 명시 없음
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가? 명시 없음
# consortium: 공동수급/하도급/컨소시엄 가능 여부는? 명시 없음
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가? 명시 없음
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가? 개인정보의 안전성 확보 조치 필요
# deliverables: 납품물(산출물) 목록은 무엇인가? 요구사항 추적표, 인터페이스 설계서, 단위/통합테스트 결과서, 운영 및 사용자 매뉴얼
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가? 명시 없음
# contact: 문의처(담당자/전화/이메일)는 무엇인가? 명시 없음
#
# === 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: SW사업 영향평가, SW사업정보 제출, 시스템 및 시스템 운영, 시스템 장비 구성, 테스트 요구사항, 인터페이스 기준 준수, 성능 일반, 품질관리 방안, 보안 계획 수립 및 실행
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 사업수행 보안 계획 수립 및 실행, 보안지침 준수 및 자료·문서 보안관리
# deliverables: 납품물은 사업완료보고서(웹 취약점 점검 결과보고서 포함)
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 국방과학연구소_대용량 자료전송시스템 고도화.pdf 분석 ===
# project_name: 대용량 자료전송시스템 고도화 사업
# agency: 국방과학연구소
# purpose: 대용량 자료 전송 시스템의 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 보안기능 강화, 취약점 제거
# requirements_must: 시큐어 코딩 가이드 준수, 시스템 장애 시 중단없이 운영 가능해야 함
# requirements_optional: 명시 없음
# eval_items: 기술 능력 평가 (비중 90%)
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: PM 포함 필수 인력 요구
# security: 보안 및 개인정보 보호 요구사항 준수
# deliverables: 명시 없음
# maintenance: 유지관리 계획 포함
# contact: 명시 없음
#
# === 그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.pdf 분석 ===
# project_name: GKL 그룹웨어 시스템 구축사업
# agency: 그랜드코리아레저(주)
# purpose: 사업 목적은 GKL 그룹웨어 시스템 구축이다.
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 그룹웨어 시스템의 구축 및 운영에 관한 요구사항
# requirements_must: ECR, BFR, PER, INR, DAR, TER, SER, QUR, PMR, PSR, COR 요구사항 포함
# requirements_optional: 명시 없음
# eval_items: 기술 능력 평가 및 가격 평가 구성
# eval_weights: 기술 능력 평가 90%, 가격 평가 10%
# price_eval: 가격 평가 방식은 제안가격 적정성
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 재무 상태, 신용도, 입찰 참가 제한 여부 확인 요구
# consortium: 명시 없음
# staffing: 명시 없음
# security: 소프트웨어 보안약점 진단 및 관련 지침 준수
# deliverables: 시스템 구성 요건 정의서, 시스템 구축 이행 결과서
# maintenance: 명시 없음
# contact: 이경남 차장, 02)6421-6466, Ign@7luck.com; 한수림 사원, 02)6421-6104, slhan23@7luck.com; 박동진 사원, 02)6421-6470, pdjworld@7luck.com; 정승순 대리, 02)6421-6661, jss1362@7luck.com
#
# === 나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.pdf 분석 ===
# project_name: 스마트 팹 서비스 활용체계 구축관련 설비온라인시스템 구축 사업
# agency: 나노종합기술원
# purpose: 스마트 팹 서비스 활용을 위한 설비 온라인 시스템 구축
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 설비 단위 인식 장치 설계, 설치 및 운영
# requirements_must: Carrier ID 인식 장치 설계 및 설치, 통신 및 데이터 수신 확인
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 시스템 접근 및 권한 관리 요구사항 포함
# deliverables: 기구 설계 문서, 작업 완료 보고서, 테스트 결과 보고서, 기능정의서, 화면정의서
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 제안서, 사업자등록증, 인감증명서, 사용인감계, 법인 등기부등본
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 파일 암호화 솔루션 도입 및 적용을 위한 전략 수립
# requirements_optional: 명시 없음
# eval_items: 기술 능력 평가, 사업 관리 및 지원 부문, 성능 및 품질
# eval_weights: 기술 능력 평가 70% (계획 및 기술 부문 30%, 사업 관리 및 지원 부문 40%)
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 보안 관련 요구사항, 개인정보보호법 준수
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.pdf 분석 ===
# project_name: 아·태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 온라인교육시스템 고도화 2차
# agency: 명시 없음
# purpose: 사이버범죄 역량강화를 위한 온라인 교육 시스템 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 홈페이지 및 온라인 교육 시스템 고도화 및 관리 기능 추가
# requirements_must: 반응형 웹 구축, 개인정보보호법 준수, OWASP 10대 보안 취약점 점검 및 제거
# requirements_optional: 명시 없음
# eval_items: 기술 및 기능
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 사업자는 소프트웨어 개발 보안 적용, 취약점 점검 실시
# deliverables: 홈페이지 관리자 매뉴얼, 교육훈련 관련 자료
# maintenance: 무상 하자보수 12개월, 장애 발생 시 4시간 이내 보수
# contact: 명시 없음
#
# === 대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.pdf 분석 ===
# project_name: 다층적 융합 학습경험 플랫폼(M ILE) 구축 제안요청서
# agency: 대전대학교
# purpose: 시스템 간 유기적 연동 및 확장 용이성 확보, 데이터 마이그레이션 방안 제시
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: DB 구조 설계, 데이터 마이그레이션, 시험 운영 및 품질 보증
# requirements_must: 프로그램의 신뢰성, 데이터 보안성과 무결성 보장, 웹 접근성 및 표준 준수
# requirements_optional: 명시 없음
# eval_items: 기술평가 및 가격평가
# eval_weights: 기술 평가(90%) 및 입찰 가격 평가(10%)
# price_eval: 협상에 의한 평가
# presentation: 제안 설명회 평가(PT)
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 필수 인력 요구사항 없음
# security: 개인정보 비밀 유출 방지 및 처벌 기준 명시
# deliverables: 문서 및 USB 제출, 개발된 소프트웨어의 소유권 대학 귀속
# maintenance: 최종 검수 완료일부터 최소 1년 무상 유지보수
# contact: 명시 없음
#
# === 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.pdf 분석 ===
# project_name: 기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고도화 사업
# agency: 대한상공회의소
# purpose: 재생에너지 지원센터 홈페이지의 기능 개선 및 시스템 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 방문 접수 (대한상공회의소 총무팀, 19층)
# submission_docs: 제안서 10부, 제안요약서 10부, 평가관련 증빙자료 1부, 발표용 자료 10부 (USB 제출)
# format_requirement: 제안서에 포함된 영문약어 해설 제시
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 기능 개선, 디자인 개선, 사용자 인터페이스(UI) 및 경험(UX) 개선
# requirements_must: 재생에너지 데이터 및 통계 시스템 구축, 웹 접근성 준수
# requirements_optional: 명시 없음
# eval_items: 기술능력 평가, 심사위원 점수 평균 산정
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 개인정보 보호 요구사항 준수
# deliverables: 최종 산출물(프로그램 개발 명세서, 소스 프로그램, 시스템 관리 자료 등)
# maintenance: 유지보수 기간 1년
# contact: 명시 없음
#
# === 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .pdf 분석 ===
# project_name: 전국체전 전산시스템 구축 사업
# agency: 대한장애인체육회
# purpose: 전국체전 관련 정보 시스템 구축 및 운영
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 제한경쟁입찰 후 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 참가신청 시스템, 대진추첨 시스템, 경기기록 시스템, 정보제공 시스템 등
# requirements_must: MS-SQL Server 사용, JBoss 6.4 및 Java/JSP 기반 시스템, 보안 요구사항 준수
# requirements_optional: 명시 없음
# eval_items: 기술평가 (90%), 가격평가 (10%)
# eval_weights: 기술 90%, 가격 10%
# price_eval: 가격 평가 방식 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 대기업 참여 제한
# consortium: 공동수급 가능
# staffing: 필수 인력 요건 없음
# security: 국가정보안보 관련 인증 요구
# deliverables: 시스템 및 관련 문서
# maintenance: 하자보수 12개월, 교육 및 기술 지원 제공
# contact: 명시 없음
#
# === 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가?
# agency: 발주 기관(수요기관)은 어디인가?
# purpose: 사업 목적(추진 배경)은 무엇인가?
# budget: 총 사업 예산(사업비)은 얼마인가?
# base_amount: 추정 가격/기초금액은 얼마인가?
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
# deadline: 입찰/제안서 제출 마감일시는 언제인가?
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가?
# submission_docs: 제출 서류 목록은 무엇인가?
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가?
# duration: 사업 수행 기간은 얼마나 되는가?
# start_date: 사업 착수(시작) 예정일은 언제인가?
# end_date: 사업 종료(납품) 예정일은 언제인가?
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가?
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가?
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가?
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가?
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가?
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가?
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은?
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가?
# qa_method: 질의응답 제출 방법/양식은 무엇인가?
# briefing: 현장설명회가 있는가? 있다면 일정/장소는?
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가?
# consortium: 공동수급/하도급/컨소시엄 가능 여부는?
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가?
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가?
# deliverables: 납품물(산출물) 목록은 무엇인가?
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가?
# contact: 문의처(담당자/전화/이메일)는 무엇인가?
#
# === 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.pdf 분석 ===
# project_name: 선랜 구축 및 RFID 보안 가이드라인 사업
# agency: 명시 없음
# purpose: 문화체육관광부 <공공저작물 등록·연계 활용>과 정보 연계 추진
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 정보시스템의 구축 운영 관련 "서비스 접근 및 전달", "플랫폼 및 기반구조", "요소기술" 및 "인터페이스 및 통합" 분야 포함
# requirements_must: 보안대책 수립 및 준수, 사용자 인증 전자서명 기반, 원격지 개발 보안 관리 대책
# requirements_optional: 명시 없음
# eval_items: 사업 이해도, 추진전략, 적용기술, 표준 프레임워크 적용, 개발 방법론
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 공동수급 가능
# staffing: PM 등 필수 인력 요건 명시 없음
# security: 보안/개인정보 보호 요구사항 포함
# deliverables: 하자보수 지원 방안 제시, 사업수행계획서
# maintenance: 하자담보책임 기간 12개월
# contact: 명시 없음
#
# === 부산관광공사_경영정보시스템 기능개선.pdf 분석 ===
# project_name: 경영정보시스템 기능개선 용역
# agency: 부산관광공사
# purpose: 경영정보시스템 기능 개선
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 2024년 00월 00일
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 2024년 00월 00일
# end_date: 명시 없음
# scope: 소프트웨어 개발 및 시스템 개선
# requirements_must: 데이터 표준화 및 공공 데이터 제공, 전자정부 표준프레임워크 준수
# requirements_optional: 명시 없음
# eval_items: 기술 및 가격
# eval_weights: 명시 없음
# price_eval: 협상 방식
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: SW사업 운영 및 유지보수, 관련 실적
# consortium: 공동수급 가능
# staffing: 필수 인력 요건 있음
# security: 정보 보호 및 기밀 유지 요구사항
# deliverables: 기능 점수 산정서 제출
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 안정화 운영 지원
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 납품확인서, 기술지원 확약서 제출
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: API 서비스 개발 및 관리
# requirements_must: 다양한 데이터 전송 프로토콜 지원, API 접근 제어, 보안 인증 프로토콜 지원 등
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 전산정보 보호대책 및 위반 시 징계 조치
# deliverables: API 관리 시스템 관련 문서
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.pdf 분석 ===
# project_name: 명시 없음
# agency: 아시아 물 위원회 사무국
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: e-발주시스템을 통한 온라인 제출
# submission_docs: 정성제안서, 정량제안서, 발표자료, 기타자료 각 1부, 공동수급협정서 1부
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 사업관리자(PM)가 직접 발표해야 함
# requirements_optional: 명시 없음
# eval_items: 제안사별 발표자료와 함께 질의응답 포함
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 있음, 일정은 제안서 제출 마감 후 별도 통보
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 수자원 분야 박사 또는 기술사 이상
# consortium: 가능
# staffing: 사업 책임자(PM) 및 분야별 전문가 요구
# security: 명시 없음
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.pdf 분석 ===
# project_name: 채팅상담 시스템 구축 사업
# agency: 명시 없음
# purpose: 채팅상담 시스템의 구축을 통한 고객 상담 효율성 증대
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 채팅상담 시스템 및 연계 기능 개발
# requirements_must: 기능 요구사항, 성능 요구사항, 보안 요구사항 등 47개 요구사항 충족
# requirements_optional: 명시 없음
# eval_items: 기술, 가격 등 평가 항목 구성
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 공동수급 가능
# staffing: 명시 없음
# security: 사용자 인증 관련 보안 요구사항 포함
# deliverables: 기능 개발 완료 후 납품물 제공
# maintenance: 유지보수 조건 명시 없음
# contact: 명시 없음
#
# === 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가?
# agency: 발주 기관(수요기관)은 어디인가?
# purpose: 사업 목적(추진 배경)은 무엇인가?
# budget: 총 사업 예산(사업비)은 얼마인가?
# base_amount: 추정 가격/기초금액은 얼마인가?
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
# deadline: 입찰/제안서 제출 마감일시는 언제인가?
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가?
# submission_docs: 제출 서류 목록은 무엇인가?
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가?
# duration: 사업 수행 기간은 얼마나 되는가?
# start_date: 사업 착수(시작) 예정일은 언제인가?
# end_date: 사업 종료(납품) 예정일은 언제인가?
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가?
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가?
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가?
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가?
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가?
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가?
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은?
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가?
# qa_method: 질의응답 제출 방법/양식은 무엇인가?
# briefing: 현장설명회가 있는가? 있다면 일정/장소는?
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가?
# consortium: 공동수급/하도급/컨소시엄 가능 여부는?
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가?
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가?
# deliverables: 납품물(산출물) 목록은 무엇인가?
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가?
# contact: 문의처(담당자/전화/이메일)는 무엇인가?
#
# === 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 명시 없음
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 명시 없음
# deliverables: 최종보고서, 서울 디지털성범죄 안심지원센터 업무 시스템 및 AI 기반 삭제지원시스템 소스코드 일체
# maintenance: 유상 유지관리 범위 및 세부내역 포함
# contact: 명시 없음
#
# === 서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .pdf 분석 ===
# project_name: 서울특별시교육청 지능정보화전략계획(ISP) 수립(2차)
# agency: 서울특별시교육청
# purpose: 지능정보화 전략계획 수립
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 일반경쟁
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 정보화전략계획 수립 관련 컨설팅
# requirements_must: 명시 없음
# requirements_optional: 명시 없음
# eval_items: 기술 평가, 가격 평가
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: PM, PL 필수
# security: 명시 없음
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 김경애 02-2282-8433 / 최병조 02-2282-8433
#
# === 세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.pdf 분석 ===
# project_name: 인사정보 전산시스템 구축 사업
# agency: 세종테크노파크
# purpose: 인사정보 시스템 구축 및 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 구축, 데이터 변환, 보안 관리, 품질 요구사항 등
# requirements_must: 성능 테스트, 보안 요구사항, 품질 관리, 프로젝트 관리 요구사항, 기술 이전 계획
# requirements_optional: 명시 없음
# eval_items: 유사 사업 실적, 기술자 보유현황
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 신뢰성, 사용성, 유지관리성 관련 요건 충족
# consortium: 가능
# staffing: 필수 인력 요건 명시 없음
# security: 정보자산의 기밀성과 무결성 확보 요구
# deliverables: 기술 이전에 필요한 산출물 작성
# maintenance: 유지보수 및 운영 지원 계획 포함
# contact: 명시 없음
#
# === 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.pdf 분석 ===
# project_name: 강릉어선안전국 상황관제시스템 구축 사업
# agency: 수협중앙회
# purpose: 시스템 구축을 통한 안전관제 기능 강화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 제한경쟁
# deadline: 명시 없음
# submission_method: 방문 제출
# submission_docs: 입찰참가신청서, 사업자등록증, 사용인감계, 법인인감증명서, 법인등기부등본, 정보통신공사업 등록증, 소프트웨어사업자 일반현황관리확인서 등
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 영상시스템, 음향시스템 구축
# requirements_must: 품질관리 계획 수립, 시스템 구축의 정확성, 설계서 작성 및 승인, 위험관리방안 등
# requirements_optional: 명시 없음
# eval_items: 경영상태, 유사용역분야 수행 실적, 기술인력 보유상태, 사업의 이해, 시스템 구축방안, 인테리어 구현방안, 기술 및 기능의 우수성, 성능시험 및 품질관리, 사업관리, 사업지원 등
# eval_weights: 정량적 평가(20점), 정성적 평가(60점)
# price_eval: 가격 제안서 제출
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 정보통신공사업 등록, 유사용역 실적 등
# consortium: 공동수급 가능
# staffing: 사업 책임자는 임원급, 실무책임자는 공사기간 중 100% 투입 가능해야 함
# security: 명시 없음
# deliverables: 시스템(H/W, S/W) 등 구축물 및 관리 방안
# maintenance: 하자 보수 및 유지관리 필요
# contact: 명시 없음
#
# === 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.pdf 분석 ===
# project_name: 플랫폼 재구축 사업계획서 및 제안요청서(RFP) 작성
# agency: 수협중앙회
# purpose: 정보시스템 구축을 위한 사업계획 수립 및 구체적인 요구사항 정의
# budget: 약 4,800만원 내외
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 사업 실적 증명서
# format_requirement: 명시 없음
# duration: 14개월
# start_date: 2024년 6월
# end_date: 2025년 10월
# scope: 정보시스템의 아키텍처 정의 및 최적 운영 환경 제시
# requirements_must: 보안 관련 요구사항, 정보시스템 기능에 대한 데이터 구조 설계
# requirements_optional: 명시 없음
# eval_items: 기술적 역량, 경험, 비용 효율성, 프로젝트 관리 능력 등
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 관련 실적 및 인증 보유
# consortium: 가능
# staffing: 필수 인력 요구사항 있음
# security: ISMS 요구사항 있음
# deliverables: 최종보고서, 요약본 및 원본파일
# maintenance: 유지보수 기간 및 범위 명시 없음
# contact: 명시 없음
#
# === 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.pdf 분석 ===
# project_name: 2024년 버스정보시스템 확대 구축 및 기능개선 사업
# agency: 명시 없음
# purpose: 버스정보안내단말기(BIT)를 확대 구축하여 버스정보 소외지역을 해소하고, 버스정보시스템(BIS)의 기능을 개선
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 버스정보안내단말기 130대 제작‧설치(신규 60, 교체 70) 및 버스정보시스템 프로그램 기능개선
# requirements_must: 네트워크 장비에 대한 보안 강화, 사용자 인증정보 보호 등
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 필수 인력 요건 없음
# security: 개발 시 보안 준수 사항 요구
# deliverables: 하자보수 방안 제시 요구
# maintenance: 운영 및 유지관리 방안 제시 요구
# contact: 명시 없음
#
# === 을지대학교_을지대학교 비교과시스템 개발.pdf 분석 ===
# project_name: 명시 없음
# agency: 을지대학교
# purpose: 사업 목적(추진 배경) 명시 없음
# budget: 비공개
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 하자보수기간 36개월, 개발 시스템 정상운영 위한 시스템 조건 및 보안대책 수립 등
# requirements_optional: 명시 없음
# eval_items: 기술 평가와 가격 평가 진행
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 용역수행 책임자(PM) 교체 불가
# security: 소프트웨어 개발보안 가이드 준수 요구
# deliverables: 유지관리수행계획서
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .pdf 분석 ===
# project_name: ERP 패키지 솔루션 및 성과관리시스템 개발 사업
# agency: 명시 없음
# purpose: 최신 ICT기술을 적용한 ERP 패키지 솔루션 및 성과관리시스템 개발
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 2024년 7월
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 2024년 7월 ~ 2025년 3월
# start_date: 2024년 7월
# end_date: 2025년 3월
# scope: ERP 패키지 구축, 성과관리시스템 개발, 전자서명시스템 및 모바일시스템 구축
# requirements_must: 기능 요구사항, 인터페이스 요구사항, 보안 요구사항 등 119개 요구사항
# requirements_optional: 명시 없음
# eval_items: 기술 평가, 가격 평가, 정량 평가, 정성 평가
# eval_weights: 기술 평가 80점, 가격 평가 20점
# price_eval: 협상에 의한 평가 방식
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 참가 자격 요건 명시 없음
# consortium: 가능
# staffing: 필수 인력 요건 명시 없음
# security: 보안 요구사항 포함
# deliverables: 명시 없음
# maintenance: 하자보수 12개월, 교육 및 운영 지원 계획 포함
# contact: 명시 없음
#
# === 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가? 명시 없음
# agency: 발주 기관(수요기관)은 어디인가? 명시 없음
# purpose: 사업 목적(추진 배경)은 무엇인가? 장애대응 대책 제시
# budget: 총 사업 예산(사업비)은 얼마인가? 명시 없음
# base_amount: 추정 가격/기초금액은 얼마인가? 명시 없음
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가? 제한경쟁입찰/협상에 의한 계약
# deadline: 입찰/제안서 제출 마감일시는 언제인가? 명시 없음
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가? 명시 없음
# submission_docs: 제출 서류 목록은 무엇인가? 명시 없음
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가? 명시 없음
# duration: 사업 수행 기간은 얼마나 되는가? 명시 없음
# start_date: 사업 착수(시작) 예정일은 언제인가? 명시 없음
# end_date: 사업 종료(납품) 예정일은 언제인가? 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? 고증․검수, 시연․보완 포함
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가? 장애대응 대책
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가? 명시 없음
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가? 기술평가(90%) / 가격평가(10%)
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가? 기술(90%) / 가격(10%)
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가? 가격평가
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은? 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가? 명시 없음
# qa_method: 질의응답 제출 방법/양식은 무엇인가? 명시 없음
# briefing: 현장설명회가 있는가? 있다면 일정/장소는? 명시 없음
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가? 최근 3년간 유사사업 수행실적
# consortium: 공동수급/하도급/컨소시엄 가능 여부는? 명시 없음
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가? 사업관리자(PM) 이력사항 제출
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가? 명시 없음
# deliverables: 납품물(산출물) 목록은 무엇인가? 명시 없음
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가? 명시 없음
# contact: 문의처(담당자/전화/이메일)는 무엇인가? 명시 없음
#
# === 인천광역시_도시계획위원회 통합관리시스템 구축용역.pdf 분석 ===
# project_name: 도시계획위원회 통합관리시스템 구축 용역
# agency: 인천광역시
# purpose: 웹 사이트 구축을 통한 응답속도 향상 및 장애인 등 소외계층 서비스 이용 고려
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 2024년 월 일
# submission_method: 방문 제출
# submission_docs: 정량적 제안서 2부, 정성적 제안서 및 제안발표자료 10부, 발표용 파일 USB, 입찰참가서류(가격제안서 포함)
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 장비 구성, 오픈소스 SW 도입, 웹 서비스 연계 및 통합
# requirements_must: HTML, Java, J2EE 1.4 이상 지원, 웹 서비스(SOAP, WSDL 등) 지원, 보안 기능 준수
# requirements_optional: 선택 요구사항(우대/가점) 없음
# eval_items: 기술 능력 평가(정성적), 경영상태 평가, 가격 평가
# eval_weights: 기술 평가 90점, 가격 평가 10점
# price_eval: 협상에 의한 평가
# presentation: 제안 발표(PT) 있음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 없는 것으로 보임
# eligibility: 최근 3년간 도시계획정보 및 위원회 운영 관련 시스템 구축 실적 필요
# consortium: 공동수급 가능
# staffing: 명시 없음
# security: 국가정보보안기본지침 준수
# deliverables: 시스템 구축 및 관련 문서
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.pdf 분석 ===
# project_name: 인천일자리플랫폼 정보시스템 구축 ISP 수립
# agency: 명시 없음
# purpose: 구인기업‧구직자 일자리 생애주기 맞춤형 정보시스템 구축 및 운영
# budget: 100,000천원 (1억원)
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약 (제한경쟁입찰)
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 계약일로부터 3개월
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 일자리 플랫폼 구축 및 운영
# requirements_must: 기밀성과 무결성을 확보하기 위한 요구사항, DB 구축 및 데이터 구조 설계, 보안 요구사항 등
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 정보 자산의 기밀성 및 무결성을 확보하기 위한 요구사항
# deliverables: 현황분석서, 목표모델설계서 등
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.pdf 분석 ===
# project_name: 2024년 광주문화예술통합플랫폼 시스템 유지 및 보수 용역
# agency: 광주문화재단
# purpose: 광주문화예술 통합 플랫폼 유지 및 보수
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 방문 제출
# submission_docs: 입찰참가 공문, 제안서 및 요약서, 가격산출내역서, 평가관련 증명서류
# format_requirement: 제안서 및 발표자료 원본 1부 및 평가본 9부, PDF 파일 각 1본, USB에 저장 제출
# duration: 8.5개월
# start_date: 계약일로부터
# end_date: 계약일로부터 8.5개월 후
# scope: 플랫폼 디자인 및 운영 시스템 개편, 정보 제공 수준 향상
# requirements_must: 저작권 준수, 보안 관리 대책 포함, 정보 시스템 관련 법령 및 지침 준수
# requirements_optional: 명시 없음
# eval_items: 기술, 가격, 사업관리 방안
# eval_weights: 기술 60점, 가격 20점, 사업관리 방안 20점
# ...
# scope: 소프트웨어, 하드웨어 및 통신 인터페이스 관련 요구사항 기술
# requirements_must: 데이터 설계, 성능 테스트, 보안 요구사항, 프로젝트 관리 및 지원 요구사항
# requirements_optional: 소프트웨어 관련 인증 획득 시 가점
# eval_items: 사업 수행 실적, 투입 인력 경험
# eval_weights: 명시 없음
# price_eval: 협상 방식
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 공동수급 가능
# staffing: 필수 인력 요건 명시 없음
# security: 보안 관리 지침 준수 요구
# deliverables: 산출정보 정리 및 보고서 제출
# maintenance: 유지보수 관련 요구사항 명시 없음
# contact: 명시 없음
#
# === 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.pdf 분석 ===
# project_name: 기초학문자료센터 DB 구축 사업
# agency: 한국연구재단
# purpose: 학술활동결과물 DB 구축 및 서비스
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 주요사업실적 증명서, 용역이행 실적 증명서 등
# format_requirement: 제안서 내용은 명확한 용어를 사용해야 하며, 계량화 가능한 것은 계량화해야 함
# duration: 1년 (2024.4.1.~2025.3.31.)
# start_date: 2024-04-01
# end_date: 2025-03-31
# scope: 학술활동결과물 DB 구축 및 관련 서비스 운영
# requirements_must: 보안 요구사항, 기술지원 요구사항, 표준화 요구사항, 사업관리 요구사항 등
# requirements_optional: 명시 없음
# eval_items: 기술 및 가격 평가
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 허용
# staffing: PM(프로젝트 매니저) 필수
# security: 정보 보안 요구사항 포함
# deliverables: 구축된 DB 및 서비스 시스템
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 20억 미만
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 제안서 본문 내용은 200페이지(100장) 이내
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 필수 보안 요구사항 및 기능 요구사항 포함
# requirements_optional: 명시 없음
# eval_items: 기술 평가 및 가격 평가
# eval_weights: 명시 없음
# price_eval: 가격 평가 방식은 제안가격
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 공동수급 가능
# staffing: 필수 인력 요건이 명시되지 않음
# security: 보안 요구사항 및 암호화 제품 사용 필요
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 디지털혁신본부 데이터정보센터 학술데이터분석팀 한민아(☎: 042-869-6672, minahhan@nrf.re.kr) / 경영지원본부 재정기금실 운영지원팀 이현우(☎: 042-869-6232, lhw0203@nrf.re.kr)
#
# === 한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.pdf 분석 ===
# project_name: 한국원자력연구원 선량평가시스템 고도화 사업
# agency: 한국원자력연구원
# purpose: 선량평가시스템의 기능 고도화 및 안정성 향상
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 일반경쟁
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 사업수행계획서, 청렴계약서약서, 저작권 확인서 등
# format_requirement: 명시 없음
# duration: 6개월
# start_date: 계약 체결일
# end_date: 계약 체결일로부터 6개월 후
# scope: 기능 점수 기반으로 시스템 개발 및 개선
# requirements_must: 포트란 및 웹 시스템 평가장기 개선, 액체 선량평가 추가, 데이터 안정성 보장
# requirements_optional: 명시 없음
# eval_items: 기술 및 가격을 포함한 종합평가
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: 핵심인력 요구
# security: 보안서약서 제출 및 보안조치 이행
# deliverables: 기술이전 계획서, 매뉴얼 작성, 보고서 등
# maintenance: 하자보증, 유지보수 조건 명시
# contact: 명시 없음
#
# === 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 보안 요구사항(SER), 품질 요구사항(QUR), 제약사항(COR), 프로젝트 관리 요구사항(PMR), 프로젝트 지원 요구사항(PSR)
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 보안 사항에 대한 지침 및 절차 요구
# deliverables: 산출물 및 작업 단위별 산출물 제시
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.pdf 분석 ===
# project_name: 전기안전 관제시스템 보안 모듈 개발
# agency: 디지털점검부 디지털전환기획팀
# purpose: 보안 모듈 개발 및 시스템 안정화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 2024. 11.
# end_date: 명시 없음
# scope: KCMVP 통신 데이터 추가 및 보안 모듈 기능 개선
# requirements_must: 공사 TLS 규격 준수, 사용자 인증 전자서명 기반
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능, 구성원 지분율 10% 이상 요구
# staffing: 명시 없음
# security: 전자서명 요구, 보안 규정 준수
# deliverables: 구축 계획서/결과서, 인터페이스 설계서 등
# maintenance: 하자보수 기간 1년
# contact: 김지영, 063-716-2787
#
# === 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.pdf 분석 ===
# project_name: IP-NAVI 해외지식재산센터 사업관리 시스템 기능개선
# agency: 한국지식재산보호원
# purpose: 사용자에 따른 개별 관리 기능 추가, 관리자 시스템 실적 통합관리 기능 추가, 시스템 회원 대상 1:1 온라인 상담 서비스 구축
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 2024년 월 일
# submission_method: 명시 없음
# submission_docs: 동의서, 확인서, 보안각서, 사용인감계, 제안서 및 제안사 일반사항, 사업자등록증 사본, 법인등기부 등본, 법인 인감증명서, (사용인감 사용 시) 사용인감계, 국세 및 지방세 완납증명서, 이행(입찰)보증보험증권
# format_requirement: 명시 없음
# duration: 3개월
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 기능 개선
# requirements_must: PKI기반 인증서 방식, 비밀번호 강화(8자리 이상, 특수문자 포함), 관리자 접근 이중 통제 의무, 민감정보 수집 금지, 국가정보원 승인 암호 모듈 사용 등
# requirements_optional: 명시 없음
# eval_items: 기술 평가 항목, 가격 평가 항목
# eval_weights: 기술평가 90점, 가격평가 10점
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: ISMS 인증 요구사항, 보안 취약점 점검 필수
# deliverables: 명시 없음
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.pdf 분석 ===
# project_name: 운행정보기록 자동분석시스템(TORAS) 구축 사업
# agency: 명시 없음
# purpose: 운행정보기록 데이터를 수령 및 분석 할 수 있는 시스템 구축
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 제안서, 사업수행계획서, 기술지원확약서, S/W 라이선스, 보안정책서, 설치 및 구성 결과서
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 차종별 운행기록 로그 자동 분석, 데이터 수집 및 해석, 고속열차 데이터 해석
# requirements_must: 데이터 수집, 열차 운행 정보 활용, 동력차 데이터 해석 모듈 작성, 시스템 운영 요구사항 준수
# requirements_optional: 관련 기술 지원 및 정보 제공
# eval_items: 기술 및 기능, 성능 및 품질, 프로젝트 관리
# eval_weights: 기술 및 기능 25%, 성능 및 품질 12%, 프로젝트 관리 16%
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: 필수 인력 요건 명시 없음
# security: 보안 요구사항 관련 명시 없음
# deliverables: 프로세스 흐름도, 인터페이스 정의서, 테이블 정의서, 모듈 규격서, 시스템 매뉴얼, 구축 단계별 산출물
# maintenance: 기술지원 및 이전 관련 비용 제안사 부담
# contact: 명시 없음
#
# === 한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).pdf 분석 ===
# project_name: 모바일오피스 시스템 고도화
# agency: 한국철도공사
# purpose: 모바일 업무지원 확대 및 서비스 연속성 확보
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 2024. 8.
# submission_method: 온라인
# submission_docs: 명시 없음
# format_requirement: PDF 파일로 제출, 암호화 파일 및 압축파일 제출 불가
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 시스템 구축 및 개발, 운영비용, 사용자 지원 방안 제시
# requirements_must: 시스템 성능 보증, 안정적 운영지원 및 사용자 지원 방안, 보안 요구사항 준수
# requirements_optional: 명시 없음
# eval_items: 기술, 가격
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: PM, 보안담당 필수
# security: 사용자 계정 접근 관리, 로그 기록 및 확인 필요
# deliverables: 설치확인서, 성능시험계획서, 성능시험시나리오, 성능시험결과서, 보안 요구사항 정의서
# maintenance: 하자보수 활동 포함, 장애 발생 시 기준에 따른 조치
# contact: 이규범(042-615-5730), 이정민(042-615-5733), 조서연(042-615-5746)
#
# === 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.pdf 분석 ===
# project_name: 정보시스템 구축 사업
# agency: 발주 기관(수요기관) 명시 없음
# purpose: 정보시스템 구축을 위한 사업 진행 및 고도화
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 제안요청서, 사업수행계획서, 보안서약서 등
# format_requirement: 제안서 양식 및 제출 형식 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 정보시스템 구축 범위 및 데이터 관리, 보안, 품질 관리 등
# requirements_must: 컨설팅 요구사항(20), 데이터 요구사항(3), 보안 요구사항(3), 품질관리 요구사항(2), 제약사항(3), 프로젝트 관리 요구사항(9), 프로젝트 지원 요구사항(2)
# requirements_optional: 선택 요구사항 명시 없음
# eval_items: 기술 및 가격 평가
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 제안 발표 여부 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간 명시 없음
# qa_method: 질의응답 제출 방법/양식 명시 없음
# briefing: 현장설명회 여부 명시 없음
# eligibility: 제안사 소속 PM은 최근 5년 이내 정보화전략 컨설팅 경험이 있어야 함
# consortium: 공동수급/하도급/컨소시엄 가능 여부 명시 없음
# staffing: PM은 사업수행 기간 동안 100% 상주해야 함
# security: 정보자산의 기밀성·무결성을 위한 보안 요구사항 존재
# deliverables: 과업별 산출물 목록 존재
# maintenance: 유지보수 조건 명시 없음
# contact: 문의처 명시 없음
#
# === 한국한의학연구원_통합정보시스템 고도화 용역.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 입찰참가신청서, 법인인감증명서, 사업자등록증 사본, 법인등기부등본, 국세·지방세·건강보험료 완납증명서
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? (구체적 내용 불명)
# requirements_must: 네트워크 접근통제, 네트워크 자료유출방지, 백도어 방지 기술 적용
# requirements_optional: 명시 없음
# eval_items: 기술 요구사항, 성능 요구사항, 인터페이스 요구사항, 데이터 요구사항, 테스트 요구사항, 보안 요구사항, 품질 요구사항
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 정보 자산의 기밀성 및 무결성 확보, 사용자 인증을 위한 전자서명 기반
# deliverables: 명시 없음
# maintenance: 유지관리확약서 포함
# contact: 재무회계팀 이정호 042-868-9366, 총무전산팀 김유성 042-866-9265
#
# === 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 명시 없음
# requirements_must: 보안 요구사항, 기술지원, 교육지원 및 하자보수, 정기 및 수시보고 요구사항
# requirements_optional: 명시 없음
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 민형사상 책임, 보안교육 이수, 자료 삭제 및 반납과 관련된 요구사항
# deliverables: 명시 없음
# maintenance: 하자보수 기간 1년간
# contact: 명시 없음
#
# === 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.pdf 분석 ===
# project_name: 사업(용역)명은 무엇인가? 명시 없음
# agency: 발주 기관(수요기관)은 어디인가? 명시 없음
# purpose: 사업 목적(추진 배경)은 무엇인가? 권한 관리 및 데이터 품질 관리
# budget: 총 사업 예산(사업비)은 얼마인가? 명시 없음
# base_amount: 추정 가격/기초금액은 얼마인가? 명시 없음
# contract_type: 계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가? 명시 없음
# deadline: 입찰/제안서 제출 마감일시는 언제인가? 명시 없음
# submission_method: 제출 장소 또는 제출 방법(온라인/방문/우편)은 무엇인가? 명시 없음
# submission_docs: 제출 서류 목록은 무엇인가? 제안서 10부, S/W 관련 서비스사업 신고 확인서, 사업자등록증 사본
# format_requirement: 제안서(기술/가격) 제출 파일 형식이나 양식은 무엇인가? MS 워드, MS 파워포인트, 한글, PDF 등 Windows 운영체제에서 실행 가능한 형식
# duration: 사업 수행 기간은 얼마나 되는가? 명시 없음
# start_date: 사업 착수(시작) 예정일은 언제인가? 명시 없음
# end_date: 사업 종료(납품) 예정일은 언제인가? 명시 없음
# scope: 제안 요청 범위(Scope/업무 범위)는 무엇인가? 권한 관리 및 데이터 품질 관리
# requirements_must: 필수 요구사항(기능/성능/보안 등)은 무엇인가? 데이터 품질 관리 전담자, 보안 준수 사항
# requirements_optional: 선택 요구사항(우대/가점)에는 무엇이 있는가? 명시 없음
# eval_items: 평가 항목(기술/가격 등) 구성은 어떻게 되는가? 정량적 평가, 정성적 평가
# eval_weights: 평가 배점(점수) 비율은 어떻게 되는가? 명시 없음
# price_eval: 가격 평가 방식(최저가/협상 등)은 무엇인가? 명시 없음
# presentation: 제안 발표(PT/발표평가)가 있는가? 있다면 일정은? 명시 없음
# qa_period: 질의응답(Q&A) 접수 기간은 언제인가? 명시 없음
# qa_method: 질의응답 제출 방법/양식은 무엇인가? 명시 없음
# briefing: 현장설명회가 있는가? 있다면 일정/장소는? 명시 없음
# eligibility: 참가 자격 요건(면허/실적/인증/등급)은 무엇인가? 명시 없음
# consortium: 공동수급/하도급/컨소시엄 가능 여부는? 명시 없음
# staffing: 필수 인력 요건(PM/보안담당 등)이 있는가? 데이터 품질 관리 전담자
# security: 보안/개인정보 요구사항(인증, ISMS 등)은 무엇인가? 보안 준수 사항, 시스템 무중단 운영
# deliverables: 납품물(산출물) 목록은 무엇인가? 명시 없음
# maintenance: 유지보수/운영 조건(기간/범위)은 무엇인가? 하자담보 책임기간 12개월
# contact: 문의처(담당자/전화/이메일)는 무엇인가? 명시 없음
#
# === 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf 분석 ===
# project_name: 명시 없음
# agency: 명시 없음
# purpose: 명시 없음
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 제안 요청 범위에는 다국어 지원, 데이터 Import/Export 기능, UI 컴포넌트 및 데이터셋 간 양방향 바인딩, 테스트 자동화 도구, 사용자 맞춤형 포털 시스템 구축 등이 포함됨
# requirements_must: GS 인증 획득 제품, 정적 분석, 테스트 실행, 성능 테스트 등 다양한 기능 제공
# requirements_optional: 최근 3년간 소프트웨어 관련 인증, 정부·지자체 수상경력 등
# eval_items: 명시 없음
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 명시 없음
# security: 개인정보 영향 평가 및 보안 측정을 반드시 수행해야 함
# deliverables: 설치 결과서, 기술지원 확약서, 프로그램 목록, 프로그램명세서, 사용자 매뉴얼 등
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 기초과학연구원_2025년도 중이온가속기용 극저온시스템 운전 용역.pdf 분석 ===
# project_name: 중이온가속기용 극저온시스템 운전 용역
# agency: 중이온가속기연구소
# purpose: 극저온시스템의 안전하고 안정적인 운영을 위한 운전 용역 제공
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 명시 없음
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 품질계획서, 문서제출계획서, 제작공정 및 검사계획서, 작업절차서, 불일치사항 보고서 등
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 2024년 10월 30일
# end_date: 명시 없음
# scope: 극저온시스템의 모니터링 및 제어, 주요 수치 기록 및 분석, 운전 경험 문서화
# requirements_must: 계약 요건 충족을 위한 품질 목표 및 절차서, 조직 구성, 품질검사 및 불일치사항 관리
# requirements_optional: 명시 없음
# eval_items: 품질검사 업무 이행 관리, 계약 요구사항 준수 여부
# eval_weights: 명시 없음
# price_eval: 명시 없음
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 명시 없음
# staffing: 질적인 교육 수행 및 평가를 위한 인력 관리 계획 필요
# security: 보안 요구사항 명시 없음
# deliverables: 품질 관련 문서 및 기록 유지 관리, 계약종결 전에 제출
# maintenance: 명시 없음
# contact: 명시 없음
#
# === 서울시립대학교_[사전공개] 학업성취도 다차원 종단분석 통합시스템 1차.pdf 분석 ===
# project_name: 학업성취도 다차원 종단분석 통합시스템 1차 고도화
# agency: 명시 없음
# purpose: 명시 없음
# budget: 20억원 미만
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 초기자료 구축 및 데이터 변환, 도입장비 성능 테스트, 정보 자산 보안 요구사항 등
# requirements_must: 보안, 시스템 관리, 품질 요구사항, 프로젝트 관리 등
# requirements_optional: 신규 고용 우수기업, 청년 고용 우수기업 등
# eval_items: 기술 및 기능, 성능 및 품질, 프로젝트 관리 등
# eval_weights: 명시 없음
# price_eval: 협상에 의한 가격 평가
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 공동수급 가능
# staffing: 필수 인력 요건 명시 없음
# security: 개인정보 보호법 준수 및 보안 요구사항 명시
# deliverables: 하자보수 및 유지관리 포함, 명시 없음
# maintenance: 하자보증 1년(발주기관 규정 및 기준에 우선 적용)
# contact: 명시 없음
#
# === 서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf 분석 ===
# project_name: 2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 구축 용역
# agency: 서울특별시
# purpose: 지도정보 플랫폼의 고도화 및 전문 활용 연계를 통해 서울시민에게 제공되는 행정정보 서비스를 개선하고자 함
# budget: 명시 없음
# base_amount: 명시 없음
# contract_type: 협상에 의한 계약
# deadline: 명시 없음
# submission_method: 명시 없음
# submission_docs: 명시 없음
# format_requirement: 명시 없음
# duration: 명시 없음
# start_date: 명시 없음
# end_date: 명시 없음
# scope: 지도정보 플랫폼의 기능 개선, OpenAPI 구조 개선 및 도시생활지도 파일 형태 확대
# requirements_must: 개인정보 보호를 위한 기술적 보호조치, 웹 접근성 및 웹표준 준수
# requirements_optional: 명시 없음
# eval_items: 기술능력 평가, 입찰가격 평가
# eval_weights: 명시 없음
# price_eval: 최저입찰가격에 따른 평가
# presentation: 명시 없음
# qa_period: 명시 없음
# qa_method: 명시 없음
# briefing: 명시 없음
# eligibility: 명시 없음
# consortium: 가능
# staffing: PM 및 보안담당 인력 요구
# security: 개인정보 처리 위탁 및 보호 조치 요구
# deliverables: DB 품질관리 계획 포함
# maintenance: 명시 없음
# contact: 명시 없음
# 전체 분석 완료!
