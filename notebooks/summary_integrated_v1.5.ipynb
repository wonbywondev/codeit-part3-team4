# %% [markdown]
# ### 사전 준비 사항
#
# #### (1) uv add (터미널)
#
# ```bash
# uv add pdfplumber sentence-transformers faiss-cpu numpy torch python-dotenv openai
# ```
#
# #### (2) .env 파일 세팅
# ```bash
# OPENAI_API_KEY = ""
# HF_TOKEN = ""
# ```
#
# #### (3) pdf 파일 세팅
# pdf 파일 100개를 `data/raw/files` 에 위치합니다.
# 성능 개선을 위한 테스트에서는 전체를 대상으로 인덱싱하지 않고, 5개 인덱싱 코드 실행 권장(주석 해제)

# %%
from preprocess.pp_basic import docs, BASE_DIR, EVAL_DIR, GOLD_EVIDENCE_CSV, GOLD_FIELDS_JSONL, RAW_DIR
import preprocess.pp_v5 as pp
from preprocess.pp_v5 import pp_version

# %%
import os
from pathlib import Path
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()
MODEL = "gpt-4o-mini"

# %%
# 임베딩 및 인덱스 만들기
# 한국어 임베딩 모델
embed_model_name = "nlpai-lab/KoE5"
embed_model = SentenceTransformer(embed_model_name)

# %%
# 질문 리스트 (key, 질문)
queries = [
    ("project_name", "사업(용역)명은 무엇인가?"),
    ("agency", "발주 기관(수요기관)은 어디인가?"),
    ("purpose", "사업 목적(추진 배경)은 무엇인가?"),
    ("budget", "총 사업 예산(사업비)은 얼마인가?"),
    ("contract_type", "계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?"),
    ("deadline", "입찰/제안서 제출 마감일시는 언제인가?"),
    ("duration", "사업 수행 기간은 얼마나 되는가?"),
    ("requirements_must", "필수 요구사항(기능/성능/보안 등)은 무엇인가?"),
    ("eval_items", "평가 항목(기술/가격 등) 구성은 어떻게 되는가?"),
    ("price_eval", "가격 평가 방식(최저가/협상 등)은 무엇인가?"),
    ("eligibility", "참가 자격 요건(면허/실적/인증/등급)은 무엇인가?"),
]

def build_query_prompt(queries):
    return "\n".join(
        f"{i}. {q}"
        for i, (_, q) in enumerate(queries, start=1)
    )

# %%
# RFP 분석용 프롬프트
RFP_PROMPT = """
너는 정부·공공기관 제안요청서(RFP)를 분석하는 전문가다.
아래 컨텍스트는 하나의 정부 RFP 문서에서 추출된 내용이다.

[분석 규칙]
- 추측 금지, 문서에 명시된 내용만 사용
- 문서에 없으면 반드시 "NOT_FOUND"
- **출력은 질문 개수와 동일한 줄 수**
- **각 줄에는 답변 텍스트만 작성**
- 번호, 질문 문장, '답:', 기호, 설명을 절대 포함하지 말 것

[질문 목록]
{questions}

[컨텍스트]
{context}

질문 순서대로 답변만 한 줄씩 출력하라.
"""

# %% [markdown]
# ### 배치 질문 응답
#
# 질문 리스트를 한 번에 임베딩/검색하고, top-k 청크를 합쳐 LLM에 넣어 답변을 생성합니다.
# `return_indices=True`일 때는 검색된 청크 인덱스도 반환합니다.

# %%
def answer_batch(index, model, chunks, queries, top_k: int = 15, return_indices: bool = False) -> list[str]:
    q_list = [q for _, q in queries]
    q_emb = model.encode(q_list)
    q_mean = q_emb.mean(axis=0, keepdims=True)
    _, I = index.search(q_mean.astype("float32"), top_k)
    context = "".join(chunks[i] for i in I[0])

    prompt = RFP_PROMPT.format(questions=build_query_prompt(queries), context=context)
    resp = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "RFP 전문 분석가. 형식 엄수."},
            {"role": "user", "content": prompt},
        ],
        max_tokens=2000,
    )
    text = (resp.choices[0].message.content or "").strip()
    answers = [line.strip() for line in text.splitlines() if line.strip()]
    if return_indices:
        return answers, [int(i) for i in I[0]]
    return answers

# %% [markdown]
# ## RAG 평가 (docs_api_summary 베이스라인 그대로 + gold로 점수 측정)

# %%
import json
import pandas as pd
from tqdm.auto import tqdm
from rapidfuzz import fuzz

# %%
# 평가 데이터 경로
print("BASE_DIR:", BASE_DIR)
print("RAW_DIR:", RAW_DIR, "exists:", RAW_DIR.exists())
print("EVAL_DIR:", EVAL_DIR, "exists:", EVAL_DIR.exists())
# Out:
# BASE_DIR: /Users/won/dev/00_codeit/0_mission/200_DL_RAG
# RAW_DIR: /Users/won/dev/00_codeit/0_mission/200_DL_RAG/data/raw/files exists: True
# EVAL_DIR: /Users/won/dev/00_codeit/0_mission/200_DL_RAG/data/raw/eval exists: True

# %% [markdown]
# ### 평가용 정답 데이터 불러오기

# %%
def load_gold_fields_jsonl(path: Path) -> pd.DataFrame:
    rows = []
    with path.open("r", encoding="utf-8", errors="replace") as f:
        for line in f:
            if not line.strip():
                continue
            rows.append(json.loads(line))
    out = []
    for r in rows:
        iid = r["instance_id"]
        doc_id = r.get("doc_id", "")
        fields = r.get("fields", {}) or {}
        for k, v in fields.items():
            out.append({"instance_id": iid, "doc_id": doc_id, "field": k, "gold": v})
    return pd.DataFrame(out)


gold_evidence_df = pd.read_csv(GOLD_EVIDENCE_CSV)
gold_fields_df = load_gold_fields_jsonl(GOLD_FIELDS_JSONL)

display(gold_evidence_df.head(3))
display(gold_fields_df.head(3))
# Out:
#   instance_id                                        doc_id  page_start  \
# 0      G_Q001  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf         4.0
# 1      G_Q002  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf         1.0
# 2      G_Q003  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf         3.0
#
#    page_end anchor_text
# 0       4.0        사업개요
# 1       1.0    벤처기업확인기관
# 2       3.0   추진배경 및 방향
#   instance_id                                        doc_id         field  \
# 0      G_Q001  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf  project_name
# 1      G_Q002  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf        agency
# 2      G_Q003  (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf       purpose
#
#                                                 gold
# 0                                 벤처확인종합관리시스템 기능 고도화
# 1                                           벤처기업확인기관
# 2  [복수의결권주식, 스톡옵션(주식매수선택권), 성과조건부주식교부계약(RS) 등의 기능...

# %% [markdown]
# ### Retrieval 평가(Anchor 기반)
#
# `gold_evidence.csv`의 `anchor_text`가 top-k 청크 안에 포함되는지로 retrieval을 평가합니다.
# - `recall@k`: top-k 안에서 anchor가 한 번이라도 나오면 1
# - `mrr@k`: 첫 hit의 역순위(없으면 0)

# %%
def build_gold_anchor_map(df: pd.DataFrame) -> dict[str, list[str]]:
    m: dict[str, list[str]] = {}
    for _, r in df.iterrows():
        iid = str(r["instance_id"])
        anchor = str(r.get("anchor_text", "") or "").strip()
        if anchor:
            m.setdefault(iid, []).append(anchor)
    return m

GOLD_ANCHOR = build_gold_anchor_map(gold_evidence_df)


def eval_retrieval_by_anchor(chunks: list[str], idxs: list[int], anchors: list[str]) -> dict[str, float]:
    hit_rank = None
    for rank, ci in enumerate(idxs, start=1):
        if 0 <= int(ci) < len(chunks):
            c = chunks[int(ci)]
            if any(a in c for a in anchors):
                hit_rank = rank
                break
    return {"recall": 1.0 if hit_rank else 0.0, "mrr": (1.0 / hit_rank) if hit_rank else 0.0}

# %%
# 베이스라인 질문 리스트 (docs_api_summary의 queries 사용)
# queries 변수는 기존 노트북 셀에 정의되어 있어야 합니다.
BASELINE_QUERIES = queries
BASELINE_QUESTIONS = dict(BASELINE_QUERIES)

# %% [markdown]
# ### 정답 유사도 평가 함수

# %%
def eval_gen(pred: str, gold: str | None, threshold: int = 80) -> dict[str, float]:
    pred = (pred or "").strip()
    fill = 1.0 if pred and pred.lower() not in {"", "없음"} else 0.0
    if gold is None or str(gold).strip() == "":
        return {"fill": fill, "match": np.nan, "sim": np.nan}
    gold = str(gold).strip()
    sim = fuzz.token_set_ratio(pred, gold)
    return {"fill": fill, "match": 1.0 if sim >= threshold else 0.0, "sim": float(sim)}

# %%
SIM_THRESHOLD = 80
TOP_K = 15

# %%
# docs_api_summary에서 만든 docs 리스트 사용
# docs = get_pdf_paths(RAW_DIR) 가 이미 실행되어 있어야 합니다.
DOC_PATHS = docs
for p in DOC_PATHS:
    print(" -", p.name)
# Out:
#  - (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf
#  - (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원시.pdf
#  - (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.pdf
#  - (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf
#  - 2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf
#  - BioIN_의료기기산업 종합정보시스템(정보관리기관) 기능개선 사업(2차).pdf
#  - KOICA 전자조달_[긴급] [지문] [국제] 우즈베키스탄 열린 의정활동 상하원 .pdf
#  - 경기도 안양시_호계체육관 배드민턴장 및 탁구장 예약시스템 구축 용역.pdf
#  - 경기도 평택시_2024년도 평택시 버스정보시스템(BIS) 구축사업.pdf
#  - 경기도사회서비스원_2024년 통합사회정보시스템 운영지원.pdf
#  - 경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).pdf
#  - 경희대학교_[입찰공고] 산학협력단 정보시스템 운영 용역업체 선정.pdf
#  - 고양도시관리공사_관산근린공원 다목적구장 홈페이지 및 회원 통합운영.pdf
#  - 광주과학기술원_실시간통합연구비관리시스템(RCMS)  연계 모듈 변경 사업.pdf
#  - 광주과학기술원_학사시스템 기능개선 사업.pdf
#  - 국가과학기술지식정보서비스_통합정보시스템 고도화 용역.pdf
#  - 국가철도공단_철도인프라 디지털트윈 정보화전략계획(ISP) 수립 용역(변.pdf
#  - 국립인천해양박물관_국립인천해양박물관 해양자료관리시스템 구축 용.pdf
#  - 국립중앙의료원_(긴급)「2024년도 차세대 응급의료 상황관리시스템 구축.pdf
#  - 국민연금공단_2024년 이러닝시스템 운영 용역.pdf
#  - 국민연금공단_사업장 사회보험료 지원 고시 개정에 따른 정보시스템 보.pdf
#  - 국방과학연구소_기록관리시스템 통합 활용 및 보안 환경 구축.pdf
#  - 국방과학연구소_대용량 자료전송시스템 고도화.pdf
#  - 그랜드코리아레저(주)_2024년도 GKL  그룹웨어 시스템 구축 용역.pdf
#  - 나노종합기술원_스마트 팹 서비스 활용체계 구축관련 설비온라인 시스.pdf
#  - 남서울대학교_[혁신-국고] 남서울대학교 스마트 정보시스템 활성화(학사.pdf
#  - 대검찰청_아태 사이버범죄 역량강화 허브(APC-HUB) 홈페이지 및 온라인 교.pdf
#  - 대전대학교_대전대학교 2024학년도 다층적 융합 학습경험 플랫폼(MILE) 전.pdf
#  - 대한상공회의소_기업 재생에너지 지원센터 홈페이지 개편 및 시스템 고.pdf
#  - 대한장애인체육회_2025년 전국장애인체육대회 전산 및 시스템, 홈페이지 .pdf
#  - 대한적십자사 의료원_적십자병원 병원정보 재해복구시스템 구축 용역 .pdf
#  - 문화체육관광부 국립민속박물관_2024년 국립민속박물관 민속아카이브 자.pdf
#  - 부산관광공사_경영정보시스템 기능개선.pdf
#  - 사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf
#  - 사단법인아시아물위원회사무국_우즈벡-키르기즈스탄 기후변화대응 스.pdf
#  - 서민금융진흥원_서민금융진흥원 서민금융 채팅 상담시스템 구축.pdf
#  - 서영대학교 산학협력단_전문대학 혁신지원사업 서영대학교 차세대 교육.pdf
#  - 서울특별시 여성가족재단_(재공고, 협상) 서울 디지털성범죄 안심지원센.pdf
#  - 서울특별시교육청_서울특별시교육청 지능정보화전략계획(ISP) 수립(2차) .pdf
#  - 세종테크노파크_세종테크노파크 인사정보 전산시스템 구축 용역 입찰공.pdf
#  - 수협중앙회_강릉어선안전조업국 상황관제시스템 구축.pdf
#  - 수협중앙회_수협중앙회 수산물사이버직매장 시스템 재구축 ISMP 수립 입.pdf
#  - 울산광역시_2024년 버스정보시스템 확대 구축 및 기능개선 용역.pdf
#  - 을지대학교_을지대학교 비교과시스템 개발.pdf
#  - 인천공항운영서비스(주)_인천공항운영서비스㈜ 차세대 ERP시스템 구축 .pdf
#  - 인천광역시 동구_수도국산달동네박물관 전시해설 시스템 구축(협상에 .pdf
#  - 인천광역시_도시계획위원회 통합관리시스템 구축용역.pdf
#  - 인천광역시_인천일자리플랫폼 정보시스템 구축 ISP 수립용역.pdf
#  - 재단법인 광주광역시 광주문화재단_2024년 광주문화예술통합플랫폼 시스.pdf
#  - 재단법인 광주연구원_광주정책연구아카이브(GPA) 시스템 개발.pdf
#  - 재단법인 한국장애인문화예술원_2024년 장애인문화예술정보시스템 이음.pdf
#  - 재단법인경기도일자리재단_2025년 통합접수시스템 운영.pdf
#  - 재단법인스포츠윤리센터_스포츠윤리센터 LMS(학습지원시스템) 기능개선.pdf
#  - 재단법인충북연구원_GIS통계 기반 재난안전데이터 분석ㆍ관리 시스템 구.pdf
#  - 전북대학교_JST 공유대학(원) xAPI기반 LRS시스템 구축.pdf
#  - 전북특별자치도 정읍시_정읍체육트레이닝센터 통합운영관리시스템 구.pdf
#  - 조선대학교_(재공고)2024 조선대학교 SW중심대학 사업관리시스템(WeHub) 구.pdf
#  - 중앙선거관리위원회_2025년도 행정정보시스템 위탁운영사업.pdf
#  - 축산물품질평가원_꿀 품질평가 전산시스템 기능개선 사업.pdf
#  - 축산물품질평가원_축산물이력관리시스템 개선(정보화 사업).pdf
#  - 케빈랩 주식회사_평택시 강소형 스마트시티 AI 기반의 영상감시 시스템 .pdf
#  - 파주도시관광공사_종량제봉투 판매관리 전산시스템 개선사업.pdf
#  - 한국가스공사_[재공고]차세대 통합정보시스템(ERP) 구축.pdf
#  - 한국건강가정진흥원_2025년 아이돌봄인력 인적성 검사 정보시스템 운영.pdf
#  - 한국교육과정평가원_국가교육과정정보센터(NCIC) 시스템 운영 및 개선.pdf
#  - 한국농수산식품유통공사_농산물가격안정기금 정부예산회계연계시스템 .pdf
#  - 한국농어촌공사_네팔 수자원관리 정보화사업-Pilot 시스템 구축용역.pdf
#  - 한국농어촌공사_아세안+3 식량안보정보시스템(AFSIS) 3단계 협력(캄보디아.pdf
#  - 한국로봇산업진흥원_한국로봇산업진흥원 사업관리시스템 온라인평가 .pdf
#  - 한국발명진흥회 입찰공고_2024년 건설기술에 관한 특허·실용신안 활용실.pdf
#  - 한국보건산업진흥원_의료기기산업 종합정보시스템(정보관리기관) 기능.pdf
#  - 한국보육진흥원_연차별 자율 품질관리 시스템 기능개선.pdf
#  - 한국사학진흥재단_대학재정정보시스템(기본재산 및 기채 사후관리) 고.pdf
#  - 한국사회보장정보원_라오스 보건의료정보화 협력을 위한 사전타당성 조.pdf
#  - 한국산업단지공단_산단 안전정보시스템 1차 구축 용역.pdf
#  - 한국산업인력공단_RFID기반 국가자격 시험 결과물 스마트 관리시스템 도.pdf
#  - 한국생산기술연구원_2세대 전자조달시스템  기반구축사업.pdf
#  - 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.pdf
#  - 한국수자원공사_건설통합시스템(CMS) 고도화.pdf
#  - 한국수자원공사_수도사업장 통합 사고분석솔루션 시범구축 용역.pdf
#  - 한국수자원공사_용인 첨단 시스템반도체 국가산단 용수공급사업 타당성.pdf
#  - 한국수자원조사기술원_수문자료정보관리시스템(HDIMS) 재구축 용역(3단계.pdf
#  - 한국수출입은행_(긴급) 모잠비크 마푸토 지능형교통시스템(ITS) 구축사업.pdf
#  - 한국어촌어항공단_한국어촌어항공단 경영관리시스템(ERP·GW) 기능 고도.pdf
#  - 한국연구재단_2024년 기초학문자료센터 시스템 운영 및 연구성과물 DB구.pdf
#  - 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.pdf
#  - 한국원자력연구원_한국원자력연구원 선량평가시스템 고도화.pdf
#  - 한국재정정보원_e나라도움 업무시스템 웹 접근성 컨설팅.pdf
#  - 한국전기안전공사_전기안전 관제시스템 보안 모듈 개발 용역.pdf
#  - 한국지식재산보호원_IP-NAVI  해외지식재산센터 사업관리 시스템 기능개.pdf
#  - 한국철도공사 (용역)_[재공고][긴급][협상형]운행정보기록 자동분석시스.pdf
#  - 한국철도공사 (용역)_모바일오피스 시스템 고도화 용역(총체 및 1차).pdf
#  - 한국철도공사 (용역)_예약발매시스템 개량 ISMP 용역.pdf
#  - 한국한의학연구원_통합정보시스템 고도화 용역.pdf
#  - 한국해양조사협회_2024년 항해용 간행물 품질관리 업무보조 시스템 구축.pdf
#  - 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.pdf
#  - 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf
#  - 기초과학연구원_2025년도 중이온가속기용 극저온시스템 운전 용역.pdf
#  - 서울시립대학교_[사전공개] 학업성취도 다차원 종단분석 통합시스템 1차.pdf
#  - 서울특별시_2024년 지도정보 플랫폼 및 전문활용 연계 시스템 고도화 용.pdf

# %% [markdown]
# ### 문서 단위 평가
#
# - generation: `gen_fill_rate`, `gen_match_rate`, `gen_avg_similarity`
# - retrieval: `retrieval_recall@k`, `retrieval_mrr@k` (anchor 기반)
# - score: 위 지표의 가중합

# %%
import unicodedata
def run_eval_for_doc(doc_path: Path) -> pd.DataFrame:
    doc_name = doc_path.name
    doc_name = unicodedata.normalize("NFC", doc_path.name)

    qdf = gold_fields_df[gold_fields_df["doc_id"].astype(str) == doc_name].copy()
    if len(qdf) == 0:
        print("⚠️ no gold fields:", doc_name)
        return pd.DataFrame()

    # 베이스라인 청킹/인덱싱
    model = embed_model

    index, chunks = pp.gen_input(doc_path, embed_model)


    # 배치 답변 생성 (베이스라인 질문 순서)
    answers, idxs = answer_batch(index, model, chunks, BASELINE_QUERIES, top_k=TOP_K, return_indices=True)
    answer_map = {k: answers[i] if i < len(answers) else "" for i, (k, _) in enumerate(BASELINE_QUERIES)}


    # 평가
    r_list, g_list = [], []
    for _, row in qdf.iterrows():
        iid = str(row["instance_id"])
        field = str(row["field"])
        gold = row["gold"]
        pred = answer_map.get(field, "")

        anchors = GOLD_ANCHOR.get(iid, [])
        if anchors:
            r_list.append(eval_retrieval_by_anchor(chunks, idxs, anchors))
        else:
            r_list.append({"recall": np.nan, "mrr": np.nan})

        g_list.append(eval_gen(pred, gold, threshold=SIM_THRESHOLD))

    rows = [{
        "doc_id": doc_name,
        "n_questions_total": len(qdf),
        "n_questions_with_evidence": int(sum(1 for x in qdf["instance_id"] if str(x) in GOLD_ANCHOR)),
        "retrieval_recall@k": float(np.nanmean([x["recall"] for x in r_list])),
        "retrieval_mrr@k": float(np.nanmean([x["mrr"] for x in r_list])),
        "n_questions_with_gold_fields": len(qdf),
        "gen_fill_rate": float(np.nanmean([x["fill"] for x in g_list])),
        "gen_match_rate": float(np.nanmean([x["match"] for x in g_list])),
        "gen_avg_similarity": float(np.nanmean([x["sim"] for x in g_list])),
    }]
    return pd.DataFrame(rows)

# %%
pp.show_sample(docs, n="all")
# Out:
# 문서: (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf
# 총 청크 수: 74
#
# === 청크 0 (377자) ===
# ## 2024 2024 2024 2024 2024 2024 년 년 년 년 년 년 ｢ ｢ ｢ ｢ ｢ ｢ 벤처확인종합관리시스템 벤처확인종합관리시스템 벤처확인종합관리시스템 벤처확인종합관리시스템 벤처확인종합관리시스템 벤처확인종합관리시스템 기능 기능 기능 기능 기능 기능 고도화 고도화 고도화 고도화 고도화 고도화｣ ｣ ｣ ｣ ｣ ｣ 2024 년 ｢벤처확인종합관리시스템 기능 고도화｣ 용역사업 (p.1)
# -( 복수의결권주식 , 스톡옵션 , 성과조건부주식 ) -
#
# ## 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 제안요청서 (p.1)
# 2024. 03.
#
# ## 목 차 (p.2)
#
# ## Ⅰ . 추진개요 (p.3)
#
# === 청크 1 (799자) ===
# ## 1 추진배경 및 방향 (p.3)
# □ 「 벤처기업육성에 관한 특별조치법 」 ( 이하 ' 벤처기업법 ') 복수의결권주식 , 스톡옵 션 ( 주식매수선택권 ), 성과조건부주식교부계약 (RS) 등의 기능 고도화 및 이관 , 신규 구축업무를 本 과업에서 추진
# ( 복수의결권주식 ) 벤처기업법 제 16 조의 11 에 따라 발행된 복수의결권주 식 보고 업무처리 시스템 구축
# 복수의결권이란 ? 모든 주주는 1 주당 하나의 의결권을 갖는 주주평등원칙 ( 상법 ) 과 별도로 비상장 벤처기업 창업자에게만 1 주당 최대 10 배의 의결권 행사를 부여하는 제도
# ⚬ ( 스톡옵션 * ) 벤처기업법 제 16 조의 3 에 따라 부여된 벤처기업 부여 , 취소 · 철회 신고 및 업무시스템 구축
# 스톡옵션
# 스톡옵션이란 ? 비상장 벤처기업 임 · 직원 및 기업 성장에 기여한 자에게 미리 정한 가격 ( 행 사가격 ) 으로 신주를 인수하거나 자기의 주식을 매수할 수 있는 권리 혹은 주식의 시가와 행 사가격의 차액을 청구할 수 있는 권리를 부여하는 제도
# -중소벤처 24 內 스톡옵션 신청 기능 이관을 추진하며 , 과거 데이터 정 제 및 적재 등을 통한 데이터 이관 추진
# ⚬ ( 성과조건부주식 * ) 벤처기업법 제 16 조의 19 에 따라 성과조건부주식교부 계약의 신고 및 업무처리 시스템 구축
# 성과조건부주식이란 ? 비상장 벤처기업 임ㆍ직원 및 특정인에게 자기주식 부여를 약속하되 , 일정 재직기간 및 조건을 충족해야 주식이 부여 대상자에게 귀속되도록 제한을 둔 주식
# □ 복수의결권주식 발행 보고 및 스톡옵션 신고기능은 기존 시스템 내 벤 처확인 이력정보와 신고
#
# === 청크 2 (516자) ===
# 자 ( 벤처기업 ) 의 정보와 연동
# ( 사 업 명 ) 2024 년 「 벤처확인종합관리시스템 기능 고도화 」 용역사업 -복수의결권주식 , 스톡옵션 , 성과조건부주식교부 기능 구축 및 고도화
# □ ( 사업기간 ) 계약일로부터 150 일
# 1 차 오픈 : 2024.07.10.
# 성과조건부 및 스톡옵션 오픈
# ** 2 차 오픈 : 2024.09
# 월 中 GrandOpen
# □ ( 소요예산 ) 352,000,000 원 ( 부가가치세 포함 )
# □ ( 계약방식 ) 제한경쟁입찰 ( 협상에 의한 계약 ) 에 의한 선정 *
# ( 근거 ) 「국가를 당사자로 하는 계약에 관한 법률」 시행령 제 21 조 , 제 43 조
# □ (선정 방법) 본 사업은 전문기술이 요구되는 사업으로 기술력이 높은 업체 를 선정하고 협상을 통해 요구사항을 반영할 수 있는 '협상에 의한 계약' 방식 으로 추진
# (선정 절차) 제안서 평가는 기술평가 (90%) 와 가격평가 (10%) 를 합산하여 종합평가점수로 산출 ( 배정한도 85% 이상 , 고득점순으로 협상적격자 결 정 )
#
# === 청크 3 (692자) ===
# ## 행정기관 및 공공기관 정보시스템 구축․운영 지침 (p.4)
#
# ## 제18조(평가배점) (p.4)
# 행정기관 등의 장은 기술력이 우수한 사업자를 선정하여 정보화사업의 품질을 확보하기 위해 국가계약법 시행령 제 43 조의 2, 지방계약법 시행령 제 44 조에 따라서 협상에 의한 계약체결 방법 을 우선적으로 적용하고 , 기술능력평가 배점한도를 90 점으로 한다 .
# □ (대기업 참여 제한) 「소프트웨어 진흥법」제 48 조제 2 항에 따라 , 사업금액 20 억원 미만 계약은 대기업 참여 제한
#
# ## Ⅱ . 사업 추진방안 (p.5)
#
# ## 1 추진목표 (p.5)
# ◈ 벤처확인 연계를 통한 복수의결권 및 스톡옵션 시스템 고도화
#
# ## 추진 목표 (p.5)
# ◈ 복수의결권주식, 스톡옵션 업무시스템 구축
# ◈ 스톡옵션 데이터 이관 작업 수행
# ◈ 신청접수 및 처리 결과 알림 One-Stop Service
#
# ## 2 추진체계 및 역할 (p.6)
#
# ## □ 추진체계 (p.6)
#
# ## □ 추진역할 (p.6)
#
# ## 중소벤처기업부 (p.6)
#
# ## 벤처기업확인기관 (p.6)
# ( 시스템 고도화 발주 )
#
# ## 자문위원 (p.6)
# ( 법률 , 검수 · 검사 등 )
#
# ## 사업 수행업체 (p.6)
# 벤처확인종합관리시스템 기능 고도화 수행 ( 복수의결권 , 스톡옵션 , 성과조건부주식 )
#
# ## 운영 유지관리 업체 (p.6)
# 現 시스템 유지관리업무 수행 中
#
# === 청크 4 (584자) ===
# ## 3 추진방안 (p.7)
# □ ( 구축 인터뷰 ) 복수의결권주식 및 스톡옵션 시스템 구축을 위한 사전 기능 요구사항에 대한 충 분 한 인터 뷰 * 진행 , 분석 ㆍ기 획 보고서 제출
# 시스템 Risk-Point 해결 / 개선을 위한 중소벤처기업부 , 중소벤처기업부 지방청 (13 개 ) 미 팅
# □ ( 데이터분석 ) 스톡옵션 데이터 분석 을 통한 통계 자 료 및 타 기관 연계정 보 현황 수요조사 진행
# 벤처확인종합관리시스템 벤처확인유 형 별 입수된 정보를 이용한 스톡옵 션 부여신고 간소화 서비스 추진ㆍ 분석 , 회원연계 ( 중소벤처 24) 분석
# 스톡옵션 데이터 및 문서 정제 / 적재 작업 수행
# 스톡옵션 , 복수의결권주식 확인 및 행정업무 수행을 위한 별도 백 오 피 스를 구성 , 외 부 * 접속을 위한 접근제어 솔루션 탑 재 여부 분석
# 공동인 증 서 로 그 인을 통해 접속 中 , 개선방안 제시 및 로 그 인 기록 보관
# 벤처확인종합관리시스템 內 탑재를 위한 시스템 분석 * 자료 ( 영향도 분석 ) 제출
# 데이터 연계 , 기정원 인프라 구성 (TA 분석 ), 상용 SW 활 용 및 Risk( 라이선스 등 ) 분석
#
# ## 4 추진일정 (p.8)
#
# === 청크 5 (272자) ===
# ## □ 추진일정 ( 안 ) (p.8)
# ★ 복수의결권 1 차 오픈일 ('24.07.10) 준수 , 스톡옵션 GrandOpen( 미정 )
# 주요내용
# 1차 오픈
# 중간보고 및 완 료 보고 ( 중소벤처기업부 , 벤처기업확인기관 )
# -사용자 매 뉴얼 작성 , 업무용 매 뉴얼 을 통한 교육 2 회
# 주 단위 시스템 진행 보고 ( 벤처기업확인기관 )
# 시스템 안정화를 위한 1 개월 이상 안정화 운영인력 상주
#
# ## Ⅲ . 사업 추진내용 (p.9)
#
# ## 1 복수의결권 / 스톡옵션 개 념 도 (p.9)
#
# === 청크 6 (644자) ===
# ## □ 메뉴 구성 ( 안 ) (p.9)
# ※ 성과조건부주식교부 신고기능은 스톡옵션 기능 메뉴 규성과 유사함
# -복수의결권 및 스톡옵션 업무시스템 메뉴 구성 * 및 디 자인 시안 제출
# 업무시스템 효율 성을 고 려 한 최적의 메뉴 구성 ( 안 ) 제안 , 메뉴 구성 ( 안 ) 의 명칭 은 변경 보 완 될 수 있 음
# □ ( 대민사이트 ) 벤처확인종합관리시스템 內 복수의결권주식 , 스톡옵션 메 뉴 로 구성
# -복수의결권주식 발행보고 양 식 출력
# -스톡옵션 부여 신고자 , 스톡옵션 부여 대상자 정보 확인 페 이지 구축 ( 스 톡옵션 신고 양 식 출력 )
# -스톡옵션 부여신고 지방청 (13 개 ) 자동 배정 , 스톡옵션 부여신고 ( 취소 ㆍ철회 포함 )
# □ ( 백오피스 ) 복수의결권주식 발행보고 및 스톡옵션 신고 업무처리를 위한 각 별도의 업무시스템 구축
# 중소벤처기업부 및 13 개 지방중소벤처기업청 접속 , 성과조건부주식교 부계약 업무처리 시스템도 동일하게 구축
# 벤처확인 이력정보 연동 및 요건 충족 여부 등의 이상 관제 모 니 터 링 기능 구 현
# 벤처확인 재발 급 , 벤처확인 취소
# 공시대상기업 집 단 계 열 회사 편 입 , 기업상장 여부 등
# -스톡옵션 부여신고 자동배정 프로 세 스 구 현 , 스톡옵션 부여자 알림 기능 , 업무 담 당자별 차등 권한 등
#
# === 청크 7 (672자) ===
# ## 2 업무 및 시스템 현황 (p.11)
# □ ( 복수의결권주식 ) 「 벤처기업육성에 관한 특별조치법 」 시행에 따 른 복수 의결권주식 발행 보고 기능 오픈 中
# 복수의결권주식 발행 보고 ( 보완 ) 기능 고도화
# 비상장 벤처기업 요건 확인 후 복수의결권주식 발행 , 사 후 관리 ( 상장 , 대 기업 집 단 편 입 등 ) 모 니 터 링 구 현
# 비상장 벤처기업 요건 확인 후 스톡옵션 부여신고 , 새 로운 기 획 을 통한 스톡옵션 신청 , 운영관리 구축
# 스톡옵션 신고 확인 관리자 (BackOffice) * 페 이지 별도 구성 中 , 공동인 증 서 로 그 인
# 중소벤처기업부 , 13 개 지방중소기업청 담 당 공무원 로 그
# -스톡옵션 배정 및 처리 현황 통계 기능 구축 , 부여대상자 ( 부 분 ) 취소 기능개선 등
# □ ( 인프라 ) 중소기업기술정보진흥원 클 라우 드 (Paas-TA) 환 경에 설 치 운영되 고 있으며 , 벤처확인종합관리시스템 內 시스템 탑 재에 따 른 상용 SW 적 용 가능
# 복수의결권주식 , 스톡옵션 별도 관리자 시스템 구축을 위한 PaaS-TA 자원 할당 ( 운영 / 개발 ) 제안
#
# ## < 벤처확인종합관리시스템 인프라운영 현황 > (p.12)
# ※ 중소벤처 24 제공 서비스 : SSO 이지 패 스 , 레 포 팅툴 , DB 암호 화 솔루션
#
# ## 3 복수의결권 추진내용 (p.13)
#
# === 청크 8 (394자) ===
# ## □ 복수의결권주식 제도 요약 (p.13)
# □ ( 비상장 벤처기업 ) 복수의결권주식 발행보고 前 비상장 벤처기업 여부 확인 , 요건 충족 기업만 가능
# ( 비상장 ) 복수의결권주식 발행보고 기업 법인등록 번호 조회
# -대기업기업 집 단 계 열 회사 편 입 여부 ( 데이터포 털 연계 )
# ( 벤처확인 ) 복수의결권주식 발행보고 기업 사업자등록 번호 , 법인등록 번 호 , 벤처확인발 급번호 조회
# -( 벤처확인 프로세스 ) 벤처확인 재확인  , 또 는 취소  ( 청문절차 ), 재발 급  등 복수의결권주식 발행 신고 가능 여부 체 크
# -주주 총 회 결의 시 벤처확인이 유 효 하다 면 신청 가능
# □ ( 복수의결권주식 기능개선 ) 복수의결권주식 발행보고 출력 기능개선 , 기 업 My 페 이지 활 동 이력
#
# === 청크 9 (799자) ===
# ## < My페이지 기업 활동이력 예시 > (p.15)
# ① 벤처확인 이력 기준 복수의결권주식 발행보고 , 스톡옵션 신고 이력이 있는 경우 노 출
# -벤처확인 유 효 시작일 ~ 만 료 일 기간 내 정관개정을 통한 복수의결권주식 발행보고 , 스톡옵션 신고 가 능
# -이상 : 대기업 집 단계 열편 입 , 상장 , 폐 업 / 휴 업 등이 있는 경우 표시
# ② 벤처확인이력 기준 복수의결권주식 발행보고는 '23.11.17 부터 가능 , 스톡옵션은 98 년부터 신고 가능
# -사용자 활 동이력은 업무시스템에 동일하게 노 출되도록 구 현
# ③ 벤처확인발 급번호 , 복수의결권주식 접수 번호 , 스톡옵션 접수 번호 기준 출력 기능개발
# ( 정관변경 ) 특별결의를 통한 변경 정관 업로 드 기능 구 현
# ※ 엄 격한 주주동의 , 발행주식 총 수의 4 분 의 3 이상 동의로 가결
# 특수관계인으로부터 받 은 투 자를 제 외 한 투 자금액이 누 적 100 억원 & 마 지 막 50 억원 이상
# 벤처확인 정보 연동을 통한 사용자 정보 입력 간소화
# 제출서류 업로 드 기능 구 현 ( 제출서류 이력 관리 기능 포함 )
# < 복수의결권주식 ( 발행 , 변경 ) 필 수 기재 항목 >
# ※ 복수의결권주식 ( 발행 , 주요사항 변경 ) 보고서 양 식 제공 , 보고서 양 식 분석 을 통 환 시스템 화 면 기 획 필 요
# < 사 후 변경에 따 른 복수의결권주식의 보통주 전 환 >
# □ ( 복수의결권주식 발행보고 ) 복수의결권주식 받 은 자의 성 명 , 발행일자 , 발행 수 량 을 벤처확인종합관리시스템 공시
# 복수의결권주식 발행보고 서 문서 출력 기능 구 현
# 「 벤처기업육성에 관한
#
# === 청크 10 (241자) ===
# 특별조치법 시행규칙 」 별지 제 9 호 참 고
# 복수의결권주식 변경보고 서 문서 출력 기능 구 현
# -변경 신고 완 료 후 복수의결권 발행 변경 전 / 후 비교 정보 출력
# 복수의결권주식 변경사항 공시 기능 구 현
# □ ( 복수의결권 위 반 ( 허위 거짓 ) 발행 신고기능 ) 복수의결권주식 발행 위반행 위 신고기능 구 현
# 개인정보 수 집 및 이용 동의 절차 기능 구 현 , 신고자 통신사 인 증
# -위반행위 신고작성 방법 안내 페 이지 구
#
# === 청크 11 (604자) ===
# ## 4 스톡옵션 추진내용 (p.19)
# □ ( 데이터 이관 ) 중소벤처 24 內 벤처기업 스톡옵션 ( 주식매수선택권 ) 신고를 위해 가입된 회원정보 * 및 과거 각 종 데이터 / 문서 이관
# 벤처확인종합관리시스템 內 탑 재를 위한 회원 중복가입 등 데이터 검 증 ( 회원통합 )
# 신고접수 및 보완요청 , 최종수리 단계별 신고자 알림
# 스톡옵션 신고 물량 배정 기능 구축 ( 중소벤처기업부 지방청 )
# 벤처기업법 제 16 조의 3 비상장 벤처기업 확인
# -주주 총 회 결의 시 벤처확인이 유 효 하다 면 신청 가능 , 과거 벤처확인이
# 력이 있는 경우 해당 유 효 기간 내 주주종회 결의시 신청 가능
# ☞ ( 기능 구축 ) 대민사이트 스톡옵션 신고 前 증 권시장 ( 유가 증 권시장 , 코 스 탁 시장 , 코넥 스시장 ) 에 상장되지 않 은 비상장 벤처기업 여부 확인
# < 비상장 벤처기업 여부 조회(안) >
#
# ## 1안) 비상장 / 벤처기업 동시 조회 (p.20)
# 2안) 벤처기업 조회 / 비상장 별도 확인
# 연도별 행사가격 분 포
# -배정 조건 外 부득이 재배정 이 슈 가 발행할 수 있 음 , 부여신고 접수 번호 를 통한 재배정 이력 조회 기능 구축 ( 지방청 배정 이력 전체 조회 가 능 )
#
# === 청크 12 (799자) ===
# ## □ 스톡옵션 부여신고 (p.21)
# 비상장 벤처기업 조회 후 스톡옵션 부여 신고서 작성 기능 구 현
# ( 출력 ) 「 벤처기업육성에 관한 특별조치법 시행규칙 」 별지 제 3~4 호 참 고
# ※ ( 중요 ) 기재된 화 면 은 참 고자 료 이며 , 별도 화 면 기 획 및 제안 진행
# NOE5
# 기업정보 , 업무 담 당자 입력 간소화 방안 기 획
# 기업 명 , 대표자 명 등 일반적인 입력정보
# 사업자등록 번호 , 벤처확인발 급번호 등을 통한 주식 매수선택권 부여 신고 가능 조회기능 탑 재 3. 벤처확인정보 연계
# 벤처확인발 급번호 , 벤처확인일 , 유 효 시간
# ※ 벤처확인이력조회가 되지 않 는 경우 문의 case1. 벤처확인만 료 case2. 사업자등록 번호 와 벤처확인정보 불 일치 case3. 벤처확인만 료 일 기준 벤처재확인 프로 세 스 진행 中
# 부여주식종류 별도 코드 로 관리
# 액 면 가 단위 ( 원 ), 숫 자한 글 정보 표기
# 부여인원 주식수 , 행사가격 총 합과 동일해야 함
# olue
# 50(22492482(8102)
# 0184 522
# OPA84 2191
# 92 4 849
# 1. 1841219391 842(2 48165 913 4818 12)|
# 2.78084 28898 325 1( 4 16593 4 18 22)|
# 3. (992 087712(3 (4816593 4818 39)
# 정관에 ' 스톡옵션 ( 주식매수선택권 ) 주식의 행사기간 ' 이 규정되어 있는지 여부 中 행사기간은 주식매수 선택권 부여 결의사항 행사기간과 연동되어 체 크 되 어야 함
# 주주 총 회특별결의 , 이사회 결의에 따 른 입력창 , 페 이지부터 임시 저 장 기
#
# === 청크 13 (346자) ===
# 능 활 성화
# (+) 연 번 추가를 통한 부여인원 등록 , 부여인원 대 량 등록기능 개발
# 부여인원의 핸드폰번호 등록 ( 개인정보보 호 에 관한 신고자 대리 등록에 따 른 등록 동의 )
# 핸드폰번호 를 통해 부여된 인원의 부여주식 정보 안내
# 자격 , 부여방법 코드값 으로 관리 ,
# 부여인원 주식 총 합 자동 계산
# 항목별 첨 부 파 일 업로 드 복수
# 4 91091 71909 942( 48163593 4818 42)
# 49 49
# 40 9 28
# 438s
# R3E 049
# 4400-248409-8948
# VOZAN
# 243500 B73E
# WOST
# MOFNO
# 080389948 483
# RADOLA 2891 9940R 49(EMES
# NHEE
#
# === 청크 14 (676자) ===
# ## □ 스톡옵션 취 소 ( 부분 )/ 철 회 신고 (p.22)
# 스톡옵션 부여 신고 건에 대한 주식매수선택권 피 부여자 ( 부 분 ) 취소 , 철회 기능
# ( 부 분 ) 취소 , 철회 신고 통보 결과 기능 구 현
# -피 부여자 취소 및 철회 신고 사항 알림 기능 구 현
#
# ## □ 스톡옵션 부여대상자 (p.23)
# 부여대상자는 시스템 로 그 인 후 My 페 이지를 통해 스톡옵션 부여 현황 및 행사 정보 확인
#
# ## < My페이지 스톡옵션 부여대상자 예시 > (p.23)
#
# ## Ⅳ . 제안요청 내용 (p.24)
#
# ## 1 과업수행방법 (p.24)
#
# ## □ 과업 착 수 (p.24)
# 본 시스템 기능 고도화 용역사업은 과업 시작일로부터 10 일 이내 착 수하 여야 함
# 계약상대자는 계약체결일로부터 10 일 이내 다 음 과 같 은 서류를 벤처확 인기관에 문서로 제출해야 함
# ∨ 착 수계
# ∨ 책 임기술자 선임계
# ∨ 책 임기술자 이력서 및 기술자격 증 사본
# ∨ 참 여기술자 이력서 및 기술자격 증 사본
# ∨ 보안 각 서 및 보안대 책
# ∨ 과업수행계 획 서
# ∨ 기타 필 요사항
#
# ## □ 과업수행계 획 서 제출 (p.24)
# ( 과업수행계 획 서 ) 계약서 , 과업내용서 등의 내용을 근거로 작성
# ( 계 획승 인 ) 계약상대자는 과업수행계 획 서를 벤처기업확인기관의 승 인을 득 한 후 이에 따라 과업 수행
# 제 출서류 목 록
#
# === 청크 15 (606자) ===
# ## 2 제안요청 일반사항 (p.25)
# □ 제안 업체는 시스템 기능 고도화 완 료 후 기능 확장성 등을 고 려 하여 제안하여야 함
# □ 제안 업체는 제안하는 모든 부 분 에 포 괄 적인 책 임을 가지며 , 제안 시점 에서 사업수행요건 미충족 업체는 선정 대상에서 제 외 함
# □ 제안규격의 만족 여부는 벤처기업확인기관에서 제시하는 평가 기준 등 에 의해 심 사함
# □ 전산시스템 운용 및 유지관리에 대처할 수 있는 구체적 기술이전 , 교육 계 획 및 지원계 획 을 제시해야 함
# □ 특별한 사유가 없 는 한 본 시스템 기능 고도화사업은 사업 기간 中 개 발 완 료 및 테 스트 가능하여야 하며 , 하자 보 증 기간 내 하자보수 및 유 지관리 계약이행에 대한 모든 책 임을 져 야 함
# □ 안정적이고 확장 가능한 최적의 시스템 개발하며 개발업무의 각 종 서식 및 코드 , 시스템 간 통합 및 연계 , 전산 망 간 연계 등 정보화 표준을 준용하여 개발해야 함
# □ 시스템 개발과정에서 취득한 일체 모든 정보는 외 부로 유출 또 는 발 설 해서는 안 되며 , 만약 사업 과정에서 보안사고 발 생 시 업체에서는 일 체 민 형 사상의 책 임을 지고 , 벤처기업확인기관이 입은 손 해에 대하여 배상해야 함
#
# === 청크 16 (721자) ===
# ## 3 제안요청 필 수사항 (p.26)
# □ ① 보안성을 고 려 한 시스템 구성 및 운영방안 , ② 보안성 강 화 및 관리의 용이성을 위한 추가지원 가능 사항 ( 필 요시 ) 을 제시해야 함
# □ 시스템 장 애 발 생 시 , 즉각 복구할 수 있는 체제를 구축해야 함
# □ 향 후 시스템 확장성을 위해 시스템 기능 고도화 관련 표준을 최대한 준수
# □ 제안서에 기재되지 않 은 사항이라 할지라도 제품성능에 필 요한 사항은 벤처기업확인기관과 협의를 통해 공 급 ( 납 품 ) 하여야 함
# □ 최종 인수 결과 시스템 운영 불 가로 ' 계약조건 미충족 ' 으로 판 단 시 , 벤 처기업확인기관의 요구에 의해 구축한 모든 시스템을 철거 · 회수하여야 하며 , 그 비용은 제안업체에서 일체 부 담 하고 이로 인한 벤처기업확인 기관의 손 해를 배상해야 함
# □ 본 과업의 시스템은 유기적으로 데이터 교 환 이 가능하여야 하며 , 타 기관 의 시스템 연계가 가능해야 함
# □ 시스템 기능 고도화 과정에서 취득한 정보에 대한 보안 관리 방법 등에 대한 제시 및 시스템 구축 후 하자보수를 위한 방안을 제시해야 함
#
# ## □ 요구사항 정의표 (p.27)
# ※ 사업 내용이 변경 될 경우 과업변경절차에 따라 상 호 협의하여 결정하며 , 제안서 작성 시 제안요청서 요구사 항에 명 시되지 않았 으나 제안 업체 판 단으로 추가되어야 할 요구사항에 대해서는 별도 표시하여 추가 작성 가능함
#
# ## □ 요구사항 상세 (p.28)
#
# === 청크 17 (798자) ===
# ## 가 기능 요구사항(Sy s te m Fu nction R e qu ire m ent) (p.28)
# 요구사항
# 요구사항
# 요구사항
# 요구사항
# 상세설명
# 세부내용
# SFR-016
# 요구사항
# 복수의결권주식
# 복수의결권
# 신고정보
# 복수의결권
# 요구사항정의서
# 변경보고
# (SFR-015)
# (SFR-015)
#
# ## 나 성능 요구사항( P erfor m ance R e qu ire m ent) (p.43)
#
# ## 다 시스템 장비 구성 요구사항(( Equ ip m ent C o m po s ition R e qu ire m ent) (p.45)
#
# ## 라 인터페이스 요구사항(Sy s te m I nterface R e qu ire m ent) (p.47)
#
# ## 바 테 스트 요구사항( T e s t R e qu ire m ent) (p.53)
#
# ## 사 보안 요구사항(Sec u rity R e qu ire m ent) (p.55)
#
# ## 자 제약사항( C on s train s R e qu ire m ent) (p.61)
#
# ## 세부내용 (p.62)
#
# ## [ 표준화 공통 ] (p.62)
# ❍ 위에서 제시한 방안 등을 준용하여 시스템 구축 시 고 려 되어야 할 표준화 방 안 및 요구사항에 대한 구체적인 준수방안을 제시하고 적용해야 함
# ❍ 전자정부 구축을 위한 기술 아키텍 처 표준을 제시한 ' 행정기관 및 공공기관 정보시스템 구축 · 운영지침 ( 행정안전부 고시 )' 를 준수
# ❍ 본 사업에서 구축 될 전자정부표준프 레 임 워크 를 기반으로 시스템을 개발해야 하며 , 성능 및 안정성에 문제가 발 생 할 경우 주관기관과 협의하여 결정해야 함
#
# === 청크 18 (681자) ===
# ## [ 정보화 업무 표준 ] (p.62)
# ❍ 주관기관에서 제시하는 각 종 표준 ( 프로 세 스 , 정보 , 사업관리 등 ) 을 준수해야 함
# ❍ 표준운영 체계 , 절차 및 보안체계 , 정 책 등 각 종 서식에 대하여 기존 표준체 계에 따 르 거나 표준이 없 으 면 표준 형 식을 정의하고 주관기관의 승 인을 득한 후 형 식에 맞 게 작성해야 함
#
# ## [ 정보화 기반 표준 ] (p.62)
# ❍ 행정기관 및 공공기관 정보시스템 구축 · 운영지침 ( 행정안전부 고시 )' 의 기술적 용 계 획 에 따라 본 사업에 해당하는 기술표준을 준수하여야 함
#
# ## [ 행정정보 데이터 베 이스 표준화 ] (p.62)
#
# ## [ 전자정부 웹 호환 성 준수 ] (p.62)
# ❍ 전자정부서비스의 호환 성 확보를 위해 ' 전자정부서비스 호환 성 준수지침 ( 행 정안전부 고시 )' 을 준수해야 함
# ❍ 웹 사이트 구축 표준은 ' 전자정부 웹 표준 준수지침 ( 행정안전부 고시 )' 을 준수 해야 함
# ❍ 웹 표준을 적용하여 IE(10, 11, 그 이상 ), Firefox, Safari, Opera, Chrome 등 3 개 이상의 브 라우 저 에서 웹 사이트가 정상 동작하도록 범 용성 및 호환 성이 확보되도록 적용해야 함
# ❍ 웹 사이트에 비표준기술 (Acitve X, EXE, Java Applet 등 ) 이 포함되지 않 도록 개발하여야 함
#
# === 청크 19 (317자) ===
# ## [ 웹 접근성 표준 준수 ] (p.62)
# ❍ 다 음 지침에 따 른 장 애 인 접근성을 준수하여 적용해야 함
# -인터 넷 웹 콘텐츠 접근성 지침
# -웹 접근성 향상을 위한 국가표준기술 가이 드 라인
# ❍ ' 한국 형 웹 컨텐츠 접근성 지침 (KCS.OT-10.0003/R3)' 적용
# ❍ 웹 접근성 평가도구 (KADAO-WAH) 로 점검시 항목별 95% 이상 준수
# ❍ 웹 접근성 세 부 준수 요건의 경우 주관기관과 협의하여 조정할 수 있 음
# 산 출 정보
# 요구사항
# 요구사항
# 요구사항
#
# ## 요구사항 상세설명 (p.63)
# 세부내용
# 요구사항
# 요구사항
# 요구사항
# 요구사항
# 상세설명
#
# === 청크 20 (790자) ===
# ## [ 개발보안 및 개인정보 보 호 표준 준수 ] (p.63)
# ❍ ' 전자정부 SW 개발 · 운영자를 위한 소프트웨어 개발보안 가이 드 ( 행정안전부 )' 를 준수해야 함
# ❍ ' 표준 개인정보 보 호 지침 ( 행정안전부 예 규 )' 을 준수해야 함
# ❍ ' 공공기관 홈 페 이지 개인정보 노 출방지 가이 드 라인 ( 행정안전부 )' 을 준수해야 함
# ❍ 국가정보원 , 중소벤처기업부 등의 정보보안 요건을 충족해야 함
# 사업수행계
# COR-004
# 제약사항
# ❍ 다 양 한 디바 이스 (PC, 스 마 트 폰 , 태블 릿 PC 등 ) 와 브 라우 저 지원을 위한 스 마 트 기 반의 반 응형 웹 기술 적용
# ❍ OSMU(One Sourece Multi Use) 의 개 념 에 따라 하나의 소스로 다 양 한 사이 즈 의 화 면 에 최적화된 UI 가 구성 될 수 있도록 구 현
# ❍ 모 바 일 전자정부 관련 웹 접근성 및 웹 호환 성을 준수하여 구조 설 계
# ❍ 모 바 일 서비스에 적합하고 이용 빈 도가 높은 정보위주의 메뉴 설 계
# ❍ 모 바 일 기기를 통해 홈 페 이지 접속 시 모 바 일 홈 페 이지로 자동전 환 될 수 있 도록 구성
# 사업수행계
# COR-005
# 제약사항
# 중소벤처
# 기술지원
# 중소벤처
# 기술지원이
# 기술확약서
# 벤처확인시스템과
# 기술확약서를
# 세부내용
#
# ## 차 프로 젝 트 관리 요구사항( P ro j ect M gm t R e qu ire m ent) (p.65)
#
# ## 카 프로 젝 트 지원 요구사항( P ro j ect S u pport R e qu ire m ent) (p.68)
#
# ## □ 산출 물 목록 (p.73)
#
# === 청크 21 (495자) ===
# ## □ 특수사항 (p.74)
#
# ## ◦ 윈 백 (Winback) (p.74)
# -제안요청서에 증설 또 는 변경으로 표기한 경우에는 기존 제품과의 호환 성을 고 려 하여야 하며 , 필 요 시 기존 제품 수 량까 지 포함하여 다 른 제품
# 으로 윈 백 제안을 할 수 있 음
# -윈 백 ( 기존 제품과 다 른 제품으로 제안한 경우 포함 ) 시 각 종 프로 그램 수정 등에 필 요한 기술지원 및 기존 제품 수 량 의 교체는 제안업체가 부 담 하 여야 함
# -그 밖 에 윈 백 ( 기존 제품과 다 른 제품으로 제안한 경우 포함 ) 시 필 요하거나 그 로 인해 발 생 되는 일체의 사항은 사업자가 모 두 책 임지고 해결하여 야 함
# -제안업체는 사업수행계 획 서 제출 시 윈 백 완 료 가능한 일정을 명 시하 여야 하며 , 추 후 사업수행과정에서 해당 일시 까 지 윈 백 을 완 료 하기 어 렵 다고 판 단되는 경우 발주처와 협의하여야 함
# 소프트웨어 개발보안 ( 시 큐 어 코 딩 ) 관련 가이 드 준수
#
# === 청크 22 (766자) ===
# ## ◦ 정보보 호 제품 준수사항 (p.75)
# -( 정보보 호 제품 운영 ) 정보보 호 제품은 CC 인 증 ( 네 트 워크 기반 제품 및 컴퓨 팅 기반 제품은 EAL2 이상 ) 을 획 득한 제품이어야 하며 , 암호 모 듈 검 증 대 상제품은 검 증필 암호 모 듈 탑 재제품이어야 함
# ※ 국가 공공기관 정보보 호 제품 도입기준 및 절차 ( 국가정보원 ) 준수
# -( 제품변경 시 재인 증 ) 제안업체는 취약점 또 는 기능적 결함 등이 발 견 되어 정보보 호 제품의 SW 패 치 또 는 HW 사 양 을 변경하는 경우 , 납 품한 동 제품의 취약점 및 결함을 즉 시 보완하고 , 변경 후 수일 이내에 변경된 사 양 으로 재인 증 추진 등 관련 사항을 조치하여야 함
# ※ 기존 보안적합성 검 증필 제품도 국가 ‧ 공공기관 구축 후 국가 전문기관의 현 장 실 사 위 주의 사 후 검 증 필 요
# -정보보 호 제품 관련 처리기준은 국가정보원 기준 및 중소벤처기업부 , 벤처기업확인기관 관련 지침에 의거 준용하여야 함
#
# ## ◦ 개인정보보 호 법 (p.75)
# ※ 공공기관의 개인정보 취 급 시 준수해야 하는 공통법규 ( 법률 , 지침 , 매 뉴얼 고시 등 ) 및 평가대 상 사업의 특성에 따라 적용되는 관련 법 등을 참 고하여 평가기준을 수 립 해야 함
# -서비스 보안성 강 화를 위해 운영서 버 의 개인정보 유출 탐 지 등 모 니 터 링 , 개발서 버 시 험 운영을 위한 개인정보 관련 모의 데이터 추출 ‧생 성 등의 방안을 마 련하여야 함
#
# ## ◦ 구축시스템의 모의시 험 (p.76)
#
# === 청크 23 (570자) ===
# ## ◦ 기타조건 (p.76)
# -본 사업의 추진과 관련하여 제안요청서에 명 시되지 않 은 사항에 대해 서는 최근 고지된 관련 규정 및 고시를 준용함
# -수요기관 위임발주 및 S/W 분 리발주 사업의 경우 본 사업 이 외 사업 에 대한 사유로 인해 사업기간이 중단 등 조정 될 수 있 음
# -본 사업은 20 억원미만 사업으로「대기업인 소프트웨어 사업자가 참 여 할 수 있는 사업금액의 하한 ( 과 학 기술정보통신부 고시 ) 」고시를 준수하며 , 대기업 및 중 견 기업은 입찰에 참 여할 수 없음
# -본 사업은「소프트웨어 진흥법」제 48 조 제 4 항 , 「독점규제 및 공정거 래 에 관한 법률」제 31 조에 따라 ' 상 호 출자제한기업 집 단소속회사 ' 는 입찰에 참 여할 수 없음
# -「국가를 당사자로 하는 계약에 관한 법률 시행령」제 43 조에 따라 본 사업 은 사업자 선정 시 ' 협상에 의한 계약체결방식 ' 우선 적용
# -본 사업은 「소프트웨어 진흥법」제 50 조에 따라 계약당사자가 과업내용 변경으로 인한 계약내용 변경이 필 요한 경우 과업 심 의위원회 개최 요 청할 수 있 음
#
# ## Ⅴ . 입찰 관련 사항 (p.78)
#
# === 청크 24 (340자) ===
# ## 1 입찰 및 낙 찰방식 (p.78)
# □ ( 입찰방식 ) 제한경쟁입찰
# 중소기업자간 경 쟁 * 및 대기업 참 여 사업금액 하한기준 (20 억 ) 대상 ** 사업
# ** ( 근거 ) 「대기업인 소프트웨어사업자가 참 여할 수 있는 사업금액의 하한」 ( 과기부 고시 )
# □ ( 낙 찰자 선정방식) 협상에 의한 계약
# ( 근거 ) 「국가를 당사자로 하는 계약에 관한 법률」 시행령 제 43 조 및 제 43 조의 2
# ( 제안서 평가기준 ) 기술평가 90%, 가격평가 10% 적용
# ( 근거 ) 「협상에 의한 계약체결기준」 ( 기 획 재정부 계약 예 규 )
# ※ 입찰진행 관련 세 부사항은 벤처기업확인기관 입찰공고문에 따 름
#
# === 청크 25 (799자) ===
# ## 2 입찰 참 가자격 (p.78)
# □ 「 국가를 당사자로 하는 계약에 관한 법률 」 시행령 제 12 조에 의한 입찰 참가자격을 갖추고 , 동법 시행령 제 76 조에 의해 부정 당 업체로 입찰 참가 제한을 받 고 있 지 않은 업체
# □ 중소기업제품 구매 촉 진 및 판 로지원에 관한 법률 제 9 조에 의거 직접 생 산 증명 서 ( 정보시스템개발서비스 , 세 부품 명코드 : 8111159901) 를 소지한 자
# □ 「 중소기업제품 구매 촉 진 및 판 로지원에 관한 법률 」 제 9 조 따 른 직접 생 산 확인 증명 서 ( 정보시스템 개발서비스 ) 를 소지한 업체
# □ 본 사업은 추정 금액 20 억 원 미 만 인 사업 으로 써 「 소프트 웨 어 진 흥 법 」 제 48 조의 규정에 따라 대기업 및 「 독점규제 및 공정거 래 에 관한 법률 」 제 14 조에 따라 지정된 상 호출 자제한기업 집단 에 속하는 기업은 참여할 수 없음
# ※ 대기업인 소프트웨어사업자의 참 여 가능 사업금액의 하한
# ※ 중소기업이 대기업이 된지 5 년 이내의 기업 , 상 호 출자제한기업 집 단에 속하지 않 는 중 견 기업 ( 증빙 서류 : 한국소프트웨어산업협회 소프트웨어 신고확인서 )
# ※ 상 호 출자제한기업 집 단 소속기업은 사업금액에 관계 없 이 원칙적으로 공공 SW 사업에 참 여제한 ( 소프트웨어진흥법 제 48 조 제 3 항 )
# □ 공동수 급 업체는 모 두 상기의 입찰 참 가자격을 구비하여야 함
# 공동수 급 업체 구성원은 「 국가를 당사자로 하는 계약에 관한 법률 」 시행령 제 12 조 ( 경 쟁 입찰의 참 가자격 ) 및 동법 시행규칙 제 14 조 (
#
# === 청크 26 (446자) ===
# 입찰 참 가자격 요건의 증명 ) 규정에 저 촉 되지 않아 야 함
# 당사자 간 책 임 , 권리 , 의무관계를 명백히 규정한 ' 공동수 급 표준협정서 ' 를 제출하여야 함
# 공동수 급 체 구성원은 5 개 이하로 구성하며 , 구성원별 계약 참 여 최소 지 분율 은 10% 이상이어야 함
# 공동수 급 의 경우 ' 공동계약 운용요령 ( 기 획 재정부 계약 예 규 제 651 호 , '23.06.16.)' 규정을 적용하며 , 동일업체가 복수의 공동수 급 에 참 여할 수 없음
# □ 하도 급 을 포함한 경우 다 음 사항을 준수해야 함
# 하도 급 사전 승 인
# -본 사업의 하도 급 의 경우 「 소프트웨어 진흥법 」 제 51 조 하도 급 계약 전
# 에 발주기관으로부터 사전 승 인을 받아 야 함
# 하도 급 비 율 제한
# 다만 , 동법 제 51 조 제 3 항 각 호 에 해당하는 경우에는 해당하지 않음
# 재 하도 급은 허용하지 않음
#
# === 청크 27 (661자) ===
# ## 3 입찰시 유의사항 (p.81)
# □ 제안내용에 대한 확인을 위하여 추가자 료 요청 또 는 현 지 실 사를 할 수 있으며 , 입찰 참 가자는 이에 응 하여야 함
# □ 낙 찰자로 결정된 이 후 에 컨 소시 엄 구성원을 변경할 수 없음
# □ 제안서 인력은 컨 소시 엄 구성원의 자사 인력으로 구성하여야 함
# 채 용 예 정 인력인 경우에는 별도로 이를 명 기하고 , 계약체결 전 까 지 채 용 을 완 료 하여야 함
# 적법한 파견 근로자는 자사 인력으로 간주하나 , 원소속사를 반 드 시 명 기 하여야 함
# 컨 소시 엄 소속 외 의 인력을 하도 급 으로 간주하며 , 주관기관의 승 인을 얻 지 못 할 경우에는 컨 소시 엄 구성원의 자사 인력으로 대체하여야 함
# ※ 단 , 상용 S/W, 패키 지 등의 서비스 지원인력 , 외 부 자문인력 등 통상적인 개발인력이 아 닌 경우는 제안서에 명 기하지 말 것 ( 참 여인력에서 제 외 )
# □ 계약상의 사업을 수행함에 있어 부 실 , 조 잡 또 는 부당하게 하거나 , 부정 한 행위를 한 사업자는 향 후 참 여 제한을 받 을 수 있 음
# □ 본 사업의 수행에 필 요한 모든 비용은 가격입찰금액에 포함시 켜 야 함
# □ 사업추진 결과 발 생 한 지식재산권은 수요기관과 공동소유 함
#
# ## Ⅵ . 제안서 작성요령 (p.82)
#
# ## 1 제안서 작성방법 (p.82)
#
# === 청크 28 (276자) ===
# ## □ 제안 서 의 효력 (p.82)
# 제 출 된 제안 서 내용 은 주관사에서 요청하지 않 는 한 수정 ‧ 추가 ‧ 대체할 수 없으며 기재 내용은 실제 와 일치 해 야 함
# 주관사에서 필 요 시 입찰 참 가자에 대하여 추가 제안이 나 추가자료를 요 청할 수 있으며 , 제출된 자 료 는 제안서와 동일한 효 력을 가 짐
# 제안서의 모든 기재사항은 객 관적으로 입 증 할 수 있는 관계 서류를 첨 부 하여 사 실 을 기재하여야 하며 , 허 위 작성한 사 실 이 판명될 경우에는 평 가대상에서 제 외 함
#
# === 청크 29 (799자) ===
# ## □ 제안 서 작성지 침 ( 권장사항 ) (p.82)
# 제출된 제안 서 는 일절 반 환하지 않으며 , 본 제안과 관련된 일체의 소요 비용 은 입찰참가자 부 담 으로 함
# 제안자는 제시된 ' 제안 서 작성 서 식 ' 을 준용하여 작성 하여야 함
# 제안서의 모든 내용은 참고자료 및 근거 자료가 제시 되어야 하며 , 주요 제안내용 에 대하여는 공인된 증빙 자료를 첨 부 해야 함
# 제안서는 제안요청 서 에 기술된 요구사항을 충 분 히 만족 할 수 있 는 방안이 포함 되어야 하며 , 제안요청 내용에 기술된 부문별 요구사항 에 대해서는 보 다 구체 적 이고 상세한 방안을 기 술 해야 함
# 제안서의 내용은 명확한 용어를 사용하여 표현 해야 하며 , 계량화가 가능한 것은 계량화 하여 표기
# 본 제안요청서에 명기되지 아 니 한 사항이라도 본 사업 수행 상 반 드 시 필 요하 다 고 판단 되는 경우에는 사업내용에 반 영 돼 야 하며 , 입찰 금액 에 포 함 한 것 으로 간주
# 제안업체는 제안서의 내용이 허위 또는 이행 불 가능한 내용 으로 작성 된 사실 이 발 견될 경우 일체의 책임 을 져 야 함
# 계약 후 에도 제안서가 본 제안요청의 요구조건과 상이하 게 작성되 었다
# 고 판 명 될 경우 는 계약자 부 담으 로 사업내용에 포함 해야 함
# 제출되는 서류가 사본 인 경우 ' 사실과 상위 없음 ' 음 명기 하여 법인 또 는 조 달 청 사용인 감으 로 날 인 하여 제출해야 함
# 제안서에 누락 된 내용 이나 추진방향 변경 시 향후 사업의 추진에 반드 시 필 요 하다고 인지 될 경우에는 사업 발주기관의 요청 으 로 수정할 수 있음
# 제출된 서류는 일체
#
# === 청크 30 (168자) ===
# 반 환하지 않으며 , 사업결과에 따 른 시스템 및 산 출 물 의 소유권 은 계약 당 사자 간 공동 으 로 소유함
# □ ( 개발 SW 의 공동 활용 ) 본 사업을 통해 개발되는 소프트웨어는 용역계 약일반조건 제 56 조 ( 계약목적 물 의 지식재산권 귀속 등 ) 에 따라 타 기관과 공 동 활 용하지 않음
#
# === 청크 31 (761자) ===
# ## 2 제안서 평가방법 (p.85)
#
# ## □ 기 술 평가 (p.85)
# 총 점 100 점 기준으로 각 평가항목에 대한 점수를 합산하여 평가
# 「 소프트 웨 어기 술 성평가기준 」 제20219 8 호 (과 학 기 술 정보통신부 고시)를 기준
# 기술평가항목 및 배점기준은 ' 기술성 평가 기준표 ' 에 의함
#
# ## 가격평가 (p.85)
# 「 협상에 의한 계약체결 기준 」 제 656호 (기 재 부 계약예 규 )에 따름
#
# ## 종합평가 (p.85)
# 종합평가점수 산출
# -종합 평가점수 = 기술 평가점수 + 입찰가격
# 평가점수
# 평가비 율 : 기 술 평가( 9 0 % ), 가격평가(10 % )
# 평가점수 결과는 소수점 다 섯째 자리에서 반 올 림
#
# ## □ 협상 적 격자 선정 및 협상 순서 (p.85)
# 협상순서는 협상적격자의 기술능력평가점수와 입찰가격평가 점수를 합산하 여 합산점수의 고득점 순에 따라 결정
# -협상이 성 립 된 때 에는 다 른 협상적격자와의 협상은 실 시하지
# -모든 협상적격자와 협상 결 렬 시 재공고 입찰에 부 칠 수 있
#
# ## □ 동점시 처리방 침 (p.86)
# 종합평가점수가 동점인 경우 기술평가 점수가 높은 업체
# 기술평가점수도 동일한 경우 기술능력의 세 부평가항목 중 배점이 큰 평 가항목에서 점수가 높은 업체
#
# ## ◦ 정성평가 (100 점 ) (p.87)
#
# ## [ 기 술 성 평가 기준표 ] (p.87)
#
# ## Ⅰ . 제안개요 (p.91)
#
# ## Ⅱ . 일 반 현황 (p.91)
# 제안업체 일반 현황
# 제안업체의 조직 및 인원
# 수행조직 및 업무 분 장
#
# === 청크 32 (710자) ===
# ## Ⅲ . 전 략 및 방법 론 (p.91)
# 사업 이해도
# 추진전 략
# 적용기술
# 표준 프 레 임 워크 적용
# 개발 방법 론
#
# ## Ⅳ . 기 술 및 기능 (p.91)
# 시스템 장비구성 요구사항
# 기능 요구사항
# 보안 요구사항
# 데이터 요구사항
# 시스템 운영 요구사항
# 제약사향
#
# ## Ⅴ . 성능 및 품질 (p.91)
# 성능 요구사항
# 품질 요구사항
# 인터 페 이스 요구사항
# 테 스트 요구사항
#
# ## Ⅵ . 프로 젝 트 관리 (p.91)
# 관리방법 론
# 관리역 량
# 일정계 획
# 개발장비
#
# ## Ⅶ . 프로 젝 트지원 (p.91)
# 품질보 증
# 시 험 운영
# 교육 훈 련
# 유지보수
# 기 밀 보안
# 비상대 책
#
# ## Ⅷ . 기 타 사항 (p.91)
#
# ## 4 제안서 세 부 작성지침 (p.92)
#
# ## Ⅶ . 별지서식 및 붙임 (p.94)
#
# ## □ 별지 서 식 (p.94)
# < 별지서식 1 호 > 2024 년 벤처확인종합관리시스템 기능 고도화 용역사업 제안서 표지
# < 별지서식 2 호 > 제안요청서 수용 여부 참 조표
# < 별지서식 3 호 > 일반 현황 및 연 혁
# < 별지서식 4 호 > 자본금 및 매출액 현황
# < 별지서식 5 호 > 사업수행 조직도
# < 별지서식 6 호 > 기술적용계 획 표
# < 별지서식 7 호 > 소프트웨어사업 하도 급 계 획 서
# < 별지서식 7-1 호 > 하도 급 적정성 판 단 자기평가표
# < 별지서식 8 호 > 공동수 급 표준협정서 ( 공동이행방식 )
# < 별지서식 9 호 > 합의 각 서
#
# === 청크 33 (537자) ===
# ## □ 붙임 자료 (p.94)
# [ 붙임 1] 청 렴 서약서
# [ 붙임 2] 근로자 권리보 호 이행 서약서
# [ 붙임 3] 보안서약서
# [ 붙임 4] 정보화 용역사업 보안특약
# [ 붙임 5] 소프트웨어 개발사업의 적정 사업기간 종합 산정서
# [ 붙임 6] 소프트웨어 영향평가 검 토 결과서
#
# ## ( 별지 제 1 호 서식 ) 제안서 표지 (p.95)
# 접수 번호
#
# ## 2024 년 벤처확인종합관리시스템 기능 고도화 용역사업 (p.95)
#
# ## -용역 제안 서 - (p.95)
# 관련 규정에 따라 『 복수의결권 및 스톡옵션 시스템 구축 고도화 용역사업 』 을 성 실히 수행하고자 동 제안서를 제출합 니 다 .
#
# ## 202 년 월 일 (p.95)
# 회 사 명
# 대표이사
# : ( 직인 )
#
# ## 벤처기업확인기관장 귀 하 (p.95)
#
# ## 제안요청 서 수용여부 참조표 (p.96)
# 주 ) 1. ' 제안요청서 수용여부 참 조표 ' 는 제안서 목차 다 음 쪽 에 작성
#
# ## 일 반 현황 및 연 혁 (p.97)
#
# ## 자본 금 및 매 출액 현황(최 근 3년) (p.98)
# 천 원 )
#
# === 청크 34 (781자) ===
# ## 주요사업실 적 (p.98)
# ※ 연도순으로 기재하며 , 제안과제 와 유사하 거나 동일한 업무영역이 나 사업 형 태에 관한 것 만 기재한다 . 단 , 현 재수행중인 사업은 비고란에 현 재수행중임을 명 시한다 .
# ※ 하도 급 은 수요처가 승 인한 경우에 한하여 작성하며 비고란에 원도 급 회사를 기재한다 .
# ※ 공동도 급 계약일 경우에는 계약금액란에 제안업체의 지 분 만을 기재한다 .
# ※ 사업별 사용 개발방법 론 을 비고에 기 재 한 다 .
# ※ 한국소프트웨어산업협회에서 발급하는 이행실적확인서를 가능한 활용 .
# ※ 실적을 확인할 수 있는 실적증명서 , 계약서 등의 증거서류제출 , 확인이 불가능한 실적은 인정하지 않음
# ※ 실적증명자료는 붙임으로 첨부하여야 하며 실적증명첨부서류에 페이지를 명시하여 주요사업실적 비고란 에 페이지를 표시하여야 함
#
# ## 사업실 적 증 명 서 (p.99)
# ① 민간거래실적은 세금계산서 , 계약서 사본 등 증빙자료를 첨부하여야 합니다 .
# ② 용역이행실적은 입찰공고 시에 제시한 용역범위 및 기준 ( 면적 , 금액 등 ) 등이 조건에 부합되는 실 적에 한하며 , 공동계약으로 이행하였을 경우 비율과 이행실적을 기재하여야 합니다 .
# ③ 이행실적란은 기재 후 투명 접착테이프를 붙여 증명을 받아야 합니다 .
# ④ 발급기관의 담당자 , 전화번호를 반드시 기재하여야 합니다 .
#
# ## 사업수행 조 직 도 (p.100)
# 사업관리자
# (PM)
# 주 1) 부문별 책임자를 명시
# 주 2) 부문별 기술자 기재순서는 평가 시 참고 될 수 있도록 서열별로 전문 엔지니어의 직 위 , 성명을 기재
#
# === 청크 35 (787자) ===
# ## ( 별지 제 6 호 서식 ) 기술적용계획표 (p.101)
#
# ## ∎ 법률 및 고시 (p.101)
#
# ## ∎ 서비스 접근 및 전 달 분 야 (p.102)
#
# ## ∎ 인터 페 이스 및 통합 분 야 (p.103)
#
# ## ∎ 플 랫폼 및 기반구조 분 야 (p.103)
#
# ## ∎ 요소기술 분 야 (p.105)
#
# ## ∎ 보안 분 야 (p.106)
# DDos
# 무선침입방지
# 접근통제
# 유출방지
# 매체제어제품
# 접근통제
# - DB
# 소프트웨어기반
# USB(
# 보안약점
# 보안관리
# - CC
# 보안취약점
# 보안약점
# 전자정부
# 보안기능
# ■ 소프트웨어사업 계약 및 관리감독에 관한 지침 [ 별지 제 7 호 서식 ]
#
# ## 소프트웨어사업 하도급 계획서 (p.109)
#
# ## 하도 급 예정 계획 (p.109)
#
# ## 직 접 물품 구매 예정 계획 (p.109)
# -물 품의 설 치 및 유지ㆍ관리 , 「소프트웨어 진흥법」시행령 제 48 조제 1 항 각 호 의 신기술 또 는 전문기술등을 하도 급 에 포함하여 작성
# -직접 물 품 구매 예 정 계 획 은 수 급 인 ( 계약상대자 ) 이 직접 구매하는 물 품에 한함
# -하도 급 예 정액 비 율 합계 50% 초 과 예외 사유
# -계약금액 (C) = 하도 급 예 정액 (A) + 물 품 구매 예 정액 (B) + 수 급 인 자체 수행액
# 「소프트웨어사업 계약 및 관리감독에 관한 지침」제 19 조에 따라 소프트웨어사업 하도 급 계 획 서를 제출합 니 다 .
# 년 월 일
# 공동수 급 체 구성원 상 호
# ( 서 명 또 는 인 )
# 공동수 급 체 구성원 상 호
# ( 서 명 또 는 인 )
#
# ## 발주기관의 장 귀하 (p.109)
#
# === 청크 36 (398자) ===
# ## 제출서류 (p.109)
# -하도 급 사업수행 계 획 서 ( 하도 급 금액 산출내역서 및 사업추진 일정표 포함 ) 각 1 부
# -물 품 공 급 확약서 각 1 부
# ※ 유의사항
# -하도 급 예 정 계 획 이 많아 지 면 이 부족할 경우 별도 서식을 첨 부할 수 있 습 니 다 .
# 210 ㎜× 297 ㎜ ( 백 상지 80g/ ㎡ )
# ( 별지 제 7-1 호 서식 )
#
# ## 1. 계약 내용 (p.110)
# 하도 급 액 : 하도 급 산출내역서상의 소프트웨어사업비
#
# ## 2. 자기평가결과 (p.110)
# 하도 급 계약의 적정성 판 단 세 부기준을 참 고하여 자기평가 실 시
# 하수 급 인의 사업 실 적 증명 서 , 보안 각 서 , 중소기업확인서
#
# ## 하도 급 적 정성 판단 자기평가표 (p.110)
# ( 별지 제 8 호 서식 )
#
# === 청크 37 (798자) ===
# ## 공동수 급 표준협정 서 ( 공동이행방식 ) (p.111)
# 계약건 명 :
# 계약금액 :
# 발주자 명 :
# 제2조 [공동수 급 체] 공동수 급 체의 명칭 , 사업소의 소재지 , 대표자는 다 음 과 같 다 .
# 주사무소소재지 :
# 대 표 자 성 명 :
# 제3조 [공동수 급 체의 구성원] ①공동수 급 체의 구성원은 다 음 과 같 다 .
# ○○○ 회사 ( 대표자
# ○○○ 회사 ( 대표자
# ②공동수 급 체 대표자는 ○○○ 로 한다 .
# 제4조 [효력기간] 본 협정서는 당사자간의 서 명 과 동시에 발 효 하며 , 당해계약의 이행 으로 종결된다 . 다만 , 발주자 또 는 제 3 자에 대하여 당해 계약과 관련한 권리의무 관 계가 남 아 있는 한 본 협정서의 효 력은 존속된다 .
# 제 5 조 [의무] 공동수 급 체의 구성원은 제 1 조에서 정한 목적을 수행하기 위하여 성 실 , 근 면 및 신의를 바탕 으로 하여 필 요한 모든 지식과 기술을 활 용할 것 을 약속한다 .
# 제 6 조 [ 책임 ] 공동수 급 체의 구성원은 발주기관에 대한 계약상의 의무이행에 대하여 연대하여 책 임을 진다 .
# 제8조 [ 거 래계 좌 ] 예 규「지방자치단체 공동계약 운영요령」 Ⅲ -7 대가의 지 급 규정에 정한 바 에 의한 선금 , 기성대가 등은 다 음 계 좌 로 지 급받 는다 .
# , 시공 정
# ○○○ 회사 ( 공동수 급 체대표자 ) : ○○ 은행 , 계 좌 번호 ○○○ , 예 금주
# 제 9 조 [구성원의 출 자비 율 ] ①공동수 급 체의 출자비 율 은 다 음 과 같 이 정한다 .
# ○○○ : %
# ○○○ : %
# 발주기관과의 계약내용 변경에 따라 계약금액이 증 감되 었 을
#
# === 청크 38 (799자) ===
# 경우
# 공동수 급 체의 구성원 중 파 산 , 해산 , 부도 등의 사유로 인하여 당 초 협정서의 내용대로 계약이행이 곤 란한 구성원이 발 생 하여 공동수 급 체의 구성원 연 명 으로 출자 비 율 의 변경을 요청한 경우
# ③ 현 금이 외 의 출자는 시가를 참 작 , 구성원이 협의 평가하는 것 으로 한다 .
# 제10조 [ 손익 의 배분] 계약을 이행한 후 이 익 또 는 손실 이 발 생 하 였 을 경우에는 제 9 조에서 정한 비 율 에 따라 배당하거나 분담 한다 .
# 제11조 [권리, 의무의 양 도제한] 구성원은 이 협정서에 의한 권리의무를 제 3 자에게 양 도할 수 없 다 .
# 한다 .
# 발주자 및 구성원 전원이 동의하는 경우
# 파 산 , 해산 , 부도 기타 정당한 이유 없 이 당해 계약을 이행하지 아니 하여 공동수 급 체의 다 른 구성원이 발주자의 동의를 얻 어 탈퇴 조치를 하는 경우
# 공동수 급 체의 구성원중 파 산 , 해산 , 부도 기타 정당한 이유 없 이 당해 계약을 이 행하지 아니 하여 시행령 제 92 조제 1 항제 6 호 의 규정에 의하여 입찰 참 가자격제한조치 를 받 은 경우
# 약을 이행하여야 하며 , 연대보 증 인이 없 거나 연대보 증 인이 계약을 이행하지 않 는 경 우에는 잔 존구성원이 발주기관의 승 인을 얻 어 새 로운 구성원을 추가하는 등의 방법 으로 당해요건을 충족하여야 한다 .
# ④ 탈퇴 하는 자의 출자금은 계약이행 완 료 후 제 10 조의 손실 을 공제한 잔 액을 반 환 한다 .
# 제13조 [하자 담 보 책임 ] 공동수 급 체가 해산한 후 당해공사에 관하여 하자가 발 생 하 였 을 경우에는 연대하여 책 임을
#
# === 청크 39 (199자) ===
# 진다 .
# 제14조 [운영위원회] ①공동수 급 체는 공동수 급 체의 구성원을 위원으로 하는 운영위원 회를 설 치하여 계약이행에 관한 제반사항을 협의한다 .
# ②이 협정서에 규정되지 아니 한 사항은 운영위원회에서 정한다 .
# 위와 같 이 공동수 급 협정을 체결하고 그 증 거로서 협정서 ○ 통을 작성하여 공동수 급 체의 구성원이 기 명날 인하여 각 자 보관한다 .
#
# === 청크 40 (442자) ===
# ## 202 년 월 일 (p.113)
#
# ## 합 의 각 서 (p.114)
#
# ## [ 붙임 1] 청 렴서 약 서 (p.115)
#
# ## 청 렴서 약 서 (p.115)
# 입찰가격의 유지나 특정인의 낙 찰을 위한 담 합을 하거나 다 른 업체와 협정 , 결의 , 합의하여 입찰의 자유경 쟁 을 부당하게 저 해하는 일체의 불 공정한 행위를 않 겠습 니 다 .
# 회사 임ㆍ직원이 관계 공무원에게 금품 , 향 응 등을 제공하거나 담 합 등 불 공정 행위를 하지 않 도록 하는 회사 윤 리 강 령과 내부비리 제보자에 대해서도 일체의 불 이 익 처 분 을 하지 않 는 사규를 제정 토 록 노 력하 겠습 니 다 .
#
# ## 년 월 일 (p.115)
# 서 약 자 :
# ○○○ 회사 대표 ○○○ ( 인 )
#
# ## 벤처기업확인기관장 귀 하 (p.115)
#
# ## [ 붙임 2] 근 로자 권리보 호 이행 서 약 서 (p.116)
#
# === 청크 41 (595자) ===
# ## 근로자 권리보 호 이행 서약서 (p.116)
# 당사는 근로자가 인간으로서의 존 엄 과 가치 및 자유와 권리를 누 릴 수 있도록 인권보 호 를 위한 경영정 책 ( 관련 법령에 의거 취업규칙 작성 · 신고 등 ) 을 확 립 하도 록 노 력하 겠습 니 다 .
# 근로자에게 노 동력 착 취적인 언 어․ 신체적 접 촉 과 성적 강압 등과 같 은 행위 , 정 신적 강압 이나 언 어 폭 력 등은 허 용하지 않 고 , 근로자의 개인정보나 사 생활 에 대 한 권리를 존중하 겠습 니 다 .
# 근로자에게 관련 규정에 부합한 노 동시간 준수 및 휴 일 제공으로 근로자 자신과 가족이 건 강 한 생활 수준을 누 릴 수 있게 하며 , 여성근로자의 모성은 특별한 도 움 을 받 을 권리를 보장하 겠습 니 다 .
# 당사는 근로 중 근로자에게 발 생 한 문제에 대하여「근로기준법」 , 「산업재해보상보 험 법」 , 「국민건 강 보 험 법」등 관련 법령을 준수하여 필 요한 조치를 취하며 이를 위 반할 시에는 관계법령에 따라 책 임지 겠습 니 다 .
# 계 약 상대 상 호 :
# 주 소 :
# : ( 인 )
#
# ## 벤처기업확인기관장 귀 하 (p.116)
#
# ## [ 붙임 3] 보안 서 약 서 (p.117)
#
# === 청크 42 (738자) ===
# ## 보 안 서 약 서 (개인용) (p.118)
# 본인은 벤처기업확인기관의 사업을 수행함에 있어 다 음 사항을 준수 할 것 임을 엄숙히 서약합 니 다 .
# ◎ 사 업 명 :
# ◎ 사업기간
# : 202
# 년 월 일 ~ 202 년 월 일
# 본인은 상기 사업을 수행함에 있어 이에 관련된 소관업무가 벤처기 업확인기관의 보안에 관한 기 밀 임을 인정한다 .
# 서 약 자
# 직 급 :
# ( 인 ) 생 년 월 일 :
# 주 소 :
# 연 락 처 :
#
# ## [ 붙임 4] 정보화 용역사업 보안특약 (p.119)
#
# ## 보안 특약사항 (p.119)
# ① 사업자는 벤처기업확인기관의 보안정 책 을 위반하 였 을 경우 [ 별표 1] 의 위규처 리 기준에 따라 위규자 및 관리자를 행정 조치하고 이로 인해 발 생 된 모든 피 해보상은 계약업체에서 책 임진다 .
# ④ 사업자는 사업 최종산출 물 에 대해 정보보안 전문가 또 는 전문 보안점검 도구 를 활 용하여 보안취약점을 점검 , 도출된 취약점에 대한 개선을 완 료 하고 그 결 과를 제출해야 한다 .
# ⑤ 필 요에 따라 발주기관에서는 사업자의 사업수행과정 전반 ( 사업수행 인력 포함 ) 에 대하여 보안감사 및 점검을 수행할 수 있으며 , 사업자는 이에 성 실 이 응 하 여야 한다 .
# [ 별표 1] 사업자 보안위규 처리기준
# [ 별표 2] 보안위약금 부과 기준
# [ 별표 3] 누출금지 대상 정보
#
# ## [ 별표 1] 사업자 보안위 규 처리기준 (p.120)
#
# ## [ 별표 2] 보안위약 금 부과 기준 (p.122)
#
# === 청크 43 (552자) ===
# ## 보안 위약 금 부과 기준 (p.122)
# □ 위규 수준별로 A~D 등 급 으로 차등 부과
# 위규 수준은 [ 별표 1 호 ] 참 고
# 사업 종 료 시 지출금액 조정을 통해 위약금 정산
#
# ## [ 별표 3] 누출금 지 대상 정보 (p.123)
#
# ## 누 출금지 대상정보 (p.123)
# 기관 소유 정보시스템의 내 ․ 외 부 IP 주소 현황
# 세 부 정보시스템 구성 현황 및 정보통신 망
# 사용자계정ㆍ비 밀번호 등 정보시스템 접근권한
# 정보통신 망 취약점 분석 · 평가 결과
# 용역사업 결과 물 및 프로 그램 소스
# 국가용 보안시스템 및 정보보 호 시스템 도입 현황
# 침입차단시스템ㆍ방지시스템 (IPS) 등 정보보 호 제품 및 라우터ㆍ스위치 등 네 트 워 크 장보
# 「 공공기관의 정보공개에 관한 법률 」 제 9 조제 1 항에 따라 비공개 대상 정보로 분 류 된 기관의 내부문서
# 「 개인정보보 호 법 」 제 2 조제 1 호 의 개인정보
# 「 보안업무규정 」 제 4 조의 비 밀 및 동 시행규칙 제 7 조제 3 항의 대 외 비
# 그 밖 에 중소벤처기업부 , 벤처기업확인기관장이 공개가 불 가하다고 판 단한 자 료
#
# === 청크 44 (469자) ===
# ## [ 붙임 5] 소프트웨어 개발사업의 적정 사업기간 종합 산정서 (p.123)
# le maa sermer.
# CALLALON 2UEE VIEZ MON
# 718/
# merin allu
# 39 92
# 2024 # 32159
# PI 81
# [ 붙임 6] 소프트웨어 영향평가 검 토 결과서
# 1 7281
# 4791 9]
# 491 8
# (55=
# 78 11 8
# 99 71 4777(91:
# E 771 49
# 300 g
# oF 100,000 g
# 22E0/4
# 194>›
# 9d 08
# (x79:
# 78 52
# (7Дe 28)
# +as sa a (42 -
# 03 9]
# 15 gl
# [ 별표 1] 산 출물 목 록
#
# ## □ 사업관리 ( 모든 사업유 형 에 공통적용 , 전 산출 물 ' 필 수 ' 제출 ) (p.126)
#
# ## □ SW 개발 ( 사업특성을 반영하여 선택산출 물 을 가감하며 타 산출 물 추가 가능 ) (p.126)
#
# ## [ 별표 2] 소프트 웨 어 보안약점 기준 (p.128)
#
# === 청크 45 (470자) ===
# ## 소프트웨어 보안약점 기준 1) (p.128)
# 입력데이터 검증 및 표현 : 프로 그램 입력 값 에 대한 검 증 누락 또 는 부적절한 검 증 , 데이 터의 잘못 된 형 식지정으로 인해 발 생 할 수 있는 보안약점
# 1) 소프트웨어 보안약점 기준은 소프트웨어 개발 시 반 드 시 배제해야 하는 필 수 보안약점 진 단항목으로 , 상 세 한 내용은 'SW 개발보안 가이 드 ' 를 참 고
# 3. 시간 및 상태 : 동시 또 는 거의 동시 수행을 지원하는 병렬 시스템 , 하나 이상의 프로 세 스가 동작
# 되는 환 경에서 시간 및 상 태 를 부적절하게 관리하여 발 생 할 수 있는 보안약점
# 코드 오 류 : 타입변 환 오류 , 자원 ( 메 모리 등 ) 의 부적절한 반 환 등과 같 이 개발자가 범 할 수 있는 코 딩 오류로 인해 유발되는 보안약점
# 캡슐 화 : 중요한 데이터 또 는 기능성을 불 충 분 하게 캡 슐 화 하 였 을 때 , 인가되지 않 은 사용
#
# === 청크 46 (799자) ===
# ## 자에게 데이터 누 출이 가능해지는 보안약점 (p.131)
# [표]
# 추진과제 | 세부 실행내용
# 추가사항 | ⑦ 타 기관 API 연계를 통한 정보 확인 ⑧ 입력정보 & 서류제출 간소화 , 정보보안 솔루션 적용
# [표]
# 구 분 | 역 할
# 중소벤처기업부 | ㆍ사업 총괄 운영ㆍ관리 감독
# 벤처기업확인기관 | ㆍ벤처확인제도 운영기관 ㆍ사업계 획 수 립 , 제안요청서 작성 ㆍ사업관리 및 검사 ㆍ사업수행 및 운영업무
# 자문위원 | ㆍ시스템 구축 및 법률 자문 등
# 운영 유지관리 업체 | ㆍ벤처확인종합관리시스템 운영 유지관리 업무 수행 中
# [표]
# 차트 툴 | 1 식 | SB Chart v2
# PDF 뷰 어 | 1 식 | ePapyrus StreamDocs v1.0
# PDF 변 환 | 1 식 | ePapyrus PDF Gateway v8.0
# PKI 공인인 증 | 1 식 | MagicLine v4.0
# 키 보 드 보안 | 1 식 | TouchEn nxKey v1.0-Explorer, TouchEn nxKey v1.0_Multi-Browser
# 업로 드 | 1 식 | RAON K Upload 2018
# 검 색엔 진 | 1 식 | Konan Search 5
# 그 리 드 툴 | 1 식 | SBGrid v2.0
# 위변조방지 | 1 식 | e-Page SAFER V2.5 Basic Package
# 화 면캡쳐 방지 | 1 식 | e-Page SAFER Web DRM Pack for Cross OS V2.5 Basic package
# [표]
# 항 목 | 내 용
# ① 발행자격 및 보유자격 | ① 발행자격 및 보유자격
# 발행자격 | 비상장 주식회사인 벤처기업 에 한정
#
# === 청크 47 (799자) ===
# ② 발행요건 | ② 발행요건
# ③ 발행한도 | ③ 발행한도
# 존속기간 | 발행 후 최대 10년 한도로 유 효 기간을 정관에 규정
# 의결권 수 | 1 주당 최대 10개 한도로 기업이 정관에 규정
# ④ 절차・방법(정관변경→주총결의) | ④ 절차・방법(정관변경→주총결의)
# [표]
# 항 목 | 내 용
# 기 타 | 허위 또는 부정한 방법 으로 발행 시 그 발행일에 보통주식 발행으로 간주
# ⑥ 복수의결권 행사 제한 | ⑥ 복수의결권 행사 제한
# ⑦ 특례 | ⑦ 특례
# 벤처기업이 었던 기업의 특 례 | 벤처기업의 지위를 상실하는 경우에도 유효 * 중소기업의 범 위를 넘 어서 면 서 벤처기업의 지위를 상 실 하는 경우에도 유 효
# 공개매수 및 주식 대 량 보유 보고 특 례 | 복수의결권 발행 벤처기업은 자본시장법상 공개매수 및 대량보유 보고 시 의결권 기준 으로 적용
# ⑧ 발행의 보고 및 고시 | ⑧ 발행의 보고 및 고시
# 발행보고 | 복수의결권 발행내용 및 중요사항 변경시 중소벤처기업부에 보고
# 본점 등 공시 | 복수의결권 발행기업은 복수의결권주식 발행 내역 등을 본점과 지점에 비치 및 공시
# 관보고시 | 중소벤처기업부는 복수의결권 발행기업 명 단 , 주요사항 변경 등을 관보에 고시
# ⑨ 허위발행죄 및 과태료 | ⑨ 허위발행죄 및 과태료
# 위반행위 인지 ‧ 신고 | 중소벤처기업부는 규정에 위반한 혐 의가 있을 경우 직권으로 조사 , 누 구든지 위반한 사 실 이 있다고 인정할 때 에 중소벤처기업부에 신고
# 허 위발행 죄 | 허 위 또 는 부정한 방법으로 복수의결권 발행한 자는 10 년 이하 징 역 또 는 5 천 만원 이하 벌 금
# [표]
# 구 분 | 항 목
#
# === 청크 48 (798자) ===
# | 설 명
# 업무 담 당자 | 접수 번호 | 복수의결권주식 고유 접수 번호
# 업무 담 당자 | 접수일자 | 복수의결권주식 발행 접수일자
# 업무 담 당자 | 처리일 | 복수의결권주식 발행 승 인 처리일자
# 업무 담 당자 | 처리기간 | 복수의결권주식 발행 절차 소요기간
# 복수의결권주식 보고자 | 업체 명 | 벤처확인서 정보 연동
# | 대표자 | 벤처확인서 정보 연동
# | 사업자등록 번호 | 벤처확인서 정보 연동 및 조회
# | 법인등록 번호 | 벤처확인서 정보 연동 및 조회
# | 벤처기업확인서 발 급번호 | 벤처확인서 정보 연동 및 조회
# | 전화 번호 | 회사 대표 연 락 처
# | 전자우 편 | 보고자 전자우 편
# | 소재지 | 벤처확인서 정보 연동 또 는 수기 입력
# | 복수의결권주식을 받 은자의 성 명 및 발행 수 량 | 창업주 , 공동창업주 선택을 통한 성 명 , 발행 수 량 기 재
# | 복수의결권주식의 발행일자 |
# | 복수의결권주식의 의결권 수 창업주 보유 보통주 납 입 여부 |
# | 전 환 일자 | 복수의결권주식이 보통주로 전 환 된 경우 기재
# | 전 환 사유 | 복수의결권주식이 보통주로 전 환 된 경우 기재
# | 투 자일자 | 복수 입력 가능
# | 투 자유치금액 ( 특수관계인 포함 ) | 복수 입력 가능
# | 투 자유치금액 ( 특수 관계인 제 외 ) | 복수 입력 가능
# | 투 자 전 창업주 지 분율 | 복수 입력 가능
# | 투 자 후 창업주 지 분율 | 복수 입력 가능
# | 합계 | 투 자유치금액 및 투 자 후 창업주 지 분율
# | 복수의결권주식 발행 , 변경 | 발행 , 변경에 따 른 접수 번호 별도 관리
# | 보고서 제출 년 / 월
#
# === 청크 49 (800자) ===
# / 일 | 보고서 신청일자 = 접수일자
# [표]
# 보고인 성 명 | 복수의결권주식 발행 신청인의 휴 대 폰 인 증 정보
# 서 명 |
# 첨 부 파 일 | 제출된 첨 부서류
# [표]
# 사 후 변경의 유 형 | 전환 여부
# 상 속 또는 양 도 |
# 창업주의 이사 사 임 | 즉 시 전환
# 공시대상기업 집단 포함 |
# 상장 | 상장 후 최대 3년 까 지 유 효
# 벤처기업 지위 상실 | 이미 발행된 복수의결권주식 존속 기한 까 지 계 속 유 효
# [표]
# 스톡옵션 | 부여주식 | 주식 행사
# [표]
# 분 류 기준 | 세부 내용 | 요구 사항수
# 기능 요구사항 (SFR, System Function Requirement) | - 목표시스템이 반 드 시 수행하여야 하거나 목표 시스템을 이용하여 사용자가 반 드 시 수행할 수 있어야 하는 기능 ( 동작 ) 에 대하여 기술 | 38
# 시스템장비구성 요구사항 (ECR, Equipment Composition Requirement) | - 목표 사업 수행을 위해 필 요한 하 드 웨어 , 소프트 웨어 , 네 트 워크 등의 도입 장비 내역 등 시스템 장비 구성에 대한 요구사항을 기술 | 5
# 보안 요구사항 (SER,Security Requirement) | - 정보 자산의 기 밀 성과 무결성을 확보하기 위해 목표시스템의 데이터 및 기능 , 운영 접근을 통 제하기 위한 요구사항을 기술 | 9
# 프로 젝 트 관리 요구사항 (PMR, Project Management Requirement) | - 프로 젝 트의 원 활 한 수행을 위한 관리 방법 및 추진 단계별 수행방안에 대한 요구사항을 기술 | 10
# 프로 젝 트 지원 요구
#
# === 청크 50 (800자) ===
# 사항 (PSR, Project Support Requirement) | - 프로 젝 트의 원 활 한 수행을 위해 필 요한 지원 사항 및 방안에 대한 요구사항을 기술 | 9
# 합 계 | 합 계 | 113
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-001
# 요구사항 명 칭 | 요구사항 명 칭 | 사용자 인 증 기능 구 현
# 요구사항 상세설명 | 정의 | 시스템 기업 / 사용자 인 증 기능 구 현
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-002
# 요구사항 명 칭 | 요구사항 명 칭 | 회원가입
# 요구사항 상세설명 | 정의 | 벤처확인종합관리시스템 회원통합
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-003
# 요구사항 명 칭 | 요구사항 명 칭 | 중소기업확인서
# 요구사항 상세설명 | 정의 | 복수의결권주식 발행보고 및 스톡옵션 부여신고 前 중소기업여부 확인
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | SFR-004
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 비상장 여부 조회
# 요구사항 상세설명 정의 | 복수의결권주식 발행보고 및 스톡옵션 부여신고 前 비상장 여부 조회
# 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-005
# 요구사항 명 칭 | 요구사항 명 칭 | 벤처기업 여부 조회
# 요구사항 상세설명 | 정의 |
#
# === 청크 51 (798자) ===
# 복수의결권주식 발행보고 및 스톡옵션 부여신고 前 벤처확인정보 연동
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-006
# 요구사항 명 칭 | 요구사항 명 칭 | 요건 조회 확인 Dashboard
# 요구사항 상세설명 | 정의 | 복수의결권 , 스톡옵션 요건 가능 여부를 공개
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-007
# 요구사항 명 칭 | 요구사항 명 칭 | 복수의결권 메뉴 생 성
# 요구사항 상세설명 | 정의 | 복수의결권주식 발행보고 / 변경보고 소개 , 제도안내 등
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 | 고유 번호 | SFR-008
# 요구사항 분 | 류 | 기능 요구사항
# 요구사항 | 명 칭 | 복수의결권주식 발행보고 / 변경
# | 정의 | 복수의결권주식 발행보고 / 변경 기능
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | SFR-009
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 복수의결권주식 발행보고 / 변경 보완
# 요구사항 상세설명 정의 세부내용 | 복수의결권주식 발행보고 / 변경 보완 ❍ 기업 복수의결권 보고 내역 접수 후 보완 요청 기능 구 현
# [표]
# 요구사항 고유 번호 | SFR-010
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 복수의결권주식 발행보고 승 인
# 정의 | 복수의결권주식 발행보고 / 변경에 대한 최종 승 인 , 반
#
# === 청크 52 (800자) ===
# 려 기능
# 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출
# [표]
# 요구사항 고유 | 번호 | SFR-011
# 요구사항 | 분 류 | 기능 요구사항
# 요구사항 | 명 칭 | 복수의결권주식 발행보고 / 변경 공시
# 요구사항 상세설명 | 정의 | 복수의결권주식 발행보고 및 변경 공시 페 이지 구 현
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-012
# 요구사항 명 칭 | 요구사항 명 칭 | 권한 부여
# 요구사항 상세설명 | 정의 | 복수의결권 , 스톡옵션 , 성과조건부주식 권한 관리 기능
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-013
# 요구사항 명 칭 | 요구사항 명 칭 | 복수의결권 API
# 요구사항 상세설명 | 정의 | 중소기업 , 대기업 , 중 견 기업 편 입 조회 (API)
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 | 고유 번호 | SFR-014
# 요구사항 | 분 류 | 기능 요구사항
# 요구사항 | 명 칭 | 복수의결권주식 허 위발행 신고
# 상세설명 | 정의 | 복수의결권주식 허 위발행 신고기능 구축
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | SFR-017
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 백 오 피 스 구축
# 정의 | 복수의결권 , 스톡옵션 관리업무 시스템 구축
# 산 출 정보 | 요구사항정의서 , 프로 그램 명세
#
# === 청크 53 (799자) ===
# 서 , 개발 산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-018
# 요구사항 명 칭 | 요구사항 명 칭 | 시스템 구축 기능 분석
# 요구사항 상세설명 | 정의 | 시스템 구축 기능 분석
# 산 출 | 정보 | 요구사항정의서 , 프로 그램 명세 서 , 개발 산출 물
# [표]
# 요구사항 고유 번호 | | SFR-019
# 요구사항 명 칭 | 요구사항 명 칭 | 정보수 집 동의 절차
# 요구사항 상세설명 | 정의 | 복수의결권 , 스톡옵션 정보수 집 에 대한 동의
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-020
# 요구사항 명 칭 | 요구사항 명 칭 | 출력보고 기능
# 요구사항 상세설명 | 정의 | 복수의결권 , 스톡옵션 출력 기능 구 현 ( 리포 팅툴 )
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-021
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 부여신고
# | 정보 |
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-022
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 부여신고 보완 / 반 려
# 요구사항 상세설명 | 정의 | 스톡옵션 부여신고 보완 / 반 려
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-023
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 통보
# 요구사항 상세설명 | 정의 | 스톡옵션부여 통보 및 신고 건에 대한 취
#
# === 청크 54 (799자) ===
# 소
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-024
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 자 료실
# 요구사항 상세설명 | 정의 | 스톡옵션 자 료실
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | SFR-025
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 스톡옵션 부여 통계
# 정의 세부내용 | 스톡옵션 부여 통계 / 분석
# 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-026
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 권한
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | SFR-027
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 스톡옵션 부여 배정
# 요구사항 상세설명 정의 세부내용 | 스톡옵션 부여 승 인을 위한 신청 배정
# 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-028
# 요구사항 | 분 류 | 기능 요구사항
# 요구사항 | 명 칭 | 벤처확인 변경 정보
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 | 고유 번호 | SFR-029
# 요구사항 명 칭 | 요구사항 명 칭 | 스톡옵션 부여 확인
# 요구사항 상세설명 | 정의 | 스톡옵션을 주식 부여 받 은 대상자 정보 확인 기능
# 산 출 | 정보 | 요구사항정의서
#
# === 청크 55 (799자) ===
# , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 | 번호 | SFR-030
# 요구사항 분 | 류 | 기능 요구사항
# 요구사항 | 명 칭 | 스톡옵션 부여취소 철회
# 요구사항 상세설명 | 정의 | 스톡옵션 부여신고가 선행된 이 후 피 부여자에게 기 부여한 스톡옵션을 취소 철 회하는 기능
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-031
# 요구사항 명 칭 | 요구사항 명 칭 | 활 동이력 기록
# 산 출 | 정보 |
# [표]
# 요구사항 고유 번호 | SFR-032
# 요구사항 분 류 | 기능 요구사항
# 요구사항 명 칭 | 시스템 관리
# 요구사항 상세설명 정의 세부내용 | 시스템 권한 설 정 , 긴급 장 애 안내 , 로 그 확인 등 ❍ 벤처확인종합관리시스템 백 오 피 스를 통한 복수의결권주식
# 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-033
# 요구사항 명 칭 | 요구사항 명 칭 | 회원관리 기능
# 요구사항 상세설명 | 정의 | 복수의결권주식 , 스톡옵션주식 , 부여대상자 인원 관리
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-034
# 요구사항 명 칭 | 요구사항 명 칭 | 자 료 안내 기능
# 요구사항 상세설명 | 정의 | 복수의결권주식 , 스톡옵션 매 뉴얼 등 안내
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | | SFR-035
# 요구사항 명 칭 | 요구사항
#
# === 청크 56 (799자) ===
# 명 칭 | 화 면 기 획 및 디 자인
# 요구사항 상세설명 | 정의 | 복수의결권주식 , 스톡옵션 백 오 피 스 ( 업무관리시스템 )
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-036
# 요구사항 명 칭 | 요구사항 명 칭 | 게시 판 기능 구 현
# 요구사항 상세설명 | 정의 | 복수의결권주식 , 스톡옵션 게시 판
# 산 출 정보 | 산 출 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-037
# 요구사항 명 칭 | 요구사항 명 칭 | 성과조건부 주식
# | 정의 | 성과조건부 주식 대민 페 이지
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SFR-038
# 요구사항 명 칭 | 요구사항 명 칭 | 성과조건부 주식 업무시스템
# 요구사항 상세설명 | 정의 | 성과조건부 주식 업무시스템
# 산 출 | 정보 | 요구사항정의서 , 프로 그램명세 서 , 개발산출 물
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | PER-001
# 요구사항 명 칭 | 요구사항 명 칭 | 성능 요구
# 상세설명 | 정의 | 성능 요구사항 일반사항 ,
# 산 출 | 정보 | 사업수행계 획 서 , 성능시 험 결과서
# [표]
# 요구사항 | 고유 번호 | PER-002
# 요구사항 | 분 류 | 성능 요구사항
# 요구사항 | 명 칭 | 업무 응답 시간
# 산 출 | 정보 | 사업수행계 획 서 , 성능시 험 결과서
# [표]
# 요구사항 고유 번호 | 요구사항
#
# === 청크 57 (800자) ===
# 고유 번호 | PER-003
# 요구사항 명 칭 | 요구사항 명 칭 | 웹 페 이지 성능
# 요구사항 상세설명 | 정의 | 웹 페 이지 성능
# 산 출 | 정보 |
# [표]
# 요구사항 고유 | 번호 | PER-004
# 요구사항 | 분 류 | 성능 요구사항
# 요구사항 | 명 칭 | 동시 사용자 접속 수
# 산 출 | 정보 | - 로 그 인된 세 션을 관리할 수 있어야 함 ❍ 동시 사용자 이상 한계 부하 테 스트를 수행하여 안정적인 시스템이 보장되어 야 함
# [표]
# 요구사항 고유 번호 | PER-005
# 요구사항 분 류 | 성능 요구사항
# 요구사항 명 칭 | 시스템 자원 효율 성
# 요구사항 상세설명 정의 세부내용 | 시스템 자원 효율 성 요건 정의 ❍ 벤처 24 클 라우 드 인프라 및 함 (WEB, WAS, DB 서 버 등 ❍ 시스템 자원 (CPU, 메 모리 ,
# 산 출 정보 |
# [표]
# 요구사항 고유 번호 | | ECR-001
# 요구사항 명 칭 | 요구사항 명 칭 | 시스템 장비 도입 공통
# 상세설명 | 정의 | 시스템 장비 도입 공통
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | | ECR-002
# 요구사항 명 칭 | 요구사항 명 칭 | 시스템 통합 아키텍 처 설 계
# 요구사항 상세설명 | 정의 | 시스템 통합 아키텍 처 설 계 보완
# 산 출 | 정보 | 사업수행계 획 서 , 시스템 아키텍 처 설 계서
# [표]
# 요구사항 고유 번호 | | ECR-003
# 요구사항 명 칭 | 요구사항 명 칭 | 라이선스 사항
# 요구사항 상세설명 | 정의 | 라이선스 사항
# 산 출 | 정보 | SW 라이선스 증 서 , 기술확약서
# [표]
# 요구사항 고유 | 번
#
# === 청크 58 (800자) ===
# 호 | ECR-004
# 요구사항 분 | 류 시스템 | 요구사항
# 요구사항 | 명 칭 | 호환 성 및 상 호 운영성
# 요구사항 상세설명 | 정의 | 중소벤처 24 클 라우 드 환 경에서 SW 호환 성 및 운영성
# 요구사항 상세설명 | 세부내용 | ❍ 본 사업에 추가 도입되는 소프트웨어는 Paas-TA 환 경에서 호환 성 및 상 호 운용성을 가 져 야 함 ❍ 성공적인 목표시스템 구축에 필 요한 각 종 물 품은 상 호 간에 통신이 원 활 하고
# 산 출 | 정보 | 기술확약서
# [표]
# 요구사항 | 고유 번호 | ECR-005
# 요구사항 | 분 류 | 시스템 요구사항
# 요구사항 | 명 칭 | 물 품교체
# 요구사항 상세설명 | 정의 | 물 품교체
# 산 출 | 정보 | 기술확약서
# [표]
# 요구사항 고유 번호 | | SIR-001
# 요구사항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 사용자 인터 페 이스 구성
# 산 출 | 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 번호 | | SIR-002
# 요구사항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 웹 호환 성
# 요구사항 상세설명 | 정의 | 웹 호환 성
# 산 출 | 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 번호 | SIR-003
# 요구사항 분 류 | 인터 페 이스 요구사항
# 요구사항 명 칭 | 디 자인
# 요구사항 상세설명 정의 세부내용 | 디 자인 적용 ❍ 화 면 UI 기 획 및 디 자인에 통하여 시행 토 록 함 ❍ 인터 페 이스 개선 및 추가
# 산 출 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 | 번호 | SIR-004
# 요구사
#
# === 청크 59 (800자) ===
# 항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 편 의성
# 요구사항 상세설명 | 정의 세부내용 | 도 움말 ❍ 사용자가 별도의 교육을 기능을 이용할 수 있어야
# 산 출 | 정보 | 사용자 인터 페 이스 설 계서
# [표]
# 요구사항 고유 번호 | | SIR-005
# 요구사항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 메뉴 체계 수 립
# 요구사항 상세설명 | 정의 | 메뉴 체계 수 립 ❍ 시스템에 쉽 게 접근할 수 있도록 직관적이고 , 편 리한 사용성을 제고한 메뉴
# 산 출 | 정보 | 사용자 인터 페 이스 설 계서
# [표]
# 요구사항 고유 번호 | SIR-006
# 요구사항 분 류 | 인터 페 이스 요구사항
# 요구사항 명 칭 | 크 로스 브 라우 징
# 요구사항 상세설명 정의 세부내용 | 다 양 한 브 라우 징 에 최적화 ❍ 시스템의 사용자 인터 페 이용할 수 있도록 하여야 - 윈 도우 웹브 라우 저 2 개 시 ❍ 웹 표준을 적용하여 IE(10,
# 산 출 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 | 번호 | SIR-007
# 요구사항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 파 일 업ㆍ다운로 드
# 요구사항 상세설명 | 정의 세부내용 | 파 일 업ㆍ다운로 드 ❍ HWP, Excel, PDF 등 ❍ HWP, Excel, PDF 등의 - 복수의결권주식 발행보고 서식과 동일하게 구 현
# 산 출 | 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 | 번호 | SIR-008
# 요구사항 분 류 | 인터 페 이스 요구사항 |
# 요구사항 명 칭 | 메 | 시지 제공
# 요구사항 상세설명
#
# === 청크 60 (799자) ===
# | 정의 | 메 시지 제공
# 산 출 | 정보 | 사용자인터 페 이스 설 계서
# [표]
# 요구사항 고유 | 번호 | SIR-009
# 요구사항 | 분 류 | 인터 페 이스 요구사항
# 요구사항 | 명 칭 | 내ㆍ 외 부 시스템 연계
# 요구사항 상세설명 | 정의 | 내ㆍ 외 부 시스템 연계
# 산 출 | 정보 | 사용자인터 페 이스 설 계서
# [표]
# 마 | 데이터 요구사항( D ata R e qu ire m ent)
# [표]
# 요구사항 고유 번호 | DAR-001
# 요구사항 분 류 | 데이터 요구사항
# 요구사항 명 칭 | 데이터 분석 요구사항
# 요구사항 상세설명 정의 | 데이터 분석 요구사항 개 념 정의
# 세부내용 | ❍ 데이터 현황 자 료 산출 및 정보 분석 을 지원 ( 수시 ) 하여야 함
# 산 출 정보 |
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | DAR-002
# 요구사항 명 칭 | 요구사항 명 칭 | 데이터 이관
# 요구사항 상세설명 | 정의 | 스톡옵션 데이터 이관 수 립 및 적용
# 산 출 | 정보 | 데이터이관추진계 획
# [표]
# 요구사항 고유 | 번호 DAR-003
# 요구사항 분 | 류 데이터 요구사항
# 요구사항 명 | 칭 첨 부문서 이관
# 산 출 | 베 이스 분석 / 설 계 산출 물
# 정보 | 데이터
# [표]
# 요구사항 고유 번호 | | DAR-004
# 요구사항 | 분 류 | 데이터 요구사항
# 요구사항 | 명 칭 | 데이터 베 이스 표준화
# 요구사항 상세설명 | 정의 | 공공기관의 데이터 베 이스 표준화지침 준수
# 산 출 | 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 | 고유 번호 | DAR-005
# 요구사항 | 분 류 | 데
#
# === 청크 61 (800자) ===
# 이터 요구사항
# 요구사항 | 명 칭 | 데이터 정합성 검 증
# 요구사항 상세설명 | 정의 | 데이터 정합성 검 증
# 산 출 | 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 고유 번호 | DAR-006
# 요구사항 분 류 | 데이터 요구사항
# 요구사항 명 칭 | 초 기데이터 구축 및 데이터 이관
# 정의 | 초 기데이터 구축 및 데이터 이관
# 산 출 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 고유 번호 | DAR-007
# 요구사항 분 류 | 데이터 요구사항
# 요구사항 명 칭 | 데이터 연계
# 요구사항 상세설명 정의 | 데이터 현 행화
# 세부내용 | ❍ 연계 운영되는 시스템을 통해 수 집 되는 신규 기업정보 및 추가 지원이력 정 보 등을 통합 DB 로 현 행화
# 산 출 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 고유 | 번호 | DAR-008
# 요구사항 | 분 류 | 데이터 요구사항
# 요구사항 | 명 칭 | 데이터 암호 화
# 요구사항 상세설명 | 정의 | 데이터 암호 화
# 산 출 | 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 고유 번호 | DAR-009
# 요구사항 분 류 | 데이터 요구사항
# 요구사항 명 칭 | 데이터 표준화 및 SQL 튜닝
# 정의 | 데이터 파 일 표준 및 SQL 튜닝 정의
# 산 출 정보 | 데이터 베 이스 분석 / 설 계 산출
# [표]
# 요구사항 고유 번호 | DAR-010
# 요구사항 분 류 | 데이터 요구사항
# 요구사항 명 칭 | 데이터 관리 정 책 수 립
# 요구사항 상세설명 정의 세부내용 | 운영관리를 위한 데이터 표준 및 관리정 책 을 수 립 ❍
#
# === 청크 62 (799자) ===
# 제안업체는 ' 공공데이터 관리지침 ( 행정안전부고시 매 뉴얼 ' 에 근거하여 선행사업 산출 물 을 참 조하여 관리가 용이하도록 표준 , 모 델 변경 , 운영방안 등
# 산 출 정보 | 데이터 베 이스 분석 / 설 계 산출 물
# [표]
# 요구사항 고유 번호 | TER-002
# 요구사항 분 류 | 테 스트 요구사항
# 요구사항 명 칭 | 운영 환 경 전 환 및 성능 테 스트
# 요구사항 상세설명 정의 | 운영 환 경 전 환 및 성능 테 스트
# 산 출 정보 | 테 스트 결과서
# [표]
# 요구사항 고유 번호 | | TER-003
# 요구사항 | 분 류 | 테 스트 요구사항
# 요구사항 | 명 칭 | 통합 테 스트
# | 정보 | 통합 테 스트결과서
# [표]
# 요구사항 고유 번호 | TER-004
# 요구사항 분 류 | 테 스트 요구사항
# 요구사항 명 칭 | 장 애 복구 테 스트
# 요구사항 상세설명 정의 세부내용 | 장 애 복구 요구사항 ❍ 시스템은 장 애 발 생 - 업무 중요도가 매우 - 업무 중요도가 보통인
# 산 출 정보 | 장 애 복구 테 스트결과서
# [표]
# 요구사항 고유 번호 | TER-005
# 요구사항 분 류 | 테 스트 요구사항
# 요구사항 명 칭 | 연계 테 스트
# 요구사항 상세설명 정의 | 연계 테 스트 요구사항
# 산 출 정보 | 연계 테 스트결과서
# [표]
# 요구사항 고유 | 번호 | SER-001
# 요구사항 | 분 류 | 보안 요구사항
# 요구사항 | 명 칭 | 관리적 보안
# 요구사항 상세설명 | 정의 | 관리적 보안요건
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | | SER-002
# 요구사항 | 분 류 | 보안 요구사항
# 요
#
# === 청크 63 (800자) ===
# 구사항 | 명 칭 | 물 리적 보안
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SER-003
# 요구사항 | 명 칭 | 기술적 보안
# 상세설명 | 정의 | 기술적 보안관리
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | SER-004
# 요구사항 분 류 | 보안 요구사항
# 요구사항 명 칭 | 참 여인력 보안
# 정의 세부내용 | 참 여인력 보안관리
# 산 출 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | SER-005
# 요구사항 | 분 류 | 보안 요구사항
# 요구사항 | 명 칭 | 공통보안 환 경
# 상세설명 | 정의 | 공통보안 환 경
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 | 번호 | SER-006
# 요구사항 | 분 류 | 보안 요구사항
# 요구사항 | 명 칭 | DB 보안
# 요구사항 상세설명 | 정의 | DB 보안
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | | SER-007
# 요구사 보안 요구사항
# 요구사항 | 명 칭 | SW 개발 보안
# 요구사항 상세설명 | 정의 | SW 개발 보안
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 고유 번호 | | SER-008
# 요구사항 명 칭 | 요구사항 명 칭 | 개인정보보 호
# 상세설명 | 정의 | 개인정보보 호 요건 정의
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 | 고유 번호 | SER-009
# 요구사항 | 분 류 |
#
# === 청크 64 (798자) ===
# 보안 요구사항
# 요구사항 | 명 칭 | 보안 요건
# 요구사항 상세설명 | 정의 | 보안정 책 에 따 른 준수사항
# 산 출 | 정보 | 사업수행계 획 서 , 보안점검결과서
# [표]
# 요구사항 | 고유 번호 | QUR-001
# 요구사항 | 분 류 | 품질 요구사항
# 요구사항 | 명 칭 | 품질보 증 및 관리
# 상세설명 | 정의 | 품질 보 증 및 관리
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | | QUR-002
# 요구사항 명 칭 | 요구사항 명 칭 | 기능 구 현 정확성
# 요구사항 상세설명 | 정의 | 기능 구 현 정확성
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | QUR-003
# 요구사항 명 칭 | 요구사항 명 칭 | 신 뢰 성
# 요구사항 상세설명 | 정의 | 시스템 신 뢰 성
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | QUR-004
# 요구사항 분 류 | 품질 요구사항
# 요구사항 명 칭 | 이식성 보장
# 요구사항 정의 | 이식성 보장
# 상세설명 세부내용 | ❍ 다 양 한 사용자 운영체제에 영향을 받 지 않 도록 시스템 개발
# 산 출 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 | 번호 | QUR-005
# 요구사항 분 | 류 품질 | 요구사항
# 요구사항 | 명 칭 상 | 호 운용성 보장
# 요구사항 상세설명 | 정의 세부내용 ❍ 증 | 상 호 운용성 보장 시스템 인터 페 이스 요구사항 기능은 기능 구 현 의 정확성 뿐 받아 야 함
# 산 출 | 정보 | 사업수행계 획 서 , 하자보수계 획 서
# [표]
# 요구사항 고유 번호 | | QUR-006
# 요구사항 명
#
# === 청크 65 (800자) ===
# 칭 | 요구사항 명 칭 | 이해의 용이성
# 요구사항 상세설명 | 정의 | 이해의 용이성
# 요구사항 상세설명 | 세부내용 | ❍ 사용자 및 운영자가 시스템을 쉽 고 편 하게 사용할 수 있도록 [ 기능 , 운영 ] 에 다 음 과 같 은 정보가 제공 - 기능 이해도 : 시스템에서 제공하는 모든 기능에 대해 사용자 매 뉴얼 에서 정보를 제공해야 함 - 운영의 이해도 : 시스템에서 제공하는 운영방법 및 인터 페 이스 기능과 방법을 운영자 매 뉴얼 에 포함해서 정보의 안정성과 데이터의 정합성을 유지해야 함
# 산 출 | 정보 | 사용자 및 운영자 매 뉴얼
# [표]
# 요구사항 | 고유 번호 | COR-001
# 요구사항 | 분 류 | 제약사항
# 요구사항 | 명 칭 | 지침 ( 가이 드 )
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | COR-002
# 요구사항 분 류 | 제약사항
# 요구사항 명 칭 | 표준 프 레 임 워크
# 요구사항 상세설명 정의 세부내용 | 전자정부 표준 프 레 임 워크 적용
# 산 출 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | COR-003
# 요구사항 분 류 | 요구사항 분 류 | 제약사항
# 요구사항 명 칭 | 요구사항 명 칭 | 표준화 요건
# 요구사항 상세설명 | 정의 | 표준화 요건 정의
# [표]
# 요구사항 고유 번호 | COR-006
# 요구사항 분 류 | 제약사항
# 요구사항 명 칭 | 상용 SW
# 요구사항 상세설명 | 정의 개발 가이 드
# 산 출 정보 | 기술확약서 ( 상용 SW 모든 제품
# [표]
# 요구사항 | 고유 번호 | COR-007
# 요구사항 | 분 류 제약사항 |
# 요구사항 |
#
# === 청크 66 (799자) ===
# 명 칭 | 하자 담 보
# 요구사항 상세설명 | 정의 세부내용 ❍ 이 | 하자 담 보 책 임기간 소프트웨어 진흥법 제 6 0조, 용역계약일 종 료 한 날 로부터 1 년간
# 산 출 | 정보 | 사업수행계 획 서 , 하자보수계 획 서
# [표]
# 요구사항 고유 번호 | | PMR-001
# 요구사항 | 분 류 | 프로 젝 트 관리 요구사항
# 요구사항 | 명 칭 | 관리방법 론
# 상세설명 | 정의 | 사업수행 조직관리
# 산 출 | 정보 | 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | | PMR-002
# 요구사항 명 칭 | 요구사항 명 칭 | 관리 방법 론
# 요구사항 상세설명 | 정의 | 관리 방법 론
# 산 출 | 정보 | 변경요청서
# [표]
# 요구사항 고유 | 번호 | PMR-003
# 요구사항 명 칭 | 요구사항 명 칭 | 보고의 종류
# 요구사항 상세설명 | 정의 | 보고의 종류 및 시기
# 산 출 | 정보 | 주 / 월간 보고
# [표]
# 요구사항 고유 | 번호 PMR-005
# 요구사항 분 | 류 프로 젝 트 관리 요구사항
# 요구사항 명 | 칭 개발장비
# 요구사항 상세설명 정의 세부내용 | 개발장비 ❍ 사업자의 참 여 의지 및 개발 환 경의 구성 여부와
# 산 출 정보 | 각 종 보고서
# [표]
# 요구사항 고유 번호 | PMR-006
# 요구사항 분 류 | 프로 젝 트 관리 요구사항
# 요구사항 명 칭 | 통제 및 리스 크 계 획
# 산 출 정보 | 제안서 , 사업수행계 획 서
# [표]
# 요구사항 고유 번호 | | PMR-007
# 요구사항 명 칭 | 요구사항 명 칭 | 시 험 운영
# 요구사항 상세설명 | 정의 | 시 험 운영
# 산 출 | 정보 | 제안서 , 사업수행계 획 서
# [표
#
# === 청크 67 (799자) ===
# ]
# 요구사항 고유 번호 | | PMR-008
# 요구사항 명 칭 | 요구사항 명 칭 | 책 임 및 보안
# 요구사항 상세설명 | 정의 | 책 임 및 보안
# 산 출 | 정보 | 제안서 , 사업수행계 획 서
# [표]
# 요구사항 고유 | 번호 PMR-009
# 요구사항 분 | 류 프로 젝 트 관리 요구사항
# 요구사항 명 | 칭 형 상 관리방안 수 립 및 준수
# 요구사항 상세설명 정의 세부내용 | 형 상 관리방안 수 립 및 준수 ❍ 시스템 개발부터 소 멸 까 지의 통합 관리되어 변경관리가 ❍ 재개발 , 추가개발에 필 요한
# 산 출 정보 | 형 상 관리 계 획 서
# [표]
# 요구사항 고유 번호 | PMR-010
# 요구사항 분 류 | 프로 젝 트 관리 요구사항
# 요구사항 명 칭 | SW 사업정보 저 장소 데이터 작성 및 제출
# 정의 | SW 사업정보 저 장소 데이터 작성 및 제출
# 산 출 정보 |
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | PSR-001
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
# 요구사항 명 칭 | 요구사항 명 칭 | 교육
# 요구사항 상세설명 | 정의 | 교육지원
# [표]
# 요구사항 고유 | 번호 | PSR-003
# 요구사항 | 분 류 | 프로 젝 트 지원
# 요구사항 | 명 칭 | 시스템 안정화
# 요구사항 상세설명 | 정의 | 시스템 안정화
# | 세부내용 | ❍ 구축시스템의 서비스 개시 후 안정된 운영을 위한 실 행방안을 제시 - 실 행방안에는 인수인계를 위한 운영 유지관리 인력 교육 , 비상연 락 체제 가동 , 기술지원 등을 의미함
# 산 출 | 정보 | 업무인수인계서 , 기술이전계 획 서
# [표]
# 요구사항 고유 번호 | |
#
# === 청크 68 (800자) ===
# PSR-004
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
# 요구사항 명 칭 | 요구사항 명 칭 | 저 작권의 책 임
# 요구사항 상세설명 | 정의 | 저 작권의 책 임
# 요구사항 상세설명 | 세부내용 | ❍ 본 사업과 관련된 모든 소프트웨어는 저 작권자 ( 사 ) 가 부여한 라이 센 스 조건 및 보 증 조건의 범 위 등 저 작권을 침해하여서는 안 되며 , 본 사업 완 료 이 후 에라도 제안된 소프트웨어 사용에 따 른 문제 발 생 시 용역사업자가 모든 책 임을 지고 해결해야 함
# 산 출 | 정보 |
# [표]
# 요구사항 고유 | 번호 | PSR-005
# 요구사항 | 분 류 | 프로 젝 트 지원
# 요구사항 | 명 칭 | 지식재산 공동귀속 및 개발 SW 의 공동 활 용
# 요구사항 상세설명 | 정의 | 지식재산 공동귀속 및 개발 SW 의 공동 활 용 사전 명 시 ❍ 계약목적 물 의 지식재산권은 발주기관과 사업자가 공동으로 소유함을 원칙으
# 산 출 | 세부내용 정보 | 로 하되 세 부사항은 협의하여 결정 ❍ 본 사업을 통해 개발되는 소프트웨어는 용역계약일반조건 제 56 조 ( 계약목적 물 의 지식재산권 귀속 등 ) 에 따라 타 기관과 공동 활 용할 계 획 이 없음 을 사전에 안내함
# [표]
# 요구사항 고유 | 번호 | PSR-006
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
# 요구사항 명 칭 | 요구사항 명 칭 | SW 산출 물 반출 절차
# 요구사항 상세설명 | 정의 | SW 산출 물 반출 절차
# 산 출 | 정보 |
# [표]
# 요구사항 고유 번호 | | PSR-007
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
#
# === 청크 69 (799자) ===
# 요구사항 명 칭 | 요구사항 명 칭 | 작업장소
# 요구사항 상세설명 | 정의 | 작업장소
# 산 출 | 정보 |
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | PSR-008
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
# 요구사항 | 명 칭 | 지식재산권 및 임치 , 공동 활 용에 관련한 사항
# 상세설명 | 정의 | 지식재산권 및 임치 , 공동 활 용에 관련한 사항을 정의함
# 산 출 | 정보 |
# [표]
# 요구사항 고유 번호 | 요구사항 고유 번호 | PSR-009
# 요구사항 분 류 | 요구사항 분 류 | 프로 젝 트 지원
# 요구사항 명 칭 | 요구사항 명 칭 | 하도 급
# 요구사항 상세설명 | 정의 | 하도 급 요건 정의
# 산 출 정보 | 산 출 정보 |
# [표]
# 산 출물 명 | 산 출물 명 | 설명
# 분석 | 시스템 분석 서 | 시스템 기능 및 DB 테 이 블 내역 등 작성
# 분석 | 요구사항 정의서 | 사용자 요구사항 정의서
# 분석 | 인터 페 이스 설 계서 | 내ㆍ 외 부 시스템 인터 페 이스 정의 및 설 계서 , 메뉴 구성도
# 설 계 | 엔 터 티 정의서 | 사업관리시스템의 엔 터 티 별 속성과 각 속성의 특정을 정의
# 분석 | 테 이 블 정의서 | 테 이 블 / 컬럼 목록과 세 부 정보 정의
# 분석 | 인 덱 스 정의서 | 인 덱 스의 목록과 세 부 정보
# 분석 | 중간보고서 | 중간보고서
# 개발 | 프로 그램 소스 코드 | 사업관리시스템 개발 소스 코드
# 테 스트 | 보안취약점점검계 획 서 / 결과서 | 보안 취약성 점검 전 략 , 목표 , 일정 및 상 세 내용 등으로 구 성된 계 획 서 및 수행 결과서
# 테 스트 |
#
# === 청크 70 (799자) ===
# 데이터 이행 결과서 | 초 기 데이터 구축 수행 결과서
# 종 료 | 운영 / 관리자 매 뉴얼 | 사업관리시스템 운영 및 관리를 위한 매 뉴얼
# 종 료 | 기술이전 계 획 서 | 사업수행 과정상 수반되는 각 종 기술의 발주기관 이전에 대한 계 획 서
# 종 료 | 하자보 증 확약서 | 하자보 증 기간 , 범 위 및 세 부내역 등을 포함한 문서
# 종 료 | 유지관리 확약서 | 유지관리 ( 유상 / 무상 ) 기간 , 범 위 및 세 부내역 등을 포함한 문서
# [표]
# 항 목 | 작 성 방 법
# Ⅱ . 일 반 현황 | Ⅱ . 일 반 현황
# 2. 제안 업체의 조직 및 인원 | - 제안업체 ( 컨 소시 엄 포함 ) 의 조직 및 인원 현황 을 제시하여야 한다 .
# Ⅲ . 전 략 및 방법 론 | Ⅲ . 전 략 및 방법 론
# 2. 추진전 략 | - 제안업체는 사업을 효 과적으로 수행하기 위한 추진전 략 ( 위 험 요소를 고 려 하여 창의적이 고 타당한 대안 ) 을 제시하여야 한다 .
# 3. 적용기술 | - 제안업체는 사업수행을 위한 주요 적용기술 및 세 부 개발방법 론 , 적용기술의 실현 가능성 등을 제시하여야 한다 . 대상 업무별 개발방안 ( 통합 / 연계 범 위 관련 적절한 방안 제시 등 ), Prototype 구 현 등 개발에 대한 전반적인 방안을 제시한다 . * 제안업체는 [ 별지 제 6 호 서식 ] 을 작성하여 기술적용계 획 제시
# 4. 표준 프 레 임 워크 적용 | - 제안업체는 사업에 적용 될 표준프 레 임 워크 및 공통 컴 포 넌 트의 사용 계 획 과 예 상되 는 문제점을 기술하고 실현 가능한 대 응 방안을 제시하여야 한다 . * 미
#
# === 청크 71 (800자) ===
# 사용 시에는 적정한 사유를 제시
# Ⅳ . 기 술 및 기능 | Ⅳ . 기 술 및 기능
# 2. 기능 요구사항 | - 방법 론 및 분석 도구를 통하여 구체적인 내용으로 분석 되고 구 현 방안이 구체적인 기술 , 제안한 방안 및 기술의 적용방안을 제시하여야 한다 .
# 3. 보안 요구사항 | - 보안요구사항 및 시스템과의 관련성을 분석 하고 적용할 보안기술 , 표준 , 제안방안 등을 구체적으로 제시하여야 한다 .
# 5. 시스템 운영 요구사항 | - 시스템 운영과 관련된 필 요사항 , 경 험 , 고 려 사항 및 유사시 대 응책 등을 제시하여야 한다 .
# 6. 제약사항 | - 기능 및 품질 등 요구사항 구 현 시 관련 제약사항과 대 응 방안을 구체적으로 기술하 여야 한다 .
# [표]
# Ⅴ . 성능 및 품질 | Ⅴ . 성능 및 품질
# 1. 성능 요구사항 | - 구 현 하고자 하는 기능을 통해 요구 성능이 충족되도록 방법 론 및 분석 도구 , 구 현 및 테 스트 방안을 구체적으로 제시하여야 한다 .
# 2. 품질 요구사항 | - 분석 · 설 계 등 각 단계별 품질 요구사항의 점검 및 검 토 방안을 구체적으로 제시하여야 한다 .
# 3. 인터 페 이스 요구 사항 | - 내 · 외 부 연계를 포함하여 시스템 및 사용자 인터 페 이스 요구사항에 대해 구체적인 제안내용을 제시하여야 한다 .
# Ⅵ . 프로 젝 트 관리 | Ⅵ . 프로 젝 트 관리
# 3. 일정계 획 | - 사업수행에 필 요한 활 동을 도출하여 정확한 활 동 기간 , 자원 , 조직 등을 제시하여야 한다 .
# 4. 개발 장비 | - 사업자의 참 여 의지 및 조직적 대 응 정도 , 사업 참 여의 준비
#
# === 청크 72 (800자) ===
# 성과 관련하여 개발 환 경의 구성여부와 해결방안을 명 확 히 제시하여야 한다 .
# Ⅶ . 프로 젝 트 지원 | Ⅶ . 프로 젝 트 지원
# 5. 기 밀 보안 | - 기 밀 보안 체계 및 대 책 , 저 작권 존중 여부 명 시 , 시스템 보안성 확보방안과 개인정 보보 호 대 책 을 제시하여야 한다 .
# 6. 비상대 책 | - 안정적인 시스템 운영을 위하여 백 업 / 복구 및 장 애 대 응 대 책 을 제시하여야 한다 .
# Ⅷ . 기 타 | Ⅷ . 기 타
# 기타 | - 상기항목에서 제시되지 않 은 기타 내용을 기술한다 .
# [표]
# | 사업관리자 (PM 부문
# 부문 | 부문 |
# [표]
# 사업명
# 작성일
# [표]
# 구분 | 항 목
# [표]
# 사 업 명 | 하 도 급 사 업 명 |
# 수 급 인 | 하수급인 | ( 전화 )
# 하도급예정액 (A) | 하도급계약 금액 (B) | 원
# 계약기간 | 하 도 급 기 간 |
# 하자담보 책임기간 | 하자담보 책임기간 |
# 국가기관등과의 낙찰방식 , 낙찰률 | 부분하도급률 (B/A) | %
# [표]
# 구 분 | 위 규 사 항 | 처 리 기 준
# [표]
# 구 분 | 위 규 사 항 | 처 리 기 준
# [표]
# | le maa sermer. | 718/
# | CALLALON 2UEE VIEZ MON | 749
# | merin allu |
# [표]
# 산 출물 명 | 산 출물 명 | 설명
# 분석 | 현 행시스템 분석 서 | 현 행 시스템의 기능 및 벤처확인 DB 테 이 블 내역 등 작성
# 분석 | 요구사항 정의서 | 사용자 요구사항 정의서
# 분석 | 인터 페 이스 설 계서 | 내ㆍ 외 부 시스템간 인터 페 이스 정의 및 설 계서 , 메뉴 구성도
# 분석 |
#
# === 청크 73 (587자) ===
# 데이터주제영역 정의서 | 데이터 주제영역 구 분 과 관련 구성요소 정의 , 데이터 코드 목록
# 설 계 | 엔 터 티 정의서 | 사업관리시스템의 엔 터 티 별 속성과 각 속성의 특정을 정의
# 분석 | 테 이 블 정의서 | 테 이 블 / 컬럼 목록과 세 부정보 정의
# 분석 | 인 덱 스 정의서 | 인 덱 스의 목록과 세 부정보
# 분석 | 중간보고서 | 중간보고서
# 개발 | 프로 그램 소스 코드 | 사업관리시스템 개발 소스 코드
# 테 스트 | 보안 취약점 점검 계 획 서 / 결 과서 | 보안 취약성 점검 전 략 , 목표 , 일정 및 상 세 내용 등으로 구 성된 계 획 서 및 수행 결과서
# 테 스트 | 데이터이행 결과서 | 초 기 데이터 구축 수행 결과서
# [표]
# 산 출물 명 | 설명
# 운영 / 관리자 매 뉴얼 | 사업관리시스템 운영 및 관리를 위한 매 뉴얼
# 종 료 보고서 | 종 료 보고서
# 기술이전 계 획 서 | 사업수행 과정상 수반되는 각 종 기술의 발주기관 이전에 대한 계 획 서
# 하자보 증 확약서 | 하자보 증 기간 , 범 위 및 세 부내역 등을 포함한 문서
# 유지관리 확약서 | 유지관리 ( 유상 / 무상 ) 기간 , 범 위 및 세 부내역 등을 포함한 문서

# %%
all_results = []
for doc_path in DOC_PATHS[:5]:
    all_results.append(run_eval_for_doc(doc_path))

results_df = pd.concat([d for d in all_results if len(d)], ignore_index=True) if all_results else pd.DataFrame()

if len(results_df):
    results_df["score"] = (
        0.5 * results_df["retrieval_mrr@k"].fillna(0) +
        0.2 * results_df["retrieval_recall@k"].fillna(0) +
        0.3 * results_df["gen_match_rate"].fillna(0)
    )

display(results_df)

if len(results_df):
    out_path = BASE_DIR / "outputs" / f"eval_integrated_{pp_version}.csv"
    out_path.parent.mkdir(parents=True, exist_ok=True)
    results_df.to_csv(out_path, index=False, encoding="utf-8-sig")
    display(results_df.sort_values(["retrieval_mrr@k", "gen_match_rate"], ascending=[False, False]).head(20))
    print("Saved:", out_path)
# Out:
# ⚠️ no gold fields: (사）한국대학스포츠협의회_KUSF 체육특기자 경기기록 관리시스템 개발.pdf
#                                               doc_id  n_questions_total  \
# 0       (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf                 21
# 1  (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원...                 21
# 2                 (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf                 21
# 3       2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf                 21
#
#    n_questions_with_evidence  retrieval_recall@k  retrieval_mrr@k  \
# 0                         21            0.476190         0.224446
# 1                         21            0.809524         0.427961
# 2                         21            0.761905         0.402080
# 3                         21            0.523810         0.078471
#
#    n_questions_with_gold_fields  gen_fill_rate  gen_match_rate  \
# 0                            21        0.52381        0.190476
# 1                            21        0.52381        0.142857
# 2                            21        0.52381        0.142857
# 3                            21        0.52381        0.285714
#
#    gen_avg_similarity     score
# 0           25.630309  0.264604
# 1           22.747314  0.418742
# 2           31.465027  0.396278
# 3           31.444749  0.229712
#                                               doc_id  n_questions_total  \
# 1  (사)부산국제영화제_2024년 BIFF & ACFM 온라인서비스 재개발 및 행사지원...                 21
# 2                 (재)예술경영지원센터_통합 정보시스템 구축 사전 컨설팅.pdf                 21
# 0       (사)벤처기업협회_2024년 벤처확인종합관리시스템 기능 고도화 용역사업 .pdf                 21
# 3       2025 구미 아시아육상경기선수권대회 조직위원회_2025 구미아시아육상경.pdf                 21
#
#    n_questions_with_evidence  retrieval_recall@k  retrieval_mrr@k  \
# 1                         21            0.809524         0.427961
# 2                         21            0.761905         0.402080
# 0                         21            0.476190         0.224446
# 3                         21            0.523810         0.078471
#
#    n_questions_with_gold_fields  gen_fill_rate  gen_match_rate  \
# 1                            21        0.52381        0.142857
# 2                            21        0.52381        0.142857
# 0                            21        0.52381        0.190476
# 3                            21        0.52381        0.285714
#
#    gen_avg_similarity     score
# 1           22.747314  0.418742
# 2           31.465027  0.396278
# 0           25.630309  0.264604
# 3           31.444749  0.229712
# Saved: /Users/won/dev/00_codeit/0_mission/200_DL_RAG/outputs/eval_integrated_5.csv

# %% [markdown]
# ### 질문 샘플 및 답변

# %%
# 질문 샘플 + 모델 답변 보기 (문서 1개 기준)
doc_name = results_df.sort_values("gen_match_rate").iloc[0]["doc_id"]  # 예시: 성능 낮은 문서
sample_n = 5

# 문서 선택
doc_path = next(
    p for p in DOC_PATHS 
    if unicodedata.normalize("NFC", p.name) == unicodedata.normalize("NFC", doc_name)
)


# 준비
qdf = gold_fields_df[gold_fields_df["doc_id"].astype(str) == doc_name].copy()

index, chunks = pp.gen_input(doc_path, embed_model)
model = embed_model

# 배치 답변
answers, idxs = answer_batch(index, model, chunks, BASELINE_QUERIES, top_k=TOP_K, return_indices=True)
answer_map = {k: answers[i] if i < len(answers) else "" for i, (k, _) in enumerate(BASELINE_QUERIES)}

# 샘플 출력
rows = []
for _, row in qdf.head(sample_n).iterrows():
    field = str(row["field"])
    gold = row["gold"]
    pred = answer_map.get(field, "")
    question = dict(BASELINE_QUERIES).get(field, "")
    rows.append({"field": field, "question": question, "gold": gold, "pred": pred})

display(pd.DataFrame(rows))
# Out:
#            field                             question  \
# 0   project_name                       사업(용역)명은 무엇인가?
# 1         agency                   발주 기관(수요기관)은 어디인가?
# 2        purpose                  사업 목적(추진 배경)은 무엇인가?
# 3         budget                  총 사업 예산(사업비)은 얼마인가?
# 4  contract_type  계약 방식(일반경쟁/제한경쟁/협상에 의한 계약 등)은 무엇인가?
#
#                                                 gold  \
# 0               BIFF&ACFM 온라인서비스 재개발 및 행사지원시스템 공급 사업
# 1                 [부산국제영화제(BIFF), 아시아콘텐츠&필름마켓(ACFM)]
# 2  [사용자 중심의 웹서비스를 제공, 브랜드 가치 제고, 참가자와 관리자의 편의성을 제...
# 3                                       243,000,000원
# 4                                            제한 경쟁입찰
#
#                                    pred
# 0  BIFF&ACFM 온라인서비스 재개발 및 행사지원시스템 공급 사업
# 1                               부산국제영화제
# 2                             NOT_FOUND
# 3                243,000,000 원 (VAT 포함)
# 4                       제한 경쟁입찰 (지역 제한)
