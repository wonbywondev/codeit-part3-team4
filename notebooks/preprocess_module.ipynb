# %%
# 기본 경로 설정
# ===============================================================
import os
import subprocess

PROJECT_NAME = "rag"

ROOT_DIR = os.getcwd()

try:
    from google.colab import drive, userdata
    IS_COLAB_MODE = True
    print("코랩 모드")

except ModuleNotFoundError as e:
    IS_COLAB_MODE = False
    ROOT_DIR = os.path.abspath(os.path.join(ROOT_DIR, ".."))
    os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
    os.environ["TOKENIZERS_PARALLELISM"] = "false"
    print(f"로컬 모드")


    DATA_DIR = os.path.join(ROOT_DIR, "data")
    RAW_DIR = os.path.join(DATA_DIR, "raw")
    PDF_DIR = os.path.join(DATA_DIR, "pdf")
    os.makedirs(DATA_DIR, exist_ok=True)


# 환경변수 로드 설정
def get_secret(key_name: str):
    if IS_COLAB_MODE:
        return userdata.get(key_name)
    else:
        from dotenv import load_dotenv
        load_dotenv(dotenv_path=os.path.join(ROOT_DIR, ".env"))
        return os.getenv(key_name)


if IS_COLAB_MODE:
    drive.mount('/content/drive')

    DATA_DIR = os.path.join(ROOT_DIR, "drive", "MyDrive", "codeit-part3-team4", "data")
    RAW_DIR = os.path.join(DATA_DIR, "raw")
    PDF_DIR = os.path.join(DATA_DIR, "pdf")
    os.makedirs(DATA_DIR, exist_ok=True)

    SAVE_DIR = os.path.join(DATA_DIR, "runs", PROJECT_NAME)
    os.makedirs(SAVE_DIR, exist_ok=True)


# .DS_Store 파일 삭제
_ = subprocess.run(
    ["find", DATA_DIR, "-name", ".DS_Store", "-type", "f", "-delete"],
    check=True
)
# Out:
# 로컬 모드

# %%
import json
from glob import glob

# 표
from img2table.document import PDF
from img2table.ocr import TesseractOCR
import pandas as pd

# 텍스트
from langchain_community.document_loaders import PyPDFLoader

# %%
metadata_json_path = os.path.join(DATA_DIR, "metadata.json")

with open(metadata_json_path, "r", encoding="utf-8") as f:
    metadata_dict = json.load(f)

PDF_PATH_LIST = glob(os.path.join(PDF_DIR, "*"))

sample_pdf = PDF_PATH_LIST[0]

# %% [markdown]
# ## 표

# %%
def trim_table(df: pd.DataFrame):
    df.columns = df.iloc[0]
    df = df[1:]
    df.reset_index(drop=True, inplace=True)

    return df

# %%
tables_by_page = PDF(sample_pdf).extract_tables(
    ocr=TesseractOCR(n_threads=1, lang="eng"),
    min_confidence=1
)
# Out:
# tesseract 5.5.2
#  leptonica-1.87.0
#   libgif 5.2.2 : libjpeg 8d (libjpeg-turbo 3.1.3) : libpng 1.6.54 : libtiff 4.7.1 : zlib 1.2.12 : libwebp 1.6.0 : libopenjp2 2.5.4
#  Found NEON
#  Found libarchive 3.8.5 zlib/1.2.12 liblzma/5.8.2 bz2lib/1.0.8 liblz4/1.10.0 libzstd/1.5.7 expat/expat_2.7.1 CommonCrypto/system libb2/system
#  Found libcurl/8.7.1 SecureTransport (LibreSSL/3.3.6) zlib/1.2.12 nghttp2/1.67.1

# %%
TABLE_DICT = dict()

for page_num, tables in tables_by_page.items():
    if not tables:
        continue

    TABLE_DICT[page_num] = []

    for i, table in enumerate(tables):
        table_num = float(f"{page_num}.{i}")
        table_content = trim_table(table.df).to_dict(orient="split")
        table_content.pop("index", None)

        TABLE_DICT[page_num].append({
            "table_title": table.title,
            "table_num": table_num,
            "table_content": table_content
        })
# Out:
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")
# /var/folders/h6/_8g_zbns4n53222bttvjsx_40000gn/T/ipykernel_58413/2037672242.py:9: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "table_content": trim_table(table.df).to_dict(orient="split")

# %% [markdown]
# ## 텍스트

# %%
loader = PyPDFLoader(sample_pdf)
docs = loader.load()
# Out:
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 372 0 (offset 0)

# %%
for doc in docs:
    page = doc.metadata["page"]
    page_label = doc.metadata["page_label"]
    title = doc.metadata["source"].split("/")[-1]
    section = metadata_dict[title][str(page)]
    if page not in TABLE_DICT.keys():
        table = None
    else:
        table = TABLE_DICT[page]

    doc.metadata = {
        "page": page,
        "page_label": page_label,
        "title": title,
        "section": section,
        "table": table
    }

# %%
docs
# Out:
# [Document(metadata={'page': 0, 'page_label': '1', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': '', 'table': None}, page_content='실손보험 청구 전산화 시스템 구축제안요청서>\n2024. 3'),
#  Document(metadata={'page': 1, 'page_label': '2', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': '', 'table': None}, page_content='목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   목   차차차차차차차차차차차차차차차차차차차차차차차차차차차차차차차차차목   차Ⅰ. 사업 개요   1. 개요 ···························································································· 2   2. 추진배경 및 필요성··································································· 2   3. 실손보험 청구 전산화 시스템 개요······································· 3   4. 사업 수행 대상·········································································· 4   5. 기대효과······················································································ 5Ⅱ. 업무 현황   1. 실손보험 청구 현황··································································· 6   2. 문제점··························································································10Ⅲ. 사업추진체계 및 일정   1. 추진 방향····················································································11   2. 사업추진체계··············································································11   3. 추진 일정·················································································· 12Ⅳ. 제안 요청 내용   1. 목표 업무프로세스·································································· 13   2. 목표시스템 개념도·································································· 17   3. 과업대상 범위·········································································· 19   4. 상세요구 사항·········································································· 24'),
#  Document(metadata={'page': 2, 'page_label': '3', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': '', 'table': None}, page_content='Ⅴ. 제안서 작성 안내   1. 제안서 효력·············································································· 90   2. 제안서 작성 권고 사항·························································· 90   3. 유의사항···················································································· 91   3. 제안서 목차 및 세부 작성 방법··········································· 93Ⅵ. 제안 안내 사항   1. 입찰 참가 자격········································································ 95   2. 제출 서류·················································································· 95   3. 제안 설명회·············································································· 96Ⅶ. 제안서 평가방법   1. 평가 방법·················································································· 97   2. 평가 기준·················································································· 98   3. 낙찰자 결정방법···································································· 102     [붙임1] 외주용역사업 보안특약················································· 103  [붙임2] 제출서식··········································································· 106'),
#  Document(metadata={'page': 3, 'page_label': '4', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 개요', '2. 추진배경 및 필요성·'], 'table': None}, page_content='- 2 -\nⅠ  사업 개요1. 개요 □ 사 업 명 : 실손보험 청구 전산화 시스템 구축 □ 사업기간 : 계약일로부터 19개월    ※ 1차: ’24년 4월~10월 25일, 2차: ’24년 10월~’25년 10월 25일 □ 계약방식 : 일반경쟁입찰, 협상에 의한 계약  ※ 본 제안요청서에서는 사업예산이 포함되지 않음2. 추진배경 및 필요성 □ 실손보험은 국민건강보험의 보완형으로 도입되어 ’23년말 국민 약 4천만명이 가입한 일상생활에 필수적인 보험상품으로 성장함  o 연간 약 1억건을 초과하는 보험금 청구와 지급이 이루어지고 있으나 복잡한 절차*로 인한 소비자 불편이 계속 문제점으로 지적됨*①보험금 청구서류 확인 → ②요양기관에 서류발급 신청 → ③서류수령 → ④보험금 청구서 작성 → ⑤서류제출 → ⑥보험금 지급 심사 → ⑦보험금 수령  o 또한, 진료비 영수증 등 보험금 청구에 필요한 수억장의 종이서류를 발급하고 처리하는데 사회적 비용이 낭비됨 □ 이에 정부는 소비자가 전송대행기관을 통해 One-Stop으로 실손보험전산청구(이하 ‘청구 전산화’)가 가능하도록 보험업법을 개정* *’23.10.24 공포 → ’24.10.25 병원급 시행(1단계) → ’25.10.25 의원 및 약국 시행(2단계)  o 이번 개정 법률은 요양기관과 보험사 간 전송대행기관을 두고 청구'),
#  Document(metadata={'page': 4, 'page_label': '5', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 실손보험 청구 전산화 시스템 개요'], 'table': None}, page_content='- 3 -\n전산화를 구현하는 것으로 별도 시스템 구축을 필요로 하고 있음3. 실손보험 청구 전산화 시스템 개요 □ 참여기관 : 전국 요양기관(병의원 및 약국), 실손보험계약을 보유 또는 보유예정인 보험사\n<그림1>실손보험 청구 전산화 시스템 개념도 □ 주요기능   o 진료를 받은 보험가입자의 요청에 따라 요양기관에서 보험사로 보험금 청구 필요서류를 전자적 방법으로 전송   o 전송대행기관은 요양기관으로부터 전자문서를 수신받아 가입보험사로 전달   o 요양기관의 서류를 보험사에서 확인이 가능토록 표준화된 레이아웃으로 변환 사용, 전송되는 전자문서는 암호화되어야 함 □ 이슈사항'),
#  Document(metadata={'page': 5, 'page_label': '6', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 사업 수행 대상'], 'table': {'table_title': 'EMR 시스템을 통하며, ’24년 10.25일\n7,725개, ’25년 10.25일 시행되는\n약국으로 93,472개 요양기관으로 확산', 'table_num': 5.1, 'table_content':                  0                1
#  0  2단계 (’25.10.25)  2단계 (’25.10.25)
#  1               구분           요양기관 수}}, page_content='- 4 -\n   o 요양기관 정보시스템에 대한 수정이 필요함, 자체 시스템을 보유한 일부 대형병원을 제외하고는 EMR업체의 상용 소프트웨어를 사용함4. 사업 수행 대상 □ 요양기관 확산 계획   o 요양기관과의 연계는 사용 중인 EMR 시스템을 통하며, ’24년 10.25일 시행되는 1단계 연계 대상은 병원 7,725개, ’25년 10.25일 시행되는 2단계 연계 대상은 의원과 약국으로 93,472개 요양기관으로 확산 운영할 계획\n  ※ 요양기관 통계 출처: HIRA빅데이터개방포털 > 공공데이터 > 공공데이터 목록 > “전국 병의원 및 약국 현황” □ 1단계 구축 대상: 병상 30개 이상 7천여 개 요양기관   o 기간: ’24.04∼’24.10.25 □ 2단계 구축 대상: 의원 및 약국 9.3만 개   o 기간: ’24.11∼’25.10.25\n1단계 (’24.10.25)구분요양기관 수상급종합병원47종합병원331병원1,402요양병원1,396정신병원257치과병원240한방병원562보건소 등3,490합계7,725\n2단계 (’25.10.25)구분요양기관 수의원35,766한의원14,606치과의원19,039약국24,061합계93,472'),
#  Document(metadata={'page': 6, 'page_label': '7', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['5. 기대효과'], 'table': None}, page_content='- 5 -\n※ 2단계 구축 사업의 경우, 1차 사업 진행 경과를 고려하여 일정이 조정될 수 있음'),
#  Document(metadata={'page': 7, 'page_label': '8', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': {'table_title': 'o (보험사) 실손보험계약을 보유 또는 보유예정인 보험사는 손해보험사\n17개, 생명보험사 16개', 'table_num': 7.0, 'table_content':                         0                      1                      2  \
#  0   실손보험계약 보유 또는 보유예정 보험사  실손보험계약 보유 또는 보유예정 보험사  실손보험계약 보유 또는 보유예정 보험사
#  1                   손해보험사                  손해보험사                  생명보험사
#  2                       1              메리츠화재해상보험                      1
#  3                       2                 한화손해보험                      2
#  4                       3                 롯데손해보험                      3
#  5                       4                 MG손해보험                      4
#  6                       5               흥국화재해상보험                      5
#  7                       6               삼성화재해상보험                      6
#  8                       7               현대해상화재보험                      7
#  9                       8                 KB손해보험                      8
#  10                      9                 DB손해보험                      9
#  11                     10                AXA손해보험                     10
#  12                     11                 하나손해보험                     11
#  13                     12                AIG손해보험                     12
#  14                     13                에이스손해보험                     13
#  15                     14                 캐롯손해보험                     14
#  16                     15               NH농협손해보험                     15
#  17                     16        신한EZ손해보험 (보유예정)                     16
#  18                   None       카카오페이손해보험 (보유예정)                   None
#
#                          3
#  0   실손보험계약 보유 또는 보유예정 보험사
#  1                   생명보험사
#  2                  한화생명보험
#  3                 ABL생명보험
#  4                  삼성생명보험
#  5                  흥국생명보험
#  6                  교보생명보험
#  7               신한라이프생명보험
#  8                푸본현대생명보험
#  9                 KB라이프생명
#  10                DGB생명보험
#  11                KDB생명보험
#  12               미래에셋생명보험
#  13               NH농협생명보험
#  14                라이나생명보험
#  15                AIA생명보험
#  16                 DB생명보험
#  17                 동양생명보험
#  18                   None  }}, page_content='- 6 -\n □ (참고자료)   o (보험사) 실손보험계약을 보유 또는 보유예정인 보험사는 손해보험사 17개, 생명보험사 16개실손보험계약 보유 또는 보유예정 보험사손해보험사생명보험사1메리츠화재해상보험1한화생명보험2한화손해보험2ABL생명보험3롯데손해보험3삼성생명보험4MG손해보험4흥국생명보험5흥국화재해상보험5교보생명보험6삼성화재해상보험6신한라이프생명보험7현대해상화재보험7푸본현대생명보험8KB손해보험8KB라이프생명9DB손해보험9DGB생명보험10AXA손해보험10KDB생명보험11하나손해보험11미래에셋생명보험12AIG손해보험12NH농협생명보험13에이스손해보험13라이나생명보험14캐롯손해보험14AIA생명보험15NH농협손해보험15DB생명보험16신한EZ손해보험 (보유예정)16동양생명보험17카카오페이손해보험 (보유예정)총 33개 보험사 5. 기대효과  □실손보험 보험금 청구 전산화에 따른 보험가입자의 편익 증대 및 종이서류 사용절감에 따른 요양기관 비용 절감  □기존 종이서류 및 스캔문서 데이터의 수기 입력 감소에 따른 업무 프로세스 개선 및 인건비 절감  □ 실손보험 보험금 청구 전산화에 따른 청구율 증가'),
#  Document(metadata={'page': 8, 'page_label': '9', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': None}, page_content='- 7 -\nⅡ  업무현황1. 실손보험 청구 현황    □ 실손보험 청구 현행 업무 흐름\n<그림2>실손보험 청구 현행 업무 흐름도  o (의료서비스 이용) 보험가입자가 요양기관에서 의료서비스를 이용 후 진료비, 약제비 등의 비용 수납  o (청구 필요서류 준비) 보험가입자는 보험금 청구 필요서류를 확인하고 진료를 받은 요양기관에 서류발급 신청 및 수령   -서류는 대면창구, 무인발급기, 증명서발급홈페이지 등의 방법으로 발급   -실손의료비 청구 필수서류는 ① 진료비 영수증, ② 약제비 영수증, ③ 진료비 세부내역서 및 ④ 처방전이며, 보험사에 따라 추가서류 필요     ※ 환자 본인이 아닌 제 3자가 서류발급을 요청하는 경우 가족관계증명서 및 대리인 위임장 필요'),
#  Document(metadata={'page': 9, 'page_label': '10', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': None}, page_content='- 8 -\n  o (청구서 작성 및 서류제출) 보험가입자 또는 청구 대리인은 청구서를 작성하고 발급받은 서류와 함께 보험사에 제출 \u3000-청구 시 보험사의 개인정보처리 동의서를 작성하며, 대리인이 청구하는 경우 권한을 위임받아야 함  o (보험금 지급 심사) 보험사는 제출된 서류를 기반으로 보험금 지급 여부와 지급액을 결정  o (보험금 지급) 보험사는 보험금 청구자와 보험가입자에게 보상 금액을 안내하고 보험금을 보험가입자에게 지급 □ 실손보험 청구 현행 방식  o 현행 실손보험 청구는 보험가입자가 보험사에 보험금을 청구하는 ‘직접청구’ 방식과 요양기관 단말기를 통해 보험금을 청구하는 방식 존재  o ‘직접청구’ 방식은 보험가입자가 요양기관에서 청구 필요서류를 발급받아 보험사 앱/웹 또는 오프라인으로 제출함제출방법설명보험사 앱(홈페이지)서류 스캔 또는 사진촬영 후 이미지(pdf등) 파일로 제출오프라인(사본제출 및 Fax)실물 문서 사본을 보험사 창구에서 제출,실물 문서 사본을 보험사에 우편으로 제출, 실물 문서 사본을 Fax로 보험사로 제출   - 보험사들은 보험금 청구서류 작성에서부터 서류의 촬영·제출까지 일괄 신청이 가능한 모바일 앱 서비스를 제공 중   - 보험사 모바일 앱에 접속하여 실손의료보험 보험금 청구서를 작성하고, 의료비 증명서류 이미지 파일을 첨부하여 보험사에 일괄 송부할 수 있음'),
#  Document(metadata={'page': 10, 'page_label': '11', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': None}, page_content='- 9 -\n <그림3>모바일 앱을 이용한 보험금 청구 개요    ※ 환자는 요양기관으로부터 의료비 증명서를 발급받은 후 해당 서류를 스마트폰 카메라로 촬영하여 이미지 파일로 저장   o 요양기관 단말기를 이용하는 방식은 보험가입자가 요양기관 단말에서청구 필요서류를 선택하여 청구할 보험사에 바로 서류를 전송함   - 요양기관과 보험사 정보시스템을 서로 연결하는 무인단말기를 설치하고, 환자가 해당 단말기를 이용해 자신의 의료비 증명서류 등을 발급받거나, 전자문서로 보험사에 송부할 수 있음   - 대형병원 및 무인단말기 사업자와 제휴하여 청구 서비스를 제공 중\n<그림4>무인단말기를 이용한 보험금 청구 개요'),
#  Document(metadata={'page': 11, 'page_label': '12', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': None}, page_content='- 10 -\n □ (관련시스템) 전자의무기록  o 전자의무기록(EMR*)시스템은 환자가 내원하였을 때 발생하는 환자의 진료기록(진단, 약물처방, 검사결과 등)을 전자적인 형태로 내원진료기록 단위로 기록할 수 있는 시스템     * EMR : Electronic Medical Records o 보험금 청구와 관련된 필수서류를 EMR시스템의 정보를 기반하여 발급받을 수 있음   - 환자는 요양기관의 키오스크 단말 등을 통해 본인의 진료기록을 열람하거나 그 사본을 발급 o 병원 규모에 따라 EMR시스템을 자체 개발하거나 상용 솔루션을 사용하고 있음*    * 사용 현황은 2023.11 기준   - 병원급 중 350개 병원은 자체 개발하여 사용하고 있으며, 병원급 이상에 서비스하는 EMR업체는 55개      ※ 상급종합병원은 모두 자체 개발 EMR 시스템 사용    - 의원급 중 27개 의원이 자체 개발이며, 의원급에 서비스하는 EMR업체는 43개   - 이 외 보건기관 및 약국 EMR시스템은 16개'),
#  Document(metadata={'page': 12, 'page_label': '13', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 실손보험 청구 현황·'], 'table': None}, page_content='- 11 -\n2. 문제점□ 보험가입자 측면 o (청구 필요서류 이해 부족) 보험사별로 청구 필요서류가 상이하며, 서류에 대한 이해 부족으로 요양기관과 의사소통이 어려움 o (번거로운 서류발급) 서류발급을 위해 요양기관에 추가 방문해야 하며, 제증명서류 발급 수수료 비용 지불하는 경우 발생 o (불편한 서류제출) 발급받은 서류를 보험사에 직접 방문, Fax 송신 또는 스캔하여 이미지 파일 업로드를 통해 제출하여야 함에 따른 불편함이 상당함 o (대기 시간 발생) 수작업으로 인한 병원비 수납 후 최종 보험금 수령까지 시간 소요 o (소액 청구 포기) 서류발급 및 청구 절차의 복잡성으로 인해 소액 청구 포기 사례 존재□ 요양기관 및 보험사 측면 o (요양기관 업무 과중) 서류발급 요청 접수와 발급 작업 반복으로 인한 원무과 인력 부담 및 업무 비효율성 과중 o (보험사 업무 비효율성) 입수한 서류 시스템 입력 및 검증에 다수 인력 소요 및 심사 후 종이문서 보관하는 형태의 비효율성 존재 o (보험사 업무 지연) 서류가 불일치하거나 부정확한 경우가 많아 재요청해야 하여 업무 지연'),
#  Document(metadata={'page': 13, 'page_label': '14', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 추진 일정'], 'table': {'table_title': '(주관기관)\n보험개발원\n정보시스템 감리\n사업수행업체', 'table_num': 13.0, 'table_content':            0                                                  1
#  0        구 분                                              주요 역할
#  1       주관기관  o 사업 수행 계획 검토 및 승인\no 사업 계획 조정 및 관리\no 업무별 요구사...
#  2  정보시스템\n감리                        o 프로젝트 진행과정 및 산출물 품질에 대한 감리
#  3     사업수행업체  o 사업 수행 계획 수립, 추진 및 결과 보고\no 장비 효율성과 서비스 확장성을 ...}}, page_content='- 12 -\nⅢ  사업추진체계 및 일정1. 추진 방향 □ 이용자 중심의 편리한 실손보험 보험금 청구 서비스 수립 □ 안심하고 이용할 수 있는 개인정보 및 의료데이터 유통체계 구축 □ 365일 24시간 이용할 수 있는 대국민포털 구축2. 사업추진체계(주관기관)보험개발원정보시스템 감리사업수행업체구 분주요 역할\n주관기관o 사업 수행 계획 검토 및 승인o 사업 계획 조정 및 관리o 업무별 요구사항 확인 등 운영 관리 및 관리 감독o 사업수행업체 진도관리 및 검수o 품질 관리 및 의사 결정o 사업관리자의 권한을 위임받아 사업통제 및 주요 이슈 해결o 사업진행관리, 프로젝트 매니저 지원, 교육, 인력관리, 변경통제o 단계별 품질검토 및 결과보고, 기술자문 수행o 이해 당사자 간 의견 교환 및 조정o 개인정보 영향평가정보시스템 감리o 프로젝트 진행과정 및 산출물 품질에 대한 감리사업수행업체o 사업 수행 계획 수립, 추진 및 결과 보고o 장비 효율성과 서비스 확장성을 고려한 시스템 구축o 개발인력 관리, 교육지원 등o 업무 담당자와 커뮤니케이션 및 개발'),
#  Document(metadata={'page': 14, 'page_label': '15', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 목표 업무프로세스'], 'table': None}, page_content='- 13 -\n3. 추진 일정  □ 사업 기간: 계약일로부터 19개월 □ 세부 일정  o 1단계 구축 기간: 2024.04. ~ 2024.10. (약 7개월)       ※ 2024.10.25(금) 서비스 오픈 일정        ※ 사업자 선정 이후, 우선협상과 병행하여 신속한 분석/설계 인력 투입 필요  o 2단계 구축 기간: 2024.11. ~ 2025.10. (약 12개월)       ※ 2025.10.25(금) 서비스 오픈 일정       ※※ 요양기관 대상별 점진적 오픈 고려추진내용구축 일정1단계 구축2단계 구축MM1M2M3M4M5M6M7M8M9M10M11M12M13M14M15M16M17M18○ 응용시스템   - 목표시스템 분석․설계   - 개발 및 단위 테스트   - 통합테스트○ 기반환경 및 시스템구축   - 계획 수립 및 분석   - 개발 환경 구축   - 운영 시스템 구축   - DR 구축   - 시스템 시험○ 서비스 오픈 및 안정화   - 서비스 오픈   - 시스템 안정화○ 시스템 확산  - 초기 확산대상 선정   - 연계 API 개발 및 설치   - 통합테스트○ 시스템 운영    - 운영교육 및 기술이전   - 실손보험 청구 전산화 시스템  운영   - 시스템 유지보수※ 상기 추진 일정은 사업추진 과정에서 협의·조정될 수 있음'),
#  Document(metadata={'page': 15, 'page_label': '16', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 목표 업무프로세스'], 'table': None}, page_content='- 14 -\nⅣ  제안 요청 내용1. 목표 업무 프로세스 □ ‘실손보험 청구 전산화’란?  o 실손보험에 가입한 환자가 요청하면 요양기관이 진료내역 등을 전자문서 형태로 제3의 전송대행기관을 거쳐 보험계약을 체결한 보험사에 보내는 방식 □ 실손보험 청구 전산화 업무 구성 및 절차\n<그림5>실손보험 청구 전산화 업무 구성 및 절차  \U000f02b1 (진료내역 조회 요구) ‘실손보험 청구권자’는 ‘종합포털’에서 3년 이내 병원에 방문한 진료내역 조회 요구    - 청구권자는 본인인증 후 진료내역 조회를 요구할 수 있음'),
#  Document(metadata={'page': 16, 'page_label': '17', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 목표 업무프로세스'], 'table': None}, page_content='- 15 -\n  \U000f02b2 (진료내역 전송) 전송대행기관은 요양기관에 진료내역을 전송받아 청구자가 종합포털에서 조회할 수 있도록 함  \U000f02b3(진료정보 전송 요구) 진료목록을 확인한 ‘실손보험 청구권자’는 보험금을 청구할 진료내역을 선택하고, 보험금 청구서 및 개인정보 동의서를 작성하여 진료정보를 보험사에 전송하도록 요청     - 보험금 청구서와 개인정보동의서를 작성해야 하며, 실손보험을 체결한 보험사에만 진료정보 전송 요청이 가능함     - (필수청구서류) ① 진료비 영수증, ② 약제비 영수증, ③ 진료비 세부내역서, ④ 처방전   \U000f02b4 (진료정보 전송 : 요양기관 → 전송대행기관) 전송 요청을 받은 전송대행기관은 해당 진료정보를 보유하고 있는 요양기관으로부터 진료정보를  전송받음  \U000f02b5 (진료정보 전송 : 전송대행기관 → 보험사) 전송받은 진료정보를 보험금을 청구하는 보험사로 전송  \U000f02b6 (청구결과 안내) 보험사는 보험금 심사 결과를 청구자에게 안내하고 보험금을 지급'),
#  Document(metadata={'page': 17, 'page_label': '18', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['1. 목표 업무프로세스'], 'table': None}, page_content='- 16 -\n □ 목표 업무 프로세스(안)\n<그림6>실손보험 청구 목표 업무 프로세스(안) o(보험금 청구권자 역할) 보험금 청구 필요 서류 전송 요청, 개인 의료데이터 수집 활용의 승인을 위한 동의권 행사  - 보유계약 조회 : 보유하고 있는 실손보험을 조회하여 청구할 보험사 선택  - 진료내역 조회 : 중계 포털에 접속하여 본인인증 후 본인의 진료내역목록을 조회하고 청구할 진료내역을 선택   - 사고접수 : 보험금 청구서, 보험사 약관 동의서, 개인정보/의료정보 제공 동의서, 지급계좌번호 등 기본정보를 작성하여 청구 접수 요청 후 접수완료 여부 확인 o (전송대행기관 역할) 실손보험 청구 전산화 시스템 운영 및 관리, 환자의 동의 및 진료정보 전송 요청에 근거하여 요양기관에서 보유하고 있는 정보주체의 의료데이터를 제공받아 전자적 형태로 유통하는 허브 역할을 수행'),
#  Document(metadata={'page': 18, 'page_label': '19', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['2. 목표시스템 개념도'], 'table': None}, page_content='- 17 -\n  - 진료내역 조회 : 요양기관에 실손보험 청구권자의 진료내역을 요청하고 조회된 목록을 종합포털에 보여줌  - 사고접수 : 보험금 청구권자의 보유계약이 조회되지 않을 경우 보험사 시스템에서 계약조회  - 청구정보 전송 : 전송받은 진료데이터를 표준양식에 맞게 처리하고 EDI 전문생성하여 이미지 파일과 함께 보험사에 청구서 전송     ※ 사고접수 요청 시 요양기관으로부터 전송받은 진료데이터로 이미지 형태(PDF) 파일 생성     ※ 입력된 보험금 청구 내용으로 이미지 형식(PDF)의 청구서 생성  - 청구완료 : 보험사로부터 청구 접수 성공 여부를 전송받아 종합포털에 보여줌 o (요양기관 역할) 보유하고 있는 의료정보를 보험금 청구자의 요청에 따라 전송     ※ 의료정보는 요양기관 EMR 시스템을 통해 전송됨 - 진료내역 조회 : 요청자의 진료내역을 전송 - 청구정보 전송 : 병원서류 원본 파일 및 의료데이터를 전송o (보험사 역할) 보험가입자의 요청에 따라 환자의 의료정보를 활용하여 실손보험 청구 심사 및 보상 지급 - 청구접수 : 청구서를 접수받고 접수 성공 여부를 전송대행기관으로 전송'),
#  Document(metadata={'page': 19, 'page_label': '20', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['2. 목표시스템 개념도'], 'table': None}, page_content='- 18 -\n2. 목표시스템 개념도 2.1 어플리케이션 구성도\n외부인터넷\n관리자사용자\n개발자\n<그림7>목표시스템 개념도 o (사용자) 실손보험 가입자가 전송대행기관에서 제공하는 대국민 채널(모바일 앱/웹)로 접속하여 실손 청구업무를 수행 o (중계 시스템) 사용자의 요청에 따라 요양병원의 진료내역을 확인하고 실손 청구에 필요한 서류를 발급 o (API 관리시스템) 실손 청구 시 데이터 Mapping 작업 수행   - 실손 청구용 진료데이터를 보험사 포맷으로 변환하여 전송   - 요양기관에서 제공하는 실손청구에 필요한 데이터를 수신하여 중계 플랫폼으로 전송 o (콜센터) 실손 청구 작업 수행 시 발생한 오류, 문의사항 및 개선사항 등에 대한 접수 및 응대'),
#  Document(metadata={'page': 20, 'page_label': '21', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 과업대상 범위'], 'table': None}, page_content='- 19 -\n o (관리자) 대국민 채널(모바일 앱/웹)에 대한 관리 및 요양기관별 전송 데이터에 대한 데이터 연결 정보 관리  ※ 요양기관 EMR 변경이 필요한 사항은 요양기관 책임하에 진행 2.2 하드웨어 구성도\n보험개발원에 방문하여 열람 가능'),
#  Document(metadata={'page': 21, 'page_label': '22', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 과업대상 범위'], 'table': None}, page_content='- 20 -\n3. 과업대상 범위\n진료시스템원무시스템진료지원시스템고객정보서비스경영관리시스템전자의무기록(EMR)\n<그림8>과업대상  ※ 과업 범위는 구축 사업자 선정 후 우선협상 혹은 사업 이행기간 동안 협의 가능  ※※ 과업 대상 범위는 점선으로 표시함□ (과업1) 실손보험 청구 중계시스템 o 실손보험 청구를 위한 회원관리, 약관 동의, 인증/식별, 보험 및 진료내역 입수, 청구처리, 보험사 전송, 알림 등 기본 기능 구현 o 청구 데이터 및 청구 서류 정보 유효성, 무결성 검증   - 진료비 계산서, 진료비 세부내역서, 약제비 영수증, 처방전 등    o 청구 중계시스템의 백오피스 관리 기능 구현  - 요양기관 및 보험사 관리, 병원 및 보험사 매핑, 청구 리스트, API 및 시스템 관리 기능 등 o 청구 전산화 시스템의 운영·관리, 자료의 수집·전송, 자료의 정확성 확보 등을 관리하기 위한 시스템 운영지침 마련'),
#  Document(metadata={'page': 22, 'page_label': '23', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 과업대상 범위'], 'table': None}, page_content='- 21 -\n□ (과업 2) 데이터 송·수신 인터페이스 구축     (요양기관 ⇔ 전송대행기관 ⇔ 보험회사)  o 요양기관 EMR 시스템과 청구 중계 시스템 연결을 위한 API Gateway 개발    - API관리, DB연결, 인증키 관리, 로그관리, IP관리, 모니터링 등  o 요양기관 내 자료 요청 수신 및 전송을 위한 연계 API서버 구축    - 연계항목, 연계방식, 청구내역 추출 연계개발 가이드 구성    - (이용 명세) 대국민포털을 통해 이용자가 선택한 요양기관으로부터 해당 이용자의 이용 명세 요청 및 수집    - (증빙서류) 실손보험 보험금 청구 접수 시, 해당 요양기관에 청구 대상 건 증빙서류 전자문서 발급 요청 및 수집    - (가입내역) 한국신용정보원을 통해 이용자의 보험 가입 확인 요청    - (변환·매핑) 요양기관/EMR로부터 수집된 실손 청구 관련 데이터를 보험사 청구 양식(표준 레이아웃)에 맞게 변환 및 매핑 (진료비 계산서, 진료비 세부내역서, 약제비 영수증, 처방전)  o 실손보험 청구 데이터 전송을 위한 보험사 연계 (전용망, VPN 등) □ (과업 3) 요양기관 EMR 시스템 대응개발  o 요양기관 내 EMR시스템과 API G/W 및 Agent 설치 및 연계  o 요양기관에서 사용하고 있는 EMR시스템을 환자 요청에 따라 필요한 전자문서를 생성, 전송대행기관에 보낼 수 있도록 수정개발 지원   - 진료 DB로부터 실손의료보험 보험금 청구에 필요한 항목을 추출하여 전자문서 레이아웃에 맞추어 변환 및 전송 기능 개발'),
#  Document(metadata={'page': 23, 'page_label': '24', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 과업대상 범위'], 'table': None}, page_content='- 22 -\n□ (과업 4) 대국민 서비스 시스템 구축  o 약관동의, 인증, 회원가입, 보험사조회, 진료기록 조회, 진료내역 선택, 청구내용 확인 등 실손보험 청구에 필요한 기능 구현  o 모바일 앱 및 웹 시스템 구축  o 제휴 앱을 통한 API 연동 및 아웃링크 기능 제공  o 청구 이력, 단계별 알림 등 사용자 편의를 위한 기능 제공  o (인프라) WEB 및 휴대폰 앱 등의 채널 수용을 위한 정보시스템 인프라 구축(H/W, S/W, N/W)  o (본인인증) 대국민포털을 통한 이용자 본인인증  o (현황조회) 대국민포털을 통한 이용자의 실손보험 보험금 청구 진행 현황조회   o (전자문서) 이용자 희망 시, 대국민 포털을 통한 청구 대상 건 증빙서류 전자문서 조회 (청구 완료 및 청구 진행 건)□ (과업 5) 실손보험 청구 콜센터 시스템 구축  o 대국민 콜센터 인프라 및 시스템 주요 기능 구축   - IVR, CTI, 녹취, 상담원 어플리케이션 등   - 전화, 인터넷, 챗봇 등의 채널 수용을 위한 정보시스템 인프라 구축(H/W, S/W, N/W)  o 챗봇, 상담톡 등 단순문의 안내 서비스 채널 구성   - 지능형 상담 서비스 구현  o 사용자 접근이 용이하도록 전화, 모바일앱 등 옴니채널 구성'),
#  Document(metadata={'page': 24, 'page_label': '25', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['3. 과업대상 범위'], 'table': None}, page_content='- 23 -\n  o (상담관리) 신속한 상담서비스 제공 및 상담정보 분석/활용을 위한 상담관리 시스템 구축 및 지원체계 확보  o (시스템연계) 보안 규정 준수를 통한 대국민포털 및 중계시스템 연계 서비스 구축      ※ 청구 증빙서류 전자문서 암호화 전송      ※ 민감정보 보안성 유지를 위한 세부 진료내역 저장 제한      ※ 참여기관 및 가입자 포털 시스템 항시 가용성 유지□ (과업 6) 재해복구 시스템 환경 구축 (DR) o 장애 및 데이터 손실 방지를 위해 백업 체계 구축      - 데이터 실시간 볼륨 복제 등 o 업무 중요도에 따라 RTO1)/RPO2) 요건을 정의하고 DR유형을 선정     - Mirror, Hot, Warm, Cold Site o 재해복구 사이트에 서버, 스토리지, 네트워크 등 DR 인프라 및 시스템 구축□ (과업 7) 정보보호 체계 구축 o 실손보험 청구 전산화 시스템 내 구간별 보안 인프라 및 시스템 구축, 적용 o 식별 및 인증, 암호화, 단말기 보안, 네트워크 보안, 계정관리, 로그관리, 서버 보안, 접근통제 응용 프로그램 등1) Recovery Time Objective2) Recovery Point Objective'),
#  Document(metadata={'page': 25, 'page_label': '26', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': None}, page_content='- 24 -\n□ (과업 8) 요양기관/EMR 업체 계약 지원   o 실손보험 청구 시스템 확산에 따른 요양기관별 서비스 이행, 개발비용 관련 계약 수행 지원      - 요양기관별 의사결정자 식별, 계약 내용 사전 협의, 계약 체결 지원 등     - 요양기관/EMR 관련 업체 개발비는 포함되지 않음'),
#  Document(metadata={'page': 26, 'page_label': '27', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': '□ 요구사항 총괄표', 'table_num': 26.0, 'table_content':                           0                                   1        2  \
#  0                   요청사항 구분                             요청사항 구분   ID부여규칙
#  1       (1) 공통설계 요구사항 (CDR)          Common Design\nRequirement  CDR-000
#  2        (2) 컨설팅 요구사항 (CSR)              Consulting Requirement  CSR-000
#  3   (3) 시스템 장비구성 요구사항 (ECR)  Equipment Composition\nRequirement  ECR-000
#  4         (4) 기능 요구사항 (FUN)        System Function\nRequirement  FUN-000
#  5        (5) 데이터 요구사항 (DAR)                    Data Requirement  DAR-000
#  6         (6) 성능 요구사항 (PER)            Performance\nRequirement  PER-000
#  7      (7) 인터페이스 요구사항 (INR)       System Interface\nRequirement  INR-000
#  8        (8) 테스트 요구사항 (TER)                    Test Requirement  TER-000
#  9         (9) 보안 요구사항 (SER)                Security Requirement  SER-000
#  10       (10) 품질 요구사항 (QUR)                 Quality Requirement  QUR-000
#  11          (11) 제약사항 (COR)              Constraint Requirement  COR-000
#  12   (12) 프로젝트관리 요구사항 (PMR)     Project Management\nRequirement  PMR-000
#  13   (13) 프로젝트지원 요구사항 (PSR)        Project Support\nRequirement  PSR-000
#  14                       합계                                  합계       합계
#
#           3
#  0   요구 사항수
#  1        5
#  2        3
#  3       15
#  4       28
#  5       10
#  6        6
#  7        5
#  8        6
#  9        8
#  10       2
#  11       3
#  12       5
#  13       5
#  14     101  }}, page_content='- 25 -\n4. 상세요구 사항□ 요구사항 총괄표요청사항 구분ID부여규칙요구     사항수(1) 공통설계 요구사항 (CDR)Common Design RequirementCDR-0005(2) 컨설팅 요구사항 (CSR)Consulting RequirementCSR-0003(3) 시스템 장비구성 요구사항 (ECR)Equipment Composition RequirementECR-00015(4) 기능 요구사항 (FUN) System Function RequirementFUN-000 28(5) 데이터 요구사항 (DAR)Data RequirementDAR-00010(6) 성능 요구사항 (PER)Performance RequirementPER-0006(7) 인터페이스 요구사항 (INR)System Interface RequirementINR-0005(8) 테스트 요구사항 (TER)Test RequirementTER-0006(9) 보안 요구사항 (SER)Security RequirementSER-0008(10) 품질 요구사항 (QUR) Quality RequirementQUR-0002(11) 제약사항 (COR)Constraint RequirementCOR-0003(12) 프로젝트관리 요구사항 (PMR)Project Management RequirementPMR-0005(13) 프로젝트지원 요구사항 (PSR)Project Support RequirementPSR-0005합계101'),
#  Document(metadata={'page': 27, 'page_label': '28', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 27.0, 'table_content':                  0        1                            2
#  0             None     고유번호                         None
#  1       공통설계\n요구사항  CDR-001                  공통 기술 수행 요건
#  2       공통설계\n요구사항  CDR-002               네트워크 스위치 표준 규격
#  3       공통설계\n요구사항  CDR-003         네트워크 구성 및 보안강화 공통 요건
#  4       공통설계\n요구사항  CDR-004                   보안장비 표준 규격
#  5       공통설계\n요구사항  CDR-005                     서버 표준 규격
#  6         컨설팅 요구사항  CSR-001          실손보험 청구 시스템 운영방안 제시
#  7         컨설팅 요구사항  CSR-002        요양기관 내 청구 데이터 관리방안 제시
#  8         컨설팅 요구사항  CSR-003  실손보험 청구 시스템 관련 유사사례 조사 · 분석
#  9   시스템 장비구성\n요구사항  ECR-001            HCI 클라우드 컴퓨팅서버 구축
#  10  시스템 장비구성\n요구사항  ECR-002                 배치 및 DB서버 구축
#  11  시스템 장비구성\n요구사항  ECR-003                      Rack 도입
#  12  시스템 장비구성\n요구사항  ECR-004         저장장치 및 SAN 스위치 도입 구축
#  13  시스템 장비구성\n요구사항  ECR-005                      백업체계 구축
#  14  시스템 장비구성\n요구사항  ECR-006              실손청구 재해복구시스템 구축
#  15  시스템 장비구성\n요구사항  ECR-007                 어플라이언스 장비 구축
#  16  시스템 장비구성\n요구사항  ECR-008                 시스템 소프트웨어 설치
#  17  시스템 장비구성\n요구사항  ECR-009                  상용 소프트웨어 설치
#  18  시스템 장비구성\n요구사항  ECR-010           웹기반의 PDF 변환 서버 솔루션
#  19  시스템 장비구성\n요구사항  ECR-011    HTML5 기반의 PDF 스트리밍 뷰어 솔루션
#  20  시스템 장비구성\n요구사항  ECR-012                  보안 소프트웨어 설치
#  21  시스템 장비구성\n요구사항  ECR-013                     보안 장비 구축
#  22  시스템 장비구성\n요구사항  ECR-014                   네트워크 장비 구축
#  23  시스템 장비구성\n요구사항  ECR-015                개발 장비 및 환경 구축
#  24         기능 요구사항  FUN-001                  통합 인증 기능 개발
#  25         기능 요구사항  FUN-002                진료기록 조회 기능 개발
#  26         기능 요구사항  FUN-003              실손 제증명 발급 기능 개발
#  27         기능 요구사항  FUN-004                실손보험 조회 기능 개발
#  28         기능 요구사항  FUN-005                  실손 청구 기능 개발
#  29         기능 요구사항  FUN-006            실손 청구 내역 조회 기능 개발
#  30         기능 요구사항  FUN-007                         None}}, page_content='- 26 -\n1. 요구사항 목록요구사항고유번호요구사항 명칭공통설계 요구사항CDR-001공통 기술 수행 요건CDR-002네트워크 스위치 표준 규격CDR-003네트워크 구성 및 보안강화 공통 요건CDR-004보안장비 표준 규격CDR-005서버 표준 규격컨설팅 요구사항CSR-001실손보험 청구 시스템 운영방안 제시CSR-002요양기관 내 청구 데이터 관리방안 제시CSR-003실손보험 청구 시스템 관련 유사사례 조사 · 분석\n시스템 장비구성 요구사항\nECR-001HCI 클라우드 컴퓨팅서버 구축ECR-002배치 및 DB서버 구축ECR-003Rack 도입ECR-004저장장치 및 SAN 스위치 도입 구축ECR-005백업체계 구축ECR-006실손청구 재해복구시스템 구축ECR-007어플라이언스 장비 구축 ECR-008시스템 소프트웨어 설치ECR-009상용 소프트웨어 설치ECR-010웹기반의 PDF 변환 서버 솔루션ECR-011HTML5 기반의 PDF 스트리밍 뷰어 솔루션ECR-012보안 소프트웨어 설치ECR-013보안 장비 구축ECR-014네트워크 장비 구축ECR-015개발 장비 및 환경 구축\n기능 요구사항FUN-001통합 인증 기능 개발FUN-002진료기록 조회 기능 개발FUN-003실손 제증명 발급 기능 개발FUN-004실손보험 조회 기능 개발FUN-005실손 청구 기능 개발FUN-006실손 청구 내역 조회 기능 개발FUN-007마이페이지 기능 개발'),
#  Document(metadata={'page': 28, 'page_label': '29', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 28.0, 'table_content':            0        1                                        2
#  0       None     고유번호                                     None
#  1       None  FUN-008                           공지 및 게시판 기능 개발
#  2       None  FUN-009                       디지털 소외 계층 포용 방안 제시
#  3       None  FUN-010                             요양기관 포털기능 개발
#  4       None  FUN-011                              보험사 포털기능 개발
#  5       None  FUN-012                       데이터 라이프사이클 관리체계 구축
#  6       None  FUN-013                       실시간 수집처리 플랫폼 기능 개발
#  7       None  FUN-014                  요양기관 실손청구 기본정보 관리 기능 개발
#  8       None  FUN-015                   보험사 실손청구 기본정보 관리 기능 개발
#  9       None  FUN-016                             데이터 검증 기능 개발
#  10      None  FUN-017                             데이터 통계 기능 개발
#  11      None  FUN-018                      정보제공 서비스 및 알림 기능 개발
#  12      None  FUN-019                           콜센터 솔루션 커스터마이징
#  13      None  FUN-020                      콜센터 IP-PBX 교환기 요구사항
#  14      None  FUN-021                          콜센터 IP-IVR 요구사항
#  15      None  FUN-022                        콜센터 CTI 미들웨어 요구사항
#  16      None  FUN-023                       콜센터 IP 녹취 솔루션 요구사항
#  17      None  FUN-024                      콜센터 통합운용관리 솔루션 요구사항
#  18      None  FUN-025  콜센터 콜백서비스 ACS(Auto Calling System) 요구사항
#  19      None  FUN-026                 콜센터 챗봇 & Talk 상담솔루션 요구사항
#  20      None  FUN-027                        콜센터 시스템 보안관련 요구사항
#  21      None  FUN-028                        종합 모니터링 시스템 기능 개발
#  22  데이터 요구사항  DAR-001                              데이터 아키텍처 정의
#  23  데이터 요구사항  DAR-002                                  데이터 표준화
#  24  데이터 요구사항  DAR-003                                    DB 설계
#  25  데이터 요구사항  DAR-004                       데이터 및 데이터베이스 성능 점검
#  26  데이터 요구사항  DAR-005                          개발 및 검증용 데이터 이관
#  27  데이터 요구사항  DAR-006                      데이터(파일/DB) 보존 정책 수립
#  28  데이터 요구사항  DAR-007                           데이터 품질 점검 및 개선
#  29  데이터 요구사항  DAR-008                                연계 데이터 관리
#  30  데이터 요구사항  DAR-009                              메타데이터 관리시스템
#  31  데이터 요구사항  DAR-010                                     None}}, page_content='- 27 -\n요구사항고유번호요구사항 명칭FUN-008공지 및 게시판 기능 개발FUN-009디지털 소외 계층 포용 방안 제시FUN-010요양기관 포털기능 개발FUN-011보험사 포털기능 개발FUN-012데이터 라이프사이클 관리체계 구축FUN-013실시간 수집처리 플랫폼 기능 개발FUN-014요양기관 실손청구 기본정보 관리 기능 개발FUN-015보험사 실손청구 기본정보 관리 기능 개발FUN-016데이터 검증 기능 개발FUN-017데이터 통계 기능 개발FUN-018정보제공 서비스 및 알림 기능 개발FUN-019콜센터 솔루션 커스터마이징FUN-020콜센터 IP-PBX 교환기 요구사항FUN-021콜센터 IP-IVR 요구사항FUN-022콜센터 CTI 미들웨어 요구사항FUN-023콜센터 IP 녹취 솔루션 요구사항FUN-024콜센터 통합운용관리 솔루션 요구사항FUN-025콜센터 콜백서비스 ACS(Auto Calling System) 요구사항FUN-026콜센터 챗봇 & Talk 상담솔루션 요구사항FUN-027콜센터 시스템 보안관련 요구사항FUN-028종합 모니터링 시스템 기능 개발\n데이터 요구사항\nDAR-001데이터 아키텍처 정의DAR-002데이터 표준화DAR-003DB 설계DAR-004데이터 및 데이터베이스 성능 점검DAR-005개발 및 검증용 데이터 이관DAR-006데이터(파일/DB) 보존 정책 수립DAR-007데이터 품질 점검 및 개선DAR-008연계 데이터 관리DAR-009메타데이터 관리시스템DAR-010데이터 정합성 검증'),
#  Document(metadata={'page': 29, 'page_label': '30', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 29.0, 'table_content':                0        1                            2
#  0           None     고유번호                         None
#  1        성능 요구사항  PER-001                        성능 일반
#  2        성능 요구사항  PER-002           모바일앱/웹페이지 디스플레이 시간
#  3        성능 요구사항  PER-003                      오류 응답시간
#  4        성능 요구사항  PER-004                 표준 I/F 성능 요건
#  5        성능 요구사항  PER-005                   시스템 자원 효율성
#  6        성능 요구사항  PER-006                        DB 성능
#  7    인터페이스\n요구사항  INR-001                 사용자 인터페이스 구성
#  8    인터페이스\n요구사항  INR-002                         웹접근성
#  9    인터페이스\n요구사항  INR-003    대외 연계 API서비스 개발 및 관리 요구사항
#  10   인터페이스\n요구사항  INR-004          보험사 표준 I/F 관리 기능 개발
#  11   인터페이스\n요구사항  INR-005         요양기관 표준 I/F 관리 기능 개발
#  12      테스트 요구사항  TER-001                    테스트 수행 방안
#  13      테스트 요구사항  TER-002                        단위테스트
#  14      테스트 요구사항  TER-003                        통합테스트
#  15      테스트 요구사항  TER-004                       시스템테스트
#  16      테스트 요구사항  TER-005                        인수테스트
#  17      테스트 요구사항  TER-006                   통합 시험환경 구성
#  18       보안 요구사항  SER-001          보험개발원 보안정책에 따른 유의사항
#  19       보안 요구사항  SER-002                       페이지 보안
#  20       보안 요구사항  SER-003                       기술적 보안
#  21       보안 요구사항  SER-004                       개인정보보호
#  22       보안 요구사항  SER-005                   취약점진단체계 구축
#  23       보안 요구사항  SER-006                    보안 취약점 점검
#  24       보안 요구사항  SER-007                     시큐어코딩 점검
#  25       보안 요구사항  SER-008                   서버(호스트) 보안
#  26       품질 요구사항  SER-008                   서버(호스트) 보안
#  27       품질 요구사항  QUR-001                상호운용성(데이터교환성)
#  28       품질 요구사항  QUR-002              변경 요구 및 변경처리 절차
#  29          제약사항  QUR-002              변경 요구 및 변경처리 절차
#  30          제약사항  COR-001                       표준화 요건
#  31          제약사항  COR-002  소프트웨어 개발보안(시큐어코딩) 관련 가이드 준수
#  32          제약사항  COR-003                프로그램 개발 표준 준수
#  33  프로젝트관리\n요구사항  COR-003                프로그램 개발 표준 준수
#  34  프로젝트관리\n요구사항  PMR-001                     관리방법론 제시
#  35  프로젝트관리\n요구사항  PMR-002                         None}}, page_content='- 28 -\n요구사항고유번호요구사항 명칭성능 요구사항PER-001성능 일반PER-002모바일앱/웹페이지 디스플레이 시간PER-003오류 응답시간PER-004표준 I/F 성능 요건PER-005시스템 자원 효율성PER-006DB 성능인터페이스 요구사항INR-001사용자 인터페이스 구성INR-002웹접근성INR-003대외 연계 API서비스 개발 및 관리 요구사항INR-004보험사 표준 I/F 관리 기능 개발INR-005요양기관 표준 I/F 관리 기능 개발테스트 요구사항TER-001테스트 수행 방안TER-002단위테스트TER-003통합테스트TER-004시스템테스트TER-005인수테스트TER-006통합 시험환경 구성\n보안 요구사항SER-001보험개발원 보안정책에 따른 유의사항SER-002페이지 보안SER-003기술적 보안SER-004개인정보보호SER-005취약점진단체계 구축SER-006보안 취약점 점검SER-007시큐어코딩 점검SER-008서버(호스트) 보안품질 요구사항QUR-001상호운용성(데이터교환성)QUR-002변경 요구 및 변경처리 절차제약사항COR-001표준화 요건COR-002소프트웨어 개발보안(시큐어코딩) 관련 가이드 준수COR-003프로그램 개발 표준 준수프로젝 트관리 요구사항PMR-001관리방법론 제시PMR-002일정관리'),
#  Document(metadata={'page': 30, 'page_label': '31', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': '1) 공통설계 요구사항(Common Design Requirement)', 'table_num': 30.1, 'table_content':             0          1                                                  2
#  0   요구사항 고유번호  요구사항 고유번호                                            CDR-001
#  1     요구사항 명칭    요구사항 명칭                                        공통 기술 수행 요건
#  2     요구사항 분류    요구사항 분류                                         공통 설계 요구사항
#  3  요구사항\n상세설명         정의                                        공통 기술 수행 요건
#  4  요구사항\n상세설명      세부 내용  ○ DB, AP, 개발 영역은 IP대역을 분리\n○ 개발 영역은 방화벽으로 분리\n...}}, page_content='- 29 -\n2. 상세 요구사항1) 공통설계 요구사항(Common Design Requirement)\n요구사항고유번호요구사항 명칭PMR-003일정 지연 방지PMR-004산출물 관리 및 보고PMR-005참여인력관리프로젝 트지원 요구사항PSR-001유지관리 지원 방안PSR-002교육지원PSR-003안정화 활동PSR-004안정화 운영지원 인력PSR-005기타 지원 요구사항\n요구사항 고유번호 CDR-001요구사항 명칭공통 기술 수행 요건요구사항 분류공통 설계 요구사항\n요구사항상세설명\n정의공통 기술 수행 요건\n세부 내용\n○ DB, AP, 개발 영역은 IP대역을 분리○ 개발 영역은 방화벽으로 분리○ 제안기기는 우리원의 IT 인프라 환경을 제안할 것 - 시스템 구성도 및 기기 사양, 산출근거 등 명시 - 제안기기는 제조사의 최신 장비로 제안하고 판매 중단에 대한 이슈가 없을 것 - 3년 이내에 제품이 단종 될 경우, 이에 대한 대응 및 지원 방안을 명시할 것○ 우리원에서 산정한 전산기기 규모를 참조하여 원활한 업무처리가 가능하도록 충분한 자원을 공급하고 확장성을 확보할 것○ 제안기기는 주센터와 DR센터에 서버별 동일 플랫폼으로 각각 설치·구축하고 정상적으로 작동할 것○ 시스템 운영체제(OS) 파일을 백업○ 시스템 구축과 관련된 네트워크 및 설치 제반공사를 수행할 것 - 콘솔 연결용 통신 케이블 및 젠더 제공 - 네트워크 연결 공사 일체○  제안기기의 설치 및 시스템 테스트 수행 중 2회 이상 동일한 유형의 장애 또 는 오류 등의 하자발생 시 무조건 기기 교환하여 공급할 것○  본 사업으로 도입되는 제품의 설치·구성 및 소프트웨어 개발 일체의 작업은 현업 시스템의 무중단을 원칙으로 수행되어야 함'),
#  Document(metadata={'page': 31, 'page_label': '32', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': '- 부득이하게 현업시스템의 중단(순단 포함)이 발생되는 경우, 상세 작업계획을 사\n전에 수립하여 발주기관의 승인을 득해야 하며, 미승인으로 인한 책임은 수행사\n에 귀속됨\n산출정보 작업계획서\n관련요구사항 설치 및 작업 결과 보고서', 'table_num': 31.0, 'table_content':             0          1                                                  2  \
#  0   요구사항 고유번호  요구사항 고유번호                                            CDR-002
#  1     요구사항 명칭    요구사항 명칭                                     네트워크 스위치 표준 규격
#  2     요구사항 분류    요구사항 분류                                         공통 설게 요구사항
#  3  요구사항\n상세설명         정의  네트워크 스위치 표준 규격 정의\n○ 네트워크 스위치 공통사항\n- 전원부 이중화 ...
#  4  요구사항\n상세설명      세부 내용                                                 구분
#  5  요구사항\n상세설명      세부 내용                                             Router
#  6  요구사항\n상세설명      세부 내용                             BackBone\nSwitch Type1
#  7  요구사항\n상세설명      세부 내용                             BackBone\nSwitch Type2
#
#                                                     3
#  0                                            CDR-002
#  1                                     네트워크 스위치 표준 규격
#  2                                         공통 설게 요구사항
#  3  네트워크 스위치 표준 규격 정의\n○ 네트워크 스위치 공통사항\n- 전원부 이중화 ...
#  4                               네트워크장비 세부 요구 사양 및 성능
#  5  - SFP+ 24 port 이상\n- 10GE 4 Port 이상\n- 최대 대역폭 ...
#  6  - 6 slot 샤시 이상\n- Supervisor 1 Module 이상\n- 25...
#  7  - 4 slot 샤시 이상\n- Supervisor 1 Module 이상\n- 25...  }}, page_content='- 30 -\n - 부득이하게 현업시스템의 중단(순단 포함)이 발생되는 경우, 상세 작업계획을 사전에 수립하여 발주기관의 승인을 득해야 하며, 미승인으로 인한 책임은 수행사에 귀속됨산출정보작업계획서관련요구사항설치 및 작업 결과 보고서요구사항 고유번호CDR-002요구사항 명칭네트워크 스위치 표준 규격요구사항 분류공통 설게 요구사항 \n요구사항상세설명\n정의네트워크 스위치 표준 규격 정의\n세부 내용\n○ 네트워크 스위치 공통사항 - 전원부 이중화 및 hotswap 기능 - 포트 미러링 기능 제공(GSLB 제외) - 미러링 기능 제공(GSLB 제외)○ 네트워크 스위치 유형에 따른 규격은 다음과 같음구분네트워크장비 세부 요구 사양 및 성능Router - SFP+ 24 port 이상 - 10GE 4 Port 이상 - 최대 대역폭 : 10G 이상(합계: 20G 이상) - 전원 공급 장치 이중화 - 전체 포트 GIBC 제공 - 회선 이중화 BGB 구성BackBone Switch Type1 - 6 slot 샤시 이상 - Supervisor 1 Module 이상 - 25GE/10GE/1GE 96 Port 이상 - Copper 48 Port 이상 - Power Module 4 이상 - 구성에 맞는 GBIC Module 제공BackBone Switch Type2 - 4 slot 샤시 이상 - Supervisor 1 Module 이상 - 25GE/10GE/1GE 48 Port 이상 - Copper 48 Port 이상 - Power Module 2 이상 - 구성에 맞는 GBIC Module 제공'),
#  Document(metadata={'page': 32, 'page_label': '33', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 32.0, 'table_content':                   0                                                  1
#  0  L4 Switch\nType1  - SFP+ 24 port 이상\n- 32GB Memory 이상\n- 20 Gbps...
#  1  L4 Switch\nType2  - SFP+ 24 port 이상\n- 32GB Memory 이상\n- 12 Gbps...
#  2  L3 Switch\nType1  - 1G/10G/25G 48 Port 이상\n- 40G/100G : 4 Port 이...
#  3  L3 Switch\nType2  - 1G/10G 48 Port 이상\n- UTP 48 Port 이상\n- 전원 공급...
#  4  L2 Switch\nType1  - 1G/10G 48 Port 이상\n- UTP 48 Port 이상\n- 전원 공급...
#  5  L2 Switch\nType2  - 1G/10G 48 Port 이상\n- UTP 24 Port 이상\n- 전원 공급...
#  6      납품확인서, 제품설명서                                       납품확인서, 제품설명서
#  7       기술지원 확약서 제출                                        기술지원 확약서 제출}}, page_content='- 31 -\nL4 Switch Type1 - SFP+ 24 port 이상 - 32GB Memory 이상 - 20 Gbps Throughput 이상 - Max 20 Gbps Throughput 이상 - SFP+ 10G Transceiver * 20 이상 - RoHS - Dual AC Power Supply - TCP Connection 1,400,000 CPS 제공L4 Switch Type2 - SFP+ 24 port 이상 - 32GB Memory 이상 - 12 Gbps Throughput 이상 - Max 12 Gbps Throughput 이상 - SFP+ 10G Transceiver * 20 이상 - RoHS - Dual AC Power SupplyL3 Switch Type1 - 1G/10G/25G 48 Port 이상 - 40G/100G : 4 Port 이상 - 전원 공급 장치 이중화 - 구성에 맞는 GBIC Module 제공L3 Switch Type2 - 1G/10G 48 Port 이상 - UTP 48 Port 이상 - 전원 공급 장치 이중화L2 Switch Type1 - 1G/10G 48 Port 이상 - UTP 48 Port 이상 - 전원 공급 장치 이중화L2 Switch Type2 - 1G/10G 48 Port 이상 - UTP 24 Port 이상 - 전원 공급 장치 이중화산출정보납품확인서, 제품설명서관련요구사항기술지원 확약서 제출'),
#  Document(metadata={'page': 33, 'page_label': '34', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 33.0, 'table_content':              0          1                                                  2
#  0    요구사항 고유번호  요구사항 고유번호                                            CDR-003
#  1      요구사항 명칭    요구사항 명칭                               네트워크 구성 및 보안강화 공통 요건
#  2      요구사항 분류    요구사항 분류                                         공통 설계 요구사항
#  3   요구사항\n상세설명         정의                               네트워크 구성 및 보안강화 공통 요건
#  4   요구사항\n상세설명      세부 내용  ○ 네트워크 및 보안강화를 위해 랙 마운트, 케이블 포설, 네트워크 및 보안장비\n...
#  5         산출정보       산출정보                                   보안취약점 진단 및 개선 결과
#  6       관련요구사항     관련요구사항                                        기술지원 확약서 제출
#  7    요구사항 고유번호  요구사항 고유번호                                            CDR-004
#  8      요구사항 명칭    요구사항 명칭                                         보안장비 표준 규격
#  9      요구사항 분류    요구사항 분류                                         공통 설계 요구사항
#  10  요구사항\n상세설명         정의                                      보안장비 표준 규격 정의
#  11  요구사항\n상세설명      세부 내용  ○ 네트워크 및 보안강화를 위해 랙 마운트, 케이블 포설, 네트워크 및 보안장비\n...}}, page_content='- 32 -\n요구사항 고유번호 CDR-003요구사항 명칭네트워크 구성 및 보안강화 공통 요건요구사항 분류공통 설계 요구사항 \n요구사항상세설명\n정의네트워크 구성 및 보안강화 공통 요건\n세부 내용\n○ 네트워크 및 보안강화를 위해 랙 마운트, 케이블 포설, 네트워크 및 보안장비 설정 등에 소요되는 경비는 본 사업에 계상되어 있음 - 신규 또는 재배치되는 방화벽 정책, 네트워크 구성 및 라우팅 설정도 포함됨○ 본 사업으로 개발되는 모든 기능과 도입되는 전산자원은 보험개발원에서 제 공 하 는 보안취약점 진단 및 개선가이드를 적용하여야 함○ 본 사업으로 도입·구축되는 네트워크 및 보안장비는 보험개발원에서 기 설치된 장비와 호환성을 보장하여야 함○ 본 사업에서 수행되는 네트워크 및 보안장비 설치·구축 작업은 다운타임을 최소화한 작업 또는 전환계획서를 작업일 이전 최소 5일전에 제출하고, 보험개발원의 승인을 득한 후 진행하여야 함○ 보안, 가상화, 네트워크(L3 이상 스위치 및 라우터 등) 등 장비의 정보보안 요건(‘안전성 검증 필 제품’)을 만족하는 제품을 납품하여야 함  - 「국가정보보안 기본지침」(국가정보원, ’23.1.31.)산출정보보안취약점 진단 및 개선 결과관련요구사항기술지원 확약서 제출요구사항 고유번호 CDR-004요구사항 명칭보안장비 표준 규격요구사항 분류공통 설계 요구사항 \n요구사항상세설명\n정의보안장비 표준 규격 정의\n세부 내용\n○ 네트워크 및 보안강화를 위해 랙 마운트, 케이블 포설, 네트워크 및 보안장비 설정 등에 소요되는 경비는 본 사업에 계상되어 있음 - 신규 또는 재배치되는 방화벽 정책, 네트워크 구성 및 라우팅 설정도 포함됨○ 본 사업으로 개발되는 모든 기능과 도입되는 전산자원은 보험개발원에서 제 공 하 는 보안취약점 진단 및 개선가이드를 적용하여야 함○ 본 사업으로 도입·구축되는 네트워크 및 보안장비는 보험개발원에서 기 설치된 장비와 호환성을 보장하여야 함○ 본 사업에서 수행되는 네트워크 및 보안장비 설치·구축 작업은 다운타임을 최소화한 작업 또는 전환계획서를 작업일 이전 최소 3일전에 제출하고, 보험개발원의 승인을 득한 후 진행하여야 함○ 보안, 가상화, 네트워크(L3 이상 스위치 및 라우터 등) 등 장비의 정보보안 요건(‘안전성 검증 필 제품’)을 만족하는 제품을 납품하여야 함  - 「국가정보보안 기본지침」(국가정보원, ’23.1.31.)○ 보안장비 공통사항'),
#  Document(metadata={'page': 34, 'page_label': '35', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 34.0, 'table_content':                                                    0  \
#  0  - 국정원 CC 인증\n- 전원부 이중화 및 hotswap 기능\n- 1년 기간 로...
#  1                                                 구분
#  2                                               DDos
#  3                                                IPS
#  4                                                WAF
#  5                                         방화벽\nType1
#  6                                         방화벽\nType2
#
#                                                     1
#  0  - 국정원 CC 인증\n- 전원부 이중화 및 hotswap 기능\n- 1년 기간 로...
#  1                                 보안장비 세부 요구 사양 및 성능
#  2  - CPU: 2.4Ghz 12Core * 2 이상\n- Memory : 64GB 이...
#  3  - CPU: 2.4Ghz 12Core * 2 이상\n- Memory : 64GB 이...
#  4  - CPU: 2.2Ghz 10Core * 2 이상\n- Memory : 96GB 이...
#  5  - CPU: 2.6Ghz 12Core * 2 이상\n- Memory : 128GB ...
#  6  - CPU: 2.1Ghz 8Core * 2 이상\n- Memory : 64GB 이상...  }}, page_content='- 33 -\n - 국정원 CC 인증 - 전원부 이중화 및 hotswap 기능 - 1년 기간 로그 저장이 가능하도록 2TB이상 디스크 제공○ 보안장비 유형에 따른 규격은 다음과 같음구분보안장비 세부 요구 사양 및 성능DDos-CPU: 2.4Ghz 12Core * 2 이상-Memory : 64GB 이상-Disk : 2TB HDD, 64GB SSD-NIC : 10GE * 6 port 이상-성능 : Throughput(30Gbps)-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성IPS-CPU: 2.4Ghz 12Core * 2 이상-Memory : 64GB 이상-Disk : 2TB HDD, 64GB SSD-NIC : 10GE * 6 port 이상-성능 : Throughput(30Gbps)-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성\nWAF-CPU: 2.2Ghz 10Core * 2 이상-Memory : 96GB 이상-Disk : 256GB SSD, 1TB HDD(Log 저장용)-NIC : 10GE * 2 port Optical Bypass-Throughput : 18Gbps-성능 : Throughput(30Gbps)-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성\n방화벽Type1\n-CPU: 2.6Ghz 12Core * 2 이상-Memory : 128GB 이상-Disk : 512GB SSD 1식, 1.92TB*2 HDD(Log 저장용)-NIC : 10G Base-RX * 10-성능 : 양방향 100Gbps 이상, 동시 세션 30,000,000 이상-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성방화벽Type2-CPU: 2.1Ghz 8Core * 2 이상-Memory : 64GB 이상-Disk : 256GB SSD 1식, 1.92TB*2 HDD(Log 저'),
#  Document(metadata={'page': 35, 'page_label': '36', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 35.1, 'table_content':             0          1                                                  2
#  0   요구사항 고유번호  요구사항 고유번호                                            CDR-005
#  1     요구사항 명칭    요구사항 명칭                                           서버 표준 규격
#  2     요구사항 분류    요구사항 분류                                         공통 설계 요구사항
#  3  요구사항\n상세설명         정의                                        서버 표준 규격 정의
#  4  요구사항\n상세설명      세부 내용  ○ 서버 공통사항\n- HCI는 2CPU 이상의 최신 제품\n※ 서버규격의 Core...}}, page_content='- 34 -\n요구사항 고유번호 CDR-005요구사항 명칭서버 표준 규격요구사항 분류공통 설계 요구사항 \n요구사항상세설명정의서버 표준 규격 정의세 부 내용○ 서버 공통사항 - HCI는 2CPU 이상의 최신 제품  ※ 서버규격의 Core수 = Core/CPU × CPU갯수 - 전원부 이중화 및 hotswap 기능 - 내장 디스크 보호 기능(RAID, 미러링 등) - 클라우드 환경으로 도입되는 서버는 모두 동일한 CPU 아키텍처로 납품하여야 함 - 모든 서버는 오픈소스 서버가상화 소프트웨어(Openstack, KVM, Docker, Kubernates 등)와 호환성이 보장되어야 함\n장용)-NIC : 10G Base-RX * 10-성능 : 양방향 60Gbps 이상, 동시세션 15,000,000 이상-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성\n방화벽Type3\n-CPU: 3.9Ghz 2Core 이상-Memory : 8GB 이상-Disk : 128GB SSD 1식, 1TB 1식 HDD(Log 저장용)-NIC : 1000Base-SX * 4, 1000Base-TX * 8-성능 : 양방향 12Gbps 이상, 동시세션 5,000,000 이상-구성을 위한 케이블등 관련 부속자재-전원 이중화 구성DNS-초당 DNS 쿼리수(QPS) 100,000 이상-초당 DHCP 리스수(LPS) 500 이상-DNS anycast 기능으로 트래픽 로드 밸랜싱 제공-GSLB 기능 통합으로 최적의 DNS응답 제공산출정보납품확인서, 제품설명서관련요구사항기술지원 확약서 제출'),
#  Document(metadata={'page': 36, 'page_label': '37', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 36.0, 'table_content':                                                    0  \
#  0  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  1                                                 구분
#  2                                         HCI-Type-1
#  3                                         HCI-Type-2
#  4                                         HCI-Type-3
#  5                                         HCI-Type-4
#  6  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  7                                       납품확인서, 제품설명서
#  8                                        기술지원 확약서 제출
#
#                                                     1  \
#  0  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  1                                   서버 세부 요구 사양 및 성능
#  2  - CPU: 2 x 2.90GHz Intel Xeon Gold5415+, 8Core...
#  3  - CPU: 2 x 2.60GHz Intel Xeon Gold6442Y, 24Cor...
#  4  - CPU: 2 x 2.50GHz Intel Xeon Gold6426Y, 16Cor...
#  5  - CPU: 2 x 2.00GHz Intel Xeon Gold5416S, 16Cor...
#  6  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  7                                       납품확인서, 제품설명서
#  8                                        기술지원 확약서 제출
#
#                                                     2
#  0  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  1  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  2  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  3  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  4  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  5  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  6  ○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에\n문...
#  7                                       납품확인서, 제품설명서
#  8                                        기술지원 확약서 제출  }}, page_content='- 35 -\n○ 서버는 기 도입된 클라우드 서버와 VM(가상서버) 마이그레이션 등 호환성에 문제가 없어야 함○ 제안하는 서버의 경우, 「공공조달 최소녹색기준제품 구매 가이드라인」(조달청, ’23.6.5.)을 준수하여야 하며, 관련 증빙자료를 제출해야 함○ 서버 유형에 따른 최소 공통 규격은 다음과 같으며, 최소 공통 규격 이상으로 제안 가능함○ 효율적인 가용성과 성능이 요구되는 시스템에는 베어메털 서버인 X86 서버 유형에  따른 최소 공통 규격으로 제안 가능함\n \n구분서버 세부 요구 사양 및 성능HCI-Type-1 - CPU: 2 x 2.90GHz Intel Xeon Gold5415+, 8Core 이상  - Memory: 256GB - Disk: SSD 4 x 3.84TB - NIC: 4 x 25GbE Dual SFP28HCI-Type-2 - CPU: 2 x 2.60GHz Intel Xeon Gold6442Y, 24Core 이상 - Memory: 1,024GB - Disk: SSD 20 x 7.68TB - NIC: 4 x 25GbE Dual SFP28HCI-Type-3 - CPU: 2 x 2.50GHz Intel Xeon Gold6426Y, 16Core 이상 - Memory: 512GB - Disk: SSD 6 x 7.68TB - NIC: 4 x 25GbE Dual SFP28HCI-Type-4 - CPU: 2 x 2.00GHz Intel Xeon Gold5416S, 16Core 이상 - Memory: 512GB - Disk: SSD 6 x 7.68TB - NIC: 4 x 25GbE Dual SFP28산출정보납품확인서, 제품설명서관련요구사항기술지원 확약서 제출'),
#  Document(metadata={'page': 37, 'page_label': '38', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['4. 상세요구 사항'], 'table': {'table_title': None, 'table_num': 37.0, 'table_content':              0          1                                                  2
#  0    요구사항 고유번호  요구사항 고유번호                                            CSR-001
#  1      요구사항 명칭    요구사항 명칭                                실손보험 청구 시스템 운영방안 제시
#  2      요구사항 분류    요구사항 분류                                           컨설팅 요구사항
#  3   요구사항\n상세설명         정의                                실손보험 청구 시스템 운영방안 제시
#  4   요구사항\n상세설명      세부 내용  ○ 실손보험 청구 시스템 운영에 대한 업무내용, 범위, 조직, 업무 방향에 대한 추...
# ...
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   투입 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 투입 전에 다음 사항을...
#  5                                            투입 확인 사항
#  6                            노트북 등 허가받지 않은 전산장비 반입 여부
#  7                    악성코드 감염여부 점검을 위한 최신 백신프로그램 설치 여부
#  8   반입되는 PC의 초기화(포맷 등), 패스워드 설정 여부\n※ 패스워드는 숫자ㆍ영문자...
#  9                               반입되는 PC의 인터넷 접속 통제 여부
#  10  비인가 저장매체ㆍ통신기기 반입 여부\n※ USB 등 휴대형 저장매체 사용금지, 필요...
#  11                                     사무실 출입카드 지급 여부
#  12  정보접근 및 사용권한, 전산장비 보안점검, 기밀유지 준수 의무\n및 위반시 처벌사항...
#  13                                      외주인력 보안서약서 작성
#  14  주) 정상(O), 비정상(X)\n본인은 상기 업무수행을 위한 투입 확인 사항을 확인...
#
#                                                      4  \
#  0                                              신청자 정보
#  1                                                None
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   투입 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 투입 전에 다음 사항을...
#  5                                                  확인
#  6                                                None
#  7                                                None
#  8                                                None
#  9                                                None
#  10                                               None
#  11                                               None
#  12                                               None
#  13                                               None
#  14  주) 정상(O), 비정상(X)\n본인은 상기 업무수행을 위한 투입 확인 사항을 확인...
#
#                                                      5
#  0                                              신청자 정보
#  1                                                None
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   투입 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 투입 전에 다음 사항을...
#  5                                                특이사항
#  6                                                None
#  7                                                None
#  8                                                None
#  9                                                None
#  10                                               None
#  11                                               None
#  12                                               None
#  13                                               None
#  14  주) 정상(O), 비정상(X)\n본인은 상기 업무수행을 위한 투입 확인 사항을 확인...  }}, page_content='- 112 -\n[별지서식 6]외주인력 투입 확인서신청자 정보\n투입 확인 사항본인은 보험개발원(이하 ‘원’)의 프로젝트 투입 전에 다음 사항을 확인하였습니다.\n 주) 정상(O), 비정상(X)본인은 상기 업무수행을 위한 투입 확인 사항을 확인하였으며, 업무수행 중에도 관련된 내용을 준수할 것을 확인합니다.                                                                                            □ 동의20   년    월    일신 청 인 :(서 명)확 인 자:                   (서 명)   \n소속 회사소속 부서성    명 핸드폰 번호사 업 명 근무 기간20  .  .  . ~ 20  .  .  .\n투입 확인 사항확인특이사항1노트북 등 허가받지 않은 전산장비 반입 여부2악성코드 감염여부 점검을 위한 최신 백신프로그램 설치 여부3반입되는 PC의 초기화(포맷 등), 패스워드 설정 여부※ 패스워드는 숫자ㆍ영문자ㆍ특수문자를 혼합하여 8자리 이상 설정4반입되는 PC의 인터넷 접속 통제 여부5비인가 저장매체ㆍ통신기기 반입 여부※ USB 등 휴대형 저장매체 사용금지, 필요시 보안담당자 승인후 사용6사무실 출입카드 지급 여부7정보접근 및 사용권한, 전산장비 보안점검, 기밀유지 준수 의무  및 위반시 처벌사항 등에 대한 보안교육 이수 여부8외주인력 보안서약서 작성'),
#  Document(metadata={'page': 114, 'page_label': '115', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['[붙임2] 제출서식'], 'table': {'table_title': '□ 확인자 성 명 :\n(인)', 'table_num': 114.0, 'table_content':      0                                         1         2
#  0   번호                                   점 검 항 목  결과 (o/x)
#  1    1                개인 PC에 개인정보(주민번호 등) 미존재 확인      None
#  2    2             ESA(내PC지키미) 실행후 ‘취약’사항 미존재 확인      None
#  3    2                     1) 악성코드 백신 설치 및 실행 여부      None
#  4    2                    2) 악성코드 백신의 최신 업데이트 여부      None
#  5    2         3) 운영체제, MS Office의 최신 보안패치 설치 여부      None
#  6    2                     4) 로그온 패스워드 안전성 여부 점검      None
#  7    2            5) 로그온 패스워드의 분기 1회 이상 변경 여부 점검      None
#  8    2                      6) Windows 방화벽 설정 점검      None
#  9    2                    7) 사용자 공유 폴더 미설정 여부 점검      None
#  10   2                     8) USB 자동 실행 차단 여부 점검      None
#  11   2        9) 미사용(3개월) ActiveX 프로그램 미존재 여부 점검      None
#  12   3  개인용으로 설치한 P2P, 게임, 메신저, 불법소프트웨어 등 미존재 여부      None
#  13   4        PC 화면보호기 설정여부 점검(10분이내, 비밀번호 설정유무)      None
#  14   5                     부팅 패스워드(CMOS) 설정여부 점검      None
#  15   6                     무선공유기 등 비허가 장비 미설치 점검      None
#  16   7                        PC 본체 잠금장치 설치여부 점검      None
#  17   8                    업무 종료시 PC 전원 OFF 여부 점검      None
#  18   9   (외부망 PC) 비인가 웹사이트(상용메일, 웹하드 등) 접속 차단 확인      None
#  19  10                     (내부망 PC) 인터넷 접속 차단 확인      None}}, page_content='- 113 -\n[별지서식 7]외주업체 PC 점검 체크리스트□ 점검일 :                           □ 외주PC 사용자 :            (인)□ 외주PM 소  속 :                   □ 외주PM 성  명 :            (인)                                      □ 확인자  성  명 :            (인)\n 주) 정상(O), 비정상(X)\n번호점  검  항  목결과 (o/x)1 개인 PC에 개인정보(주민번호 등) 미존재 확인\n2\n ESA(내PC지키미) 실행후 ‘취약’사항 미존재 확인 1) 악성코드 백신 설치 및 실행 여부  2) 악성코드 백신의 최신 업데이트 여부 3) 운영체제, MS Office의 최신 보안패치 설치 여부 4) 로그온 패스워드 안전성 여부 점검 5) 로그온 패스워드의 분기 1회 이상 변경 여부 점검 6) Windows 방화벽 설정 점검 7) 사용자 공유 폴더 미설정 여부 점검 8) USB 자동 실행 차단 여부 점검 9) 미사용(3개월) ActiveX 프로그램 미존재 여부 점검 3 개인용으로 설치한 P2P, 게임, 메신저, 불법소프트웨어 등 미존재 여부4 PC 화면보호기 설정여부 점검(10분이내, 비밀번호 설정유무)5 부팅 패스워드(CMOS) 설정여부 점검6 무선공유기 등 비허가 장비 미설치 점검7 PC 본체 잠금장치 설치여부 점검8 업무 종료시 PC 전원 OFF 여부 점검9 (외부망 PC) 비인가 웹사이트(상용메일, 웹하드 등) 접속 차단 확인10 (내부망 PC) 인터넷 접속 차단 확인'),
#  Document(metadata={'page': 115, 'page_label': '116', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['[붙임2] 제출서식'], 'table': {'table_title': '[별지서식 8]\n외주인력 철수 확인서', 'table_num': 115.0, 'table_content':                                                     0  \
#  0                                              신청자 정보
#  1                                               소속 회사
#  2                                                 성 명
#  3                                               사 업 명
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                            철수 확인 사항
#  6                                                   1
#  7                                                   2
#  8                                                   3
#  9                                                   4
#  10                                                  5
#  11                                                  6
#  12                                                  7
#  13                                                  8
#  14                                                  9
#  15                                                 10
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...
#
#                                                      1  \
#  0                                              신청자 정보
#  1                                               소속 회사
#  2                                                 성 명
#  3                                               사 업 명
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                            철수 확인 사항
#  6                                              출입증 반납
#  7                         통제구역 접근권한(계정, 생체인증 정보 등) 삭제
#  8   보험개발원 제공 단말기(PC, 노트북 등) 반납\n(외주업체 자산이거나 인수인계할 ...
#  9                           IP 반납 (사용 IP :\n.\n.\n. )
#  10                          정보시스템 계정 삭제요청 (사용한 모든 계정)
#  11                           전자기록 저장매체가 복원 불가하도록 완전삭제
#  12                            제공받은 서류 반납 또는 불필요 서류 파쇄
#  13                             개인 책상 및 사물함 내용물 비우고 반납
#  14                       기밀유지 준수 의무 및 위반시 처벌사항에 대한 교육
#  15                                        기밀유지 확약서 작성
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...
#
#                                                      2  \
#  0                                              신청자 정보
#  1                                               소속 부서
#  2                                              핸드폰 번호
#  3                                               근무 기간
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                            철수 확인 사항
#  6                                              출입증 반납
#  7                         통제구역 접근권한(계정, 생체인증 정보 등) 삭제
#  8   보험개발원 제공 단말기(PC, 노트북 등) 반납\n(외주업체 자산이거나 인수인계할 ...
#  9                           IP 반납 (사용 IP :\n.\n.\n. )
#  10                          정보시스템 계정 삭제요청 (사용한 모든 계정)
#  11                           전자기록 저장매체가 복원 불가하도록 완전삭제
#  12                            제공받은 서류 반납 또는 불필요 서류 파쇄
#  13                             개인 책상 및 사물함 내용물 비우고 반납
#  14                       기밀유지 준수 의무 및 위반시 처벌사항에 대한 교육
#  15                                        기밀유지 확약서 작성
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...
#
#                                                      3  \
#  0                                              신청자 정보
#  1                                                None
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                            철수 확인 사항
#  6                                              출입증 반납
#  7                         통제구역 접근권한(계정, 생체인증 정보 등) 삭제
#  8   보험개발원 제공 단말기(PC, 노트북 등) 반납\n(외주업체 자산이거나 인수인계할 ...
#  9                           IP 반납 (사용 IP :\n.\n.\n. )
#  10                          정보시스템 계정 삭제요청 (사용한 모든 계정)
#  11                           전자기록 저장매체가 복원 불가하도록 완전삭제
#  12                            제공받은 서류 반납 또는 불필요 서류 파쇄
#  13                             개인 책상 및 사물함 내용물 비우고 반납
#  14                       기밀유지 준수 의무 및 위반시 처벌사항에 대한 교육
#  15                                        기밀유지 확약서 작성
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...
#
#                                                      4  \
#  0                                              신청자 정보
#  1                                                None
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                                  확인
#  6                                                None
#  7                                                None
#  8                                                None
#  9                                                None
#  10                                               None
#  11                                               None
#  12                                               None
#  13                                               None
#  14                                               None
#  15                                               None
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...
#
#                                                      5
#  0                                              신청자 정보
#  1                                                None
#  2                                                None
#  3                                 20 . . . ~ 20 . . .
#  4   철수 확인 사항\n본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을...
#  5                                                특이사항
#  6                                                None
#  7                                                None
#  8                                                None
#  9                                                None
#  10                                               None
#  11                                               None
#  12                                               None
#  13                                               None
#  14                                               None
#  15                                               None
#  16  주) 정상(O), 비정상(X)\n본인은 상기 업무수행 중 취득한 정보에 대해 어떤 ...  }}, page_content="- 114 -\n[별지서식 8]외주인력 철수 확인서신청자 정보\n철수 확인 사항본인은 보험개발원(이하 ‘원’)의 프로젝트 철수 전에 다음 사항을 확인하였습니다.\n 주) 정상(O), 비정상(X)본인은 상기 업무수행 중 취득한 정보에 대해 어떤 형태로도 보관 및 이용하지 않으며, 제공 받은 모든 권한 및 자료를 반납하고 철수 후에도 '외주인력 보안서약서'의 내용을 준수할 것을 확인합니다.                                                                                            □ 동의20   년    월    일신 청 인 :(서 명)확 인 자:                   (서 명)   \n소속 회사소속 부서성    명 핸드폰 번호사 업 명 근무 기간20  .  .  . ~ 20  .  .  .\n철수 확인 사항확인특이사항1출입증 반납2통제구역 접근권한(계정, 생체인증 정보 등) 삭제3보험개발원 제공 단말기(PC, 노트북 등) 반납(외주업체 자산이거나 인수인계할 경우 제외)4IP 반납 (사용 IP :        .       .       .      )5정보시스템 계정 삭제요청 (사용한 모든 계정)6전자기록 저장매체가 복원 불가하도록 완전삭제7제공받은 서류 반납 또는 불필요 서류 파쇄8개인 책상 및 사물함 내용물 비우고 반납9기밀유지 준수 의무 및 위반시 처벌사항에 대한 교육10기밀유지 확약서 작성"),
#  Document(metadata={'page': 116, 'page_label': '117', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['[붙임2] 제출서식'], 'table': None}, page_content='- 115 -\n[별지서식 9]기 밀 유 지   확 약 서1.「○○○○○○○」수행과 관련하여 ㅇㅇ한 자료(전자 파일 등) 일체를 보험개발원  ㅇㅇ 부서에 반납 또는 삭제 조치하였습니다.2. 또한, 복사본이나 전자파일 등을 별도 보관하지 않음을 확인하며, 사실과 다른 경우는 관계법규에 따라 엄중한 처벌을 받을 것을 서약합니다.20    년   월   일확인자               (인)                    소  속                    직  위                                      성  명               (인)* 업체일 경우 대표자 성명     보 험 개 발 원 장   귀하'),
#  Document(metadata={'page': 117, 'page_label': '118', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['[붙임2] 제출서식'], 'table': {'table_title': '조직 및 기술인력 참여현황', 'table_num': 117.0, 'table_content':                     0                   1                   2  \
#  0     제안사 참여조직 및 인력현황     제안사 참여조직 및 인력현황     제안사 참여조직 및 인력현황
#  1               조직 체계               조직 체계               조직 체계
#  2  기술인력 참여현황 (단위 : 명)  기술인력 참여현황 (단위 : 명)  기술인력 참여현황 (단위 : 명)
#  3                 구 분                   계                전문분야
#  4                 구 분                   계                ○○분야
#  5                   계                None                None
#  6               특급기술자                None                None
#  7               고급기술자                None                None
#  8               중급기술자                None                None
#  9               초급기술자                None                None
#
#                      3                   4                   5
#  0     제안사 참여조직 및 인력현황     제안사 참여조직 및 인력현황     제안사 참여조직 및 인력현황
#  1               조직 체계               조직 체계               조직 체계
#  2  기술인력 참여현황 (단위 : 명)  기술인력 참여현황 (단위 : 명)  기술인력 참여현황 (단위 : 명)
#  3                전문분야                전문분야                기타분야
#  4                ○○분야                ○○분야                기타분야
#  5                None                None                None
#  6                None                None                None
#  7                None                None                None
#  8                None                None                None
#  9                None                None                None  }}, page_content='- 116 -\n[별지서식 10]조직 및 기술인력 참여현황 제안사 참여조직 및 인력현황조직 체계\n기술인력 참여현황 (단위 : 명)구  분계전문분야기타분야○○분야○○분야○○분야계특급기술자고급기술자중급기술자초급기술자'),
#  Document(metadata={'page': 118, 'page_label': '119', 'title': '사단법인 보험개발원_실손보험 청구 전산화 시스템 구축 사업.pdf', 'section': ['[붙임2] 제출서식'], 'table': {'table_title': None, 'table_num': 118.1, 'table_content':              0              1        2        3        4
#  0      경 력 사 항        경 력 사 항  경 력 사 항  경 력 사 항  경 력 사 항
#  1  사업명 및 사업 개요  참여기간\n(년월~년월)     담당업무      발주처       비고}}, page_content='- 117 -\n[별지서식 11]참여인력 이력 사항성  명소속연령직위자격증본사업 참여 직위 및 분야해당분야 근무경력      년      월최종학교(학위)전공기술등급본 사업참여 임무본 사업 참여 기간    .  .  . ~  .  .  .경   력   사   항사업명 및 사업 개요참여기간(년월~년월)담당업무발주처비고\n※ 기술자의 등급 및 자격기준 : 정보통신산업진흥법 시행규칙에 의함')]
